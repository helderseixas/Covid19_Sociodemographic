# %% [markdown]
# # Parameter sensitive analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import pickle

from util import save_model, summarize_results, \
    tunning_negative_binomial_model

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv('data/output/df_without_collinearity_standardized.csv', index_col=0)

# %%
df_y = pd.read_csv('data/output/df_mortality.csv', index_col=0)

# %%
list_population =  df_y['population']
list_offset = np.log(list_population)

# %%
df_cluster_labels = pd.read_csv('data/output/df_labeled_cluster.csv', index_col=0)[['cluster_label']].copy()
custom_order = pd.CategoricalDtype(
    categories=[
        'Urbanized',
        'Urbanized with informal settlements',        
        'Semi-urbanized',
        'Rural with high human development',
        'Rural with low human development'
    ],
    ordered=True
)
df_cluster_labels['cluster_label'] = df_cluster_labels['cluster_label'].astype(custom_order)
df_cluster_labels = df_cluster_labels.sort_values('cluster_label')

# %%
df_cluster_probabilities = pd.read_csv('data/output/df_standardized_pca_all_spherical_5_probability.csv', index_col=0)
df_cluster_probabilities.columns = ['Semi-urbanized', 'Rural with high human development', 'Urbanized with informal settlements', 'Rural with low human development', 'Urbanized']

# %% [markdown]
# ## Parameter Sensitivity Analysis

# %%
list_columns_y = ['deaths_accumulated_first_semester_2020', 'deaths_accumulated_2020', 'deaths_2021', 'deaths_2022', 'deaths']
# list_columns_y = ['deaths']
list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
# list_periods = ['2020_2022']
list_delta_first_death_columns = ['delta_first_death_2020-06-30', 'delta_first_death_2020-12-31', 'delta_first_death_2021-12-31', 'delta_first_death_2022-12-31', 'delta_first_death_general_period']
# list_delta_first_death_columns = ['delta_first_death_general_period']

for sample in range(30):
    print('\n*** Sample: ', sample)
    for i in range(len(list_periods)):
        column_y = list_columns_y[i]
        period = list_periods[i]
        column_delta_first_death = list_delta_first_death_columns[i]
        print('\n*** Period: ', period)
            
        y = df_y[column_y]
           
        # # Model 2      
        # print('\*** Model 2')
        # print('===>Full model:')
        # with open('models/model_2_'+period+'.pkl', 'rb') as file:
        #     model = pickle.load(file)
        # summarize_results(model)
        # 
        # x = df_cluster_labels.copy()
        # x = pd.get_dummies(x, columns=['cluster_label'], drop_first=True, dtype=int)
        # x = x.sort_index()        
        # x = pd.concat([x,df_variables], axis=1)    
        # scaler = StandardScaler()
        # delta_standardized = scaler.fit_transform(df_y[[column_delta_first_death]])
        # x['delta_first_death_period'] = delta_standardized[:,0]    
        # x = sm.add_constant(x)
        # 
        # x_bootstrap = x.sample(frac=1, replace=True)
        # y_bootstrap = y.loc[x_bootstrap.index]
        # list_offset_bootstrap = list_offset.loc[x_bootstrap.index]        
        # model = tunning_negative_binomial_model(x_bootstrap,y_bootstrap,list_offset_bootstrap)        
        # filename = 'model_2_'+period+'_sample_'+str(sample)
        # save_model(model,filename,'models/sensitivity_analysis/parameter')
        # summarize_results(model)
        #     
        # # Model 3    
        # print('\*** Model 3')
        # print('===>Full model:')
        # with open('models/model_3_'+period+'.pkl', 'rb') as file:
        #     model = pickle.load(file)
        # summarize_results(model)
        # 
        # x = df_cluster_probabilities.copy()
        # x['delta_first_death_period'] = df_y[column_delta_first_death]
        # scaler = StandardScaler()
        # x_standardized = scaler.fit_transform(x)
        # x = pd.DataFrame(x_standardized, index=x.index, columns=x.columns)  
        # x = sm.add_constant(x)
        # 
        # x_bootstrap = x.sample(frac=1, replace=True)
        # y_bootstrap = y.loc[x_bootstrap.index]
        # list_offset_bootstrap = list_offset.loc[x_bootstrap.index]
        # model = tunning_negative_binomial_model(x_bootstrap,y_bootstrap,list_offset_bootstrap)        
        # filename = 'model_3_'+period+'_sample_'+str(sample)
        # save_model(model,filename,'models/sensitivity_analysis/parameter')
        # summarize_results(model) 
        
        # Model 5 
        print('\*** Model 5')
        print('===>Full model:')
        with open('models/model_5_'+period+'.pkl', 'rb') as file:
            model = pickle.load(file)
        summarize_results(model)
        
        x = df_cluster_probabilities.copy()
        x['delta_first_death_period'] = df_y[column_delta_first_death]
        scaler = StandardScaler()
        x_standardized = scaler.fit_transform(x)
        x = pd.DataFrame(x_standardized, index=x.index, columns=x.columns)  
        x = pd.concat([x,df_variables], axis=1)
        x = sm.add_constant(x)
        
        x_bootstrap = x.sample(frac=1, replace=True)
        y_bootstrap = y.loc[x_bootstrap.index]
        list_offset_bootstrap = list_offset.loc[x_bootstrap.index]
        model = tunning_negative_binomial_model(x_bootstrap,y_bootstrap,list_offset_bootstrap)        
        filename = 'model_5_'+period+'_sample_'+str(sample)
        save_model(model,filename,'models/sensitivity_analysis/parameter')
        summarize_results(model)
# Out:
# *** Sample:  0
#
# *** Period:  2020_1
# \*** Model 5
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5538
# Model Family:                            NegativeBinomial   Df Model:                           21
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9113.1
# Date:                                    Tue, 18 Jun 2024   Deviance:                       4546.0
# Time:                                            23:47:14   Pearson chi2:                 5.72e+03
# No. Iterations:                                       100   Pseudo R-squ. (CS):             0.6496
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.4155      0.021   -454.788      0.000      -9.456      -9.375
# Semi-urbanized                                                 0.0861      0.016      5.347      0.000       0.055       0.118
# Rural with high human development                              0.0807      0.032      2.517      0.012       0.018       0.144
# Urbanized with informal settlements                           -0.0836      0.021     -4.017      0.000      -0.124      -0.043
# Rural with low human development                               0.0748      0.020      3.813      0.000       0.036       0.113
# Urbanized                                                     -0.1571      0.022     -7.308      0.000      -0.199      -0.115
# percentage_population_age_range_60_more                       -0.0926      0.027     -3.396      0.001      -0.146      -0.039
# percentage_urban_population                                    0.0936      0.031      3.029      0.002       0.033       0.154
# demographic_density                                            0.0268      0.012      2.202      0.028       0.003       0.051
# percentage_male_population                                    -0.0188      0.021     -0.897      0.370      -0.060       0.022
# percentage_indigenous_population                               0.0147      0.013      1.095      0.273      -0.012       0.041
# per_capita_income                                             -0.2777      0.028     -9.859      0.000      -0.333      -0.222
# gini                                                           0.0143      0.023      0.624      0.533      -0.031       0.059
# percentage_estimated_households_in_informal_settlements        0.0926      0.013      7.215      0.000       0.067       0.118
# demographic_density_in_informal_settlements                   -0.0109      0.014     -0.787      0.432      -0.038       0.016
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0118      0.017     -0.705      0.481      -0.045       0.021
# percentage_self_employed_workers                               0.0929      0.024      3.798      0.000       0.045       0.141
# unemployment_rate                                              0.1000      0.020      5.095      0.000       0.061       0.138
# percentage_workers_commerce                                   -0.0443      0.023     -1.888      0.059      -0.090       0.002
# percentage_workers_services                                    0.1260      0.028      4.434      0.000       0.070       0.182
# percentage_workers_industry                                    0.1112      0.025      4.488      0.000       0.063       0.160
# expected_years_of_schooling_at_age_18                          0.0627      0.021      2.999      0.003       0.022       0.104
# delta_first_death_period                                       0.8709      0.017     50.522      0.000       0.837       0.905
# ==============================================================================================================================
# llf: -9113.14
# deviance:  4545.96
# pearson_chi2:  5717.88
# Estimated dispersion:  1.03
# aic:  18270.29
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5538
# Model Family:                            NegativeBinomial   Df Model:                           21
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9077.4
# Date:                                    Tue, 18 Jun 2024   Deviance:                       4622.4
# Time:                                            23:50:00   Pearson chi2:                 5.97e+03
# No. Iterations:                                       100   Pseudo R-squ. (CS):             0.6639
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.4009      0.020   -460.332      0.000      -9.441      -9.361
# Semi-urbanized                                                 0.1120      0.016      7.106      0.000       0.081       0.143
# Rural with high human development                              0.0457      0.031      1.454      0.146      -0.016       0.107
# Urbanized with informal settlements                           -0.0764      0.020     -3.742      0.000      -0.116      -0.036
# Rural with low human development                               0.0947      0.019      4.993      0.000       0.058       0.132
# Urbanized                                                     -0.1725      0.021     -8.264      0.000      -0.213      -0.132
# delta_first_death_period                                       0.8501      0.017     49.690      0.000       0.817       0.884
# percentage_population_age_range_60_more                       -0.0393      0.027     -1.467      0.142      -0.092       0.013
# percentage_urban_population                                    0.1026      0.032      3.209      0.001       0.040       0.165
# demographic_density                                            0.0045      0.010      0.433      0.665      -0.016       0.025
# percentage_male_population                                    -0.0405      0.022     -1.803      0.071      -0.084       0.004
# percentage_indigenous_population                               0.0267      0.014      1.947      0.052      -0.000       0.053
# per_capita_income                                             -0.2353      0.027     -8.825      0.000      -0.288      -0.183
# gini                                                          -0.0030      0.023     -0.132      0.895      -0.047       0.041
# percentage_estimated_households_in_informal_settlements        0.1085      0.012      8.944      0.000       0.085       0.132
# demographic_density_in_informal_settlements                    0.0017      0.013      0.131      0.896      -0.024       0.028
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0061      0.016     -0.390      0.696      -0.037       0.025
# percentage_self_employed_workers                               0.1086      0.024      4.526      0.000       0.062       0.156
# unemployment_rate                                              0.1130      0.019      5.892      0.000       0.075       0.151
# percentage_workers_commerce                                   -0.0549      0.024     -2.335      0.020      -0.101      -0.009
# percentage_workers_services                                    0.1013      0.028      3.599      0.000       0.046       0.157
# percentage_workers_industry                                    0.1045      0.025      4.264      0.000       0.056       0.153
# expected_years_of_schooling_at_age_18                          0.0357      0.020      1.742      0.082      -0.004       0.076
# ==============================================================================================================================
# llf: -9077.41
# deviance:  4622.45
# pearson_chi2:  5967.35
# Estimated dispersion:  1.08
# aic:  18198.82
#
# *** Period:  2020
# \*** Model 5
# ===>Full model:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5538
# Model Family:             NegativeBinomial   Df Model:                           21
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15647.
# Date:                     Tue, 18 Jun 2024   Deviance:                       5630.6
# Time:                             23:50:01   Pearson chi2:                 5.76e+03
# No. Iterations:                        100   Pseudo R-squ. (CS):             0.4423
# Covariance Type:                 nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -7.4652      0.009   -862.849      0.000      -7.482      -7.448
# Semi-urbanized                                                 0.0208      0.008      2.633      0.008       0.005       0.036
# Rural with high human development                              0.0815      0.014      5.789      0.000       0.054       0.109
# Urbanized with informal settlements                           -0.0336      0.012     -2.895      0.004      -0.056      -0.011
# Rural with low human development                              -0.0128      0.010     -1.227      0.220      -0.033       0.008
# Urbanized                                                     -0.0633      0.010     -6.272      0.000      -0.083      -0.044
# percentage_population_age_range_60_more                        0.0690      0.013      5.287      0.000       0.043       0.095
# percentage_urban_population                                    0.1106      0.015      7.191      0.000       0.080       0.141
# demographic_density                                            0.0051      0.007      0.709      0.478      -0.009       0.019
# percentage_male_population                                     0.0164      0.010      1.693      0.090      -0.003       0.035
# percentage_indigenous_population                               0.0444      0.008      5.882      0.000       0.030       0.059
# per_capita_income                                             -0.0524      0.014     -3.643      0.000      -0.081      -0.024
# gini                                                          -0.0170      0.011     -1.503      0.133      -0.039       0.005
# percentage_estimated_households_in_informal_settlements        0.0397      0.008      5.288      0.000       0.025       0.054
# demographic_density_in_informal_settlements                    0.0006      0.008      0.075      0.940      -0.015       0.016
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0160      0.009     -1.832      0.067      -0.033       0.001
# percentage_self_employed_workers                               0.0304      0.012      2.513      0.012       0.007       0.054
# unemployment_rate                                              0.0079      0.010      0.752      0.452      -0.013       0.028
# percentage_workers_commerce                                   -0.0151      0.012     -1.288      0.198      -0.038       0.008
# percentage_workers_services                                    0.1011      0.014      7.186      0.000       0.073       0.129
# percentage_workers_industry                                    0.0656      0.012      5.531      0.000       0.042       0.089
# expected_years_of_schooling_at_age_18                         -0.0091      0.010     -0.899      0.369      -0.029       0.011
# delta_first_death_period                                       0.4957      0.012     40.468      0.000       0.472       0.520
# ==============================================================================================================================
# llf: -15646.91
# deviance:  5630.65
# pearson_chi2:  5761.88
# Estimated dispersion:  1.04
# aic:  31337.82
# Selected alpha: 0.14
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5538
# Model Family:             NegativeBinomial   Df Model:                           21
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15517.
# Date:                     Tue, 18 Jun 2024   Deviance:                       5541.3
# Time:                             23:53:24   Pearson chi2:                 5.64e+03
# No. Iterations:                        100   Pseudo R-squ. (CS):             0.4782
# Covariance Type:                 nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -7.4681      0.009   -875.096      0.000      -7.485      -7.451
# Semi-urbanized                                                 0.0231      0.008      3.017      0.003       0.008       0.038
# Rural with high human development                              0.0762      0.014      5.582      0.000       0.049       0.103
# Urbanized with informal settlements                           -0.0390      0.011     -3.521      0.000      -0.061      -0.017
# Rural with low human development                              -0.0191      0.010     -1.896      0.058      -0.039       0.001
# Urbanized                                                     -0.0557      0.010     -5.615      0.000      -0.075      -0.036
# delta_first_death_period                                       0.4923      0.012     41.597      0.000       0.469       0.516
# percentage_population_age_range_60_more                        0.0640      0.013      5.053      0.000       0.039       0.089
# percentage_urban_population                                    0.0949      0.015      6.228      0.000       0.065       0.125
# demographic_density                                            0.0081      0.007      1.115      0.265      -0.006       0.022
# percentage_male_population                                    -0.0052      0.009     -0.554      0.579      -0.024       0.013
# percentage_indigenous_population                               0.0327      0.007      4.694      0.000       0.019       0.046
# per_capita_income                                             -0.0570      0.014     -4.219      0.000      -0.084      -0.031
# gini                                                          -0.0223      0.011     -1.974      0.048      -0.044      -0.000
# percentage_estimated_households_in_informal_settlements        0.0461      0.007      6.422      0.000       0.032       0.060
# demographic_density_in_informal_settlements                   -0.0078      0.008     -0.998      0.318      -0.023       0.007
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0036      0.009     -0.412      0.680      -0.021       0.014
# percentage_self_employed_workers                               0.0426      0.012      3.577      0.000       0.019       0.066
# unemployment_rate                                              0.0213      0.010      2.074      0.038       0.001       0.042
# percentage_workers_commerce                                   -0.0288      0.012     -2.497      0.013      -0.051      -0.006
# percentage_workers_services                                    0.1340      0.013     10.053      0.000       0.108       0.160
# percentage_workers_industry                                    0.0800      0.011      7.007      0.000       0.058       0.102
# expected_years_of_schooling_at_age_18                         -0.0192      0.010     -1.950      0.051      -0.039    9.53e-05
# ==============================================================================================================================
# llf: -15517.31
# deviance:  5541.29
# pearson_chi2:  5641.11
# Estimated dispersion:  1.02
# aic:  31078.63
#
# *** Period:  2021
# \*** Model 5
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19579.
# Date:                Tue, 18 Jun 2024   Deviance:                       5648.0
# Time:                        23:53:25   Pearson chi2:                 5.76e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.6399
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -6.4296      0.006  -1110.044      0.000      -6.441      -6.418
# Semi-urbanized                                                -0.0686      0.006    -11.866      0.000      -0.080      -0.057
# Rural with high human development                              0.0712      0.010      7.350      0.000       0.052       0.090
# Urbanized with informal settlements                           -0.0347      0.009     -3.796      0.000      -0.053      -0.017
# Rural with low human development                              -0.1167      0.008    -14.524      0.000      -0.132      -0.101
# Urbanized                                                      0.0997      0.007     13.603      0.000       0.085       0.114
# percentage_population_age_range_60_more                        0.0503      0.009      5.384      0.000       0.032       0.069
# percentage_urban_population                                    0.1104      0.011      9.825      0.000       0.088       0.132
# demographic_density                                            0.0043      0.006      0.754      0.451      -0.007       0.016
# percentage_male_population                                     0.0468      0.007      7.078      0.000       0.034       0.060
# percentage_indigenous_population                               0.0339      0.006      5.426      0.000       0.022       0.046
# per_capita_income                                             -0.0044      0.011     -0.414      0.679      -0.025       0.016
# gini                                                           0.0112      0.008      1.356      0.175      -0.005       0.027
# percentage_estimated_households_in_informal_settlements        0.0057      0.006      0.932      0.351      -0.006       0.018
# demographic_density_in_informal_settlements                    0.0193      0.006      3.081      0.002       0.007       0.032
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0101      0.007      1.529      0.126      -0.003       0.023
# percentage_self_employed_workers                              -0.0044      0.009     -0.502      0.615      -0.021       0.013
# unemployment_rate                                             -0.0415      0.008     -5.214      0.000      -0.057      -0.026
# percentage_workers_commerce                                   -0.0247      0.009     -2.881      0.004      -0.042      -0.008
# percentage_workers_services                                    0.0600      0.010      5.890      0.000       0.040       0.080
# percentage_workers_industry                                    0.0077      0.009      0.903      0.367      -0.009       0.024
# expected_years_of_schooling_at_age_18                          0.0605      0.007      8.294      0.000       0.046       0.075
# delta_first_death_period                                       0.2388      0.009     25.711      0.000       0.221       0.257
# ==============================================================================================================================
# llf: -19578.65
# deviance:  5647.98
# pearson_chi2:  5762.21
# Estimated dispersion:  1.04
# aic:  39201.3
# Selected alpha: 0.09999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19546.
# Date:                Tue, 18 Jun 2024   Deviance:                       5668.0
# Time:                        23:57:52   Pearson chi2:                 5.81e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.6327
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -6.4334      0.006  -1113.973      0.000      -6.445      -6.422
# Semi-urbanized                                                -0.0658      0.006    -11.301      0.000      -0.077      -0.054
# Rural with high human development                              0.0680      0.010      6.978      0.000       0.049       0.087
# Urbanized with informal settlements                           -0.0243      0.009     -2.700      0.007      -0.042      -0.007
# Rural with low human development                              -0.1145      0.008    -14.473      0.000      -0.130      -0.099
# Urbanized                                                      0.0928      0.007     12.637      0.000       0.078       0.107
# delta_first_death_period                                       0.2334      0.009     25.694      0.000       0.216       0.251
# percentage_population_age_range_60_more                        0.0621      0.009      6.767      0.000       0.044       0.080
# percentage_urban_population                                    0.1274      0.011     11.088      0.000       0.105       0.150
# demographic_density                                            0.0055      0.006      0.965      0.335      -0.006       0.017
# percentage_male_population                                     0.0550      0.007      8.422      0.000       0.042       0.068
# percentage_indigenous_population                               0.0379      0.007      5.808      0.000       0.025       0.051
# per_capita_income                                             -0.0132      0.011     -1.216      0.224      -0.035       0.008
# gini                                                           0.0138      0.008      1.665      0.096      -0.002       0.030
# percentage_estimated_households_in_informal_settlements        0.0056      0.006      0.903      0.366      -0.007       0.018
# demographic_density_in_informal_settlements                    0.0143      0.006      2.336      0.019       0.002       0.026
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0120      0.007      1.786      0.074      -0.001       0.025
# percentage_self_employed_workers                               0.0013      0.009      0.149      0.881      -0.016       0.018
# unemployment_rate                                             -0.0419      0.008     -5.146      0.000      -0.058      -0.026
# percentage_workers_commerce                                   -0.0220      0.009     -2.484      0.013      -0.039      -0.005
# percentage_workers_services                                    0.0510      0.010      5.043      0.000       0.031       0.071
# percentage_workers_industry                                    0.0057      0.009      0.667      0.505      -0.011       0.022
# expected_years_of_schooling_at_age_18                          0.0688      0.007      9.293      0.000       0.054       0.083
# ==============================================================================================================================
# llf: -19545.96
# deviance:  5668.04
# pearson_chi2:  5805.08
# Estimated dispersion:  1.05
# aic:  39135.92
#
# *** Period:  2022
# \*** Model 5
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11260.
# Date:                Tue, 18 Jun 2024   Deviance:                       4656.8
# Time:                        23:57:52   Pearson chi2:                 5.07e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.6204
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -8.4340      0.014   -623.672      0.000      -8.460      -8.407
# Semi-urbanized                                                -0.0274      0.008     -3.489      0.000      -0.043      -0.012
# Rural with high human development                              0.0561      0.014      3.934      0.000       0.028       0.084
# Urbanized with informal settlements                           -0.0189      0.010     -1.826      0.068      -0.039       0.001
# Rural with low human development                              -0.0747      0.012     -6.195      0.000      -0.098      -0.051
# Urbanized                                                      0.0358      0.010      3.607      0.000       0.016       0.055
# percentage_population_age_range_60_more                        0.2724      0.012     22.071      0.000       0.248       0.297
# percentage_urban_population                                    0.0825      0.016      5.001      0.000       0.050       0.115
# demographic_density                                           -0.0111      0.005     -2.179      0.029      -0.021      -0.001
# percentage_male_population                                     0.0618      0.010      6.382      0.000       0.043       0.081
# percentage_indigenous_population                               0.0328      0.010      3.185      0.001       0.013       0.053
# per_capita_income                                              0.0318      0.012      2.550      0.011       0.007       0.056
# gini                                                          -0.0209      0.011     -1.853      0.064      -0.043       0.001
# percentage_estimated_households_in_informal_settlements       -0.0042      0.006     -0.678      0.498      -0.017       0.008
# demographic_density_in_informal_settlements                    0.0019      0.006      0.316      0.752      -0.010       0.014
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0173      0.010     -1.649      0.099      -0.038       0.003
# percentage_self_employed_workers                              -0.0662      0.013     -4.954      0.000      -0.092      -0.040
# unemployment_rate                                             -0.0177      0.012     -1.510      0.131      -0.041       0.005
# percentage_workers_commerce                                   -0.0582      0.012     -4.918      0.000      -0.081      -0.035
# percentage_workers_services                                   -0.0015      0.014     -0.103      0.918      -0.030       0.027
# percentage_workers_industry                                   -0.0350      0.012     -3.017      0.003      -0.058      -0.012
# expected_years_of_schooling_at_age_18                          0.0423      0.010      4.111      0.000       0.022       0.062
# delta_first_death_period                                       0.8650      0.023     37.243      0.000       0.819       0.910
# ==============================================================================================================================
# llf: -11259.64
# deviance:  4656.8
# pearson_chi2:  5072.45
# Estimated dispersion:  0.92
# aic:  22563.27
# Selected alpha: 0.060000000000000005
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11305.
# Date:                Wed, 19 Jun 2024   Deviance:                       4570.5
# Time:                        00:02:31   Pearson chi2:                 5.06e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.6559
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -8.4432      0.014   -621.977      0.000      -8.470      -8.417
# Semi-urbanized                                                -0.0216      0.008     -2.729      0.006      -0.037      -0.006
# Rural with high human development                              0.0491      0.014      3.495      0.000       0.022       0.077
# Urbanized with informal settlements                           -0.0122      0.010     -1.198      0.231      -0.032       0.008
# Rural with low human development                              -0.0738      0.012     -6.281      0.000      -0.097      -0.051
# Urbanized                                                      0.0310      0.010      3.126      0.002       0.012       0.050
# delta_first_death_period                                       0.8855      0.023     38.150      0.000       0.840       0.931
# percentage_population_age_range_60_more                        0.2842      0.012     23.617      0.000       0.261       0.308
# percentage_urban_population                                    0.0935      0.017      5.554      0.000       0.060       0.126
# demographic_density                                           -0.0032      0.005     -0.660      0.509      -0.013       0.006
# percentage_male_population                                     0.0858      0.010      8.683      0.000       0.066       0.105
# percentage_indigenous_population                               0.0422      0.011      3.903      0.000       0.021       0.063
# per_capita_income                                              0.0232      0.012      1.905      0.057      -0.001       0.047
# gini                                                          -0.0051      0.011     -0.450      0.653      -0.027       0.017
# percentage_estimated_households_in_informal_settlements       -0.0080      0.006     -1.266      0.205      -0.020       0.004
# demographic_density_in_informal_settlements                   -0.0020      0.006     -0.356      0.722      -0.013       0.009
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0370      0.011     -3.393      0.001      -0.058      -0.016
# percentage_self_employed_workers                              -0.0660      0.013     -4.911      0.000      -0.092      -0.040
# unemployment_rate                                             -0.0395      0.012     -3.414      0.001      -0.062      -0.017
# percentage_workers_commerce                                   -0.0387      0.011     -3.384      0.001      -0.061      -0.016
# percentage_workers_services                                   -0.0102      0.014     -0.709      0.478      -0.038       0.018
# percentage_workers_industry                                   -0.0205      0.012     -1.782      0.075      -0.043       0.002
# expected_years_of_schooling_at_age_18                          0.0538      0.010      5.216      0.000       0.034       0.074
# ==============================================================================================================================
# llf: -11305.37
# deviance:  4570.52
# pearson_chi2:  5060.92
# Estimated dispersion:  0.91
# aic:  22654.75
#
# *** Period:  2020_2022
# \*** Model 5
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21332.
# Date:                Wed, 19 Jun 2024   Deviance:                       5506.2
# Time:                        00:02:31   Pearson chi2:                 5.59e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.5802
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -5.9536      0.005  -1226.409      0.000      -5.963      -5.944
# Semi-urbanized                                                -0.0529      0.005    -10.626      0.000      -0.063      -0.043
# Rural with high human development                              0.0773      0.008      9.266      0.000       0.061       0.094
# Urbanized with informal settlements                           -0.0373      0.008     -4.668      0.000      -0.053      -0.022
# Rural with low human development                              -0.0909      0.007    -13.376      0.000      -0.104      -0.078
# Urbanized                                                      0.0651      0.006     10.353      0.000       0.053       0.077
# percentage_population_age_range_60_more                        0.0622      0.008      7.699      0.000       0.046       0.078
# percentage_urban_population                                    0.1196      0.010     12.536      0.000       0.101       0.138
# demographic_density                                            0.0053      0.005      1.024      0.306      -0.005       0.015
# percentage_male_population                                     0.0269      0.006      4.617      0.000       0.015       0.038
# percentage_indigenous_population                               0.0414      0.005      8.031      0.000       0.031       0.052
# per_capita_income                                             -0.0102      0.009     -1.101      0.271      -0.028       0.008
# gini                                                           0.0099      0.007      1.398      0.162      -0.004       0.024
# percentage_estimated_households_in_informal_settlements        0.0193      0.005      3.604      0.000       0.009       0.030
# demographic_density_in_informal_settlements                    0.0160      0.006      2.889      0.004       0.005       0.027
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0071      0.006     -1.279      0.201      -0.018       0.004
# percentage_self_employed_workers                               0.0057      0.007      0.775      0.438      -0.009       0.020
# unemployment_rate                                             -0.0194      0.007     -2.902      0.004      -0.033      -0.006
# percentage_workers_commerce                                   -0.0040      0.007     -0.542      0.588      -0.018       0.010
# percentage_workers_services                                    0.0545      0.009      6.262      0.000       0.037       0.072
# percentage_workers_industry                                    0.0191      0.007      2.580      0.010       0.005       0.034
# expected_years_of_schooling_at_age_18                          0.0309      0.006      4.952      0.000       0.019       0.043
# delta_first_death_period                                       0.1675      0.007     23.666      0.000       0.154       0.181
# ==============================================================================================================================
# llf: -21331.95
# deviance:  5506.18
# pearson_chi2:  5585.99
# Estimated dispersion:  1.01
# aic:  42707.9
# Selected alpha: 0.06999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21438.
# Date:                Wed, 19 Jun 2024   Deviance:                       5934.6
# Time:                        00:07:28   Pearson chi2:                 6.04e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.6315
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -5.9595      0.005  -1271.754      0.000      -5.969      -5.950
# Semi-urbanized                                                -0.0434      0.005     -9.145      0.000      -0.053      -0.034
# Rural with high human development                              0.0681      0.008      8.595      0.000       0.053       0.084
# Urbanized with informal settlements                           -0.0343      0.008     -4.496      0.000      -0.049      -0.019
# Rural with low human development                              -0.0911      0.006    -14.301      0.000      -0.104      -0.079
# Urbanized                                                      0.0604      0.006     10.095      0.000       0.049       0.072
# delta_first_death_period                                       0.1623      0.007     23.789      0.000       0.149       0.176
# percentage_population_age_range_60_more                        0.0772      0.008     10.127      0.000       0.062       0.092
# percentage_urban_population                                    0.1446      0.009     15.560      0.000       0.126       0.163
# demographic_density                                            0.0004      0.005      0.088      0.930      -0.009       0.010
# percentage_male_population                                     0.0276      0.005      5.040      0.000       0.017       0.038
# percentage_indigenous_population                               0.0464      0.005      9.174      0.000       0.037       0.056
# per_capita_income                                             -0.0072      0.009     -0.847      0.397      -0.024       0.010
# gini                                                           0.0251      0.007      3.731      0.000       0.012       0.038
# percentage_estimated_households_in_informal_settlements        0.0203      0.005      4.028      0.000       0.010       0.030
# demographic_density_in_informal_settlements                    0.0199      0.006      3.269      0.001       0.008       0.032
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0008      0.006     -0.149      0.882      -0.012       0.010
# percentage_self_employed_workers                               0.0138      0.007      1.933      0.053      -0.000       0.028
# unemployment_rate                                             -0.0198      0.007     -3.030      0.002      -0.033      -0.007
# percentage_workers_commerce                                   -0.0167      0.007     -2.321      0.020      -0.031      -0.003
# percentage_workers_services                                    0.0474      0.008      5.653      0.000       0.031       0.064
# percentage_workers_industry                                    0.0236      0.007      3.295      0.001       0.010       0.038
# expected_years_of_schooling_at_age_18                          0.0434      0.006      7.292      0.000       0.032       0.055
# ==============================================================================================================================
# llf: -21438.1
# deviance:  5934.57
# pearson_chi2:  6037.96
# Estimated dispersion:  1.09
# aic:  42920.2
#
# *** Sample:  1
#
# *** Period:  2020_1
# \*** Model 5
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5538
# Model Family:                            NegativeBinomial   Df Model:                           21
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9113.1
# Date:                                    Wed, 19 Jun 2024   Deviance:                       4546.0
# Time:                                            00:07:28   Pearson chi2:                 5.72e+03
# No. Iterations:                                       100   Pseudo R-squ. (CS):             0.6496
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.4155      0.021   -454.788      0.000      -9.456      -9.375
# Semi-urbanized                                                 0.0861      0.016      5.347      0.000       0.055       0.118
# Rural with high human development                              0.0807      0.032      2.517      0.012       0.018       0.144
# Urbanized with informal settlements                           -0.0836      0.021     -4.017      0.000      -0.124      -0.043
# Rural with low human development                               0.0748      0.020      3.813      0.000       0.036       0.113
# Urbanized                                                     -0.1571      0.022     -7.308      0.000      -0.199      -0.115
# percentage_population_age_range_60_more                       -0.0926      0.027     -3.396      0.001      -0.146      -0.039
# percentage_urban_population                                    0.0936      0.031      3.029      0.002       0.033       0.154
# demographic_density                                            0.0268      0.012      2.202      0.028       0.003       0.051
# percentage_male_population                                    -0.0188      0.021     -0.897      0.370      -0.060       0.022
# percentage_indigenous_population                               0.0147      0.013      1.095      0.273      -0.012       0.041
# per_capita_income                                             -0.2777      0.028     -9.859      0.000      -0.333      -0.222
# ...
# Rural with low human development                              -0.0747      0.012     -6.195      0.000      -0.098      -0.051
# Urbanized                                                      0.0358      0.010      3.607      0.000       0.016       0.055
# percentage_population_age_range_60_more                        0.2724      0.012     22.071      0.000       0.248       0.297
# percentage_urban_population                                    0.0825      0.016      5.001      0.000       0.050       0.115
# demographic_density                                           -0.0111      0.005     -2.179      0.029      -0.021      -0.001
# percentage_male_population                                     0.0618      0.010      6.382      0.000       0.043       0.081
# percentage_indigenous_population                               0.0328      0.010      3.185      0.001       0.013       0.053
# per_capita_income                                              0.0318      0.012      2.550      0.011       0.007       0.056
# gini                                                          -0.0209      0.011     -1.853      0.064      -0.043       0.001
# percentage_estimated_households_in_informal_settlements       -0.0042      0.006     -0.678      0.498      -0.017       0.008
# demographic_density_in_informal_settlements                    0.0019      0.006      0.316      0.752      -0.010       0.014
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0173      0.010     -1.649      0.099      -0.038       0.003
# percentage_self_employed_workers                              -0.0662      0.013     -4.954      0.000      -0.092      -0.040
# unemployment_rate                                             -0.0177      0.012     -1.510      0.131      -0.041       0.005
# percentage_workers_commerce                                   -0.0582      0.012     -4.918      0.000      -0.081      -0.035
# percentage_workers_services                                   -0.0015      0.014     -0.103      0.918      -0.030       0.027
# percentage_workers_industry                                   -0.0350      0.012     -3.017      0.003      -0.058      -0.012
# expected_years_of_schooling_at_age_18                          0.0423      0.010      4.111      0.000       0.022       0.062
# delta_first_death_period                                       0.8650      0.023     37.243      0.000       0.819       0.910
# ==============================================================================================================================
# llf: -11259.64
# deviance:  4656.8
# pearson_chi2:  5072.45
# Estimated dispersion:  0.92
# aic:  22563.27
# Selected alpha: 0.06999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11278.
# Date:                Wed, 19 Jun 2024   Deviance:                       4575.3
# Time:                        06:09:20   Pearson chi2:                 4.97e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.5993
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -8.4236      0.013   -624.719      0.000      -8.450      -8.397
# Semi-urbanized                                                -0.0176      0.008     -2.170      0.030      -0.034      -0.002
# Rural with high human development                              0.0306      0.014      2.130      0.033       0.002       0.059
# Urbanized with informal settlements                           -0.0026      0.011     -0.234      0.815      -0.024       0.019
# Rural with low human development                              -0.0627      0.012     -5.089      0.000      -0.087      -0.039
# Urbanized                                                      0.0304      0.010      2.999      0.003       0.011       0.050
# delta_first_death_period                                       0.8390      0.023     36.386      0.000       0.794       0.884
# percentage_population_age_range_60_more                        0.2886      0.013     22.698      0.000       0.264       0.313
# percentage_urban_population                                    0.0745      0.017      4.412      0.000       0.041       0.108
# demographic_density                                           -0.0097      0.005     -1.923      0.054      -0.019       0.000
# percentage_male_population                                     0.0671      0.011      6.282      0.000       0.046       0.088
# percentage_indigenous_population                               0.0348      0.011      3.217      0.001       0.014       0.056
# per_capita_income                                              0.0266      0.013      2.028      0.043       0.001       0.052
# gini                                                          -0.0169      0.012     -1.437      0.151      -0.040       0.006
# percentage_estimated_households_in_informal_settlements       -0.0095      0.007     -1.324      0.186      -0.024       0.005
# demographic_density_in_informal_settlements                   -0.0037      0.006     -0.583      0.560      -0.016       0.009
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0216      0.011     -2.052      0.040      -0.042      -0.001
# percentage_self_employed_workers                              -0.0744      0.014     -5.468      0.000      -0.101      -0.048
# unemployment_rate                                             -0.0232      0.012     -1.892      0.058      -0.047       0.001
# percentage_workers_commerce                                   -0.0591      0.012     -4.827      0.000      -0.083      -0.035
# percentage_workers_services                                   -0.0033      0.015     -0.216      0.829      -0.033       0.026
# percentage_workers_industry                                   -0.0320      0.012     -2.668      0.008      -0.056      -0.009
# expected_years_of_schooling_at_age_18                          0.0759      0.011      7.111      0.000       0.055       0.097
# ==============================================================================================================================
# llf: -11277.72
# deviance:  4575.33
# pearson_chi2:  4972.45
# Estimated dispersion:  0.9
# aic:  22599.43
#
# *** Period:  2020_2022
# \*** Model 5
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21332.
# Date:                Wed, 19 Jun 2024   Deviance:                       5506.2
# Time:                        06:09:20   Pearson chi2:                 5.59e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.5802
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -5.9536      0.005  -1226.409      0.000      -5.963      -5.944
# Semi-urbanized                                                -0.0529      0.005    -10.626      0.000      -0.063      -0.043
# Rural with high human development                              0.0773      0.008      9.266      0.000       0.061       0.094
# Urbanized with informal settlements                           -0.0373      0.008     -4.668      0.000      -0.053      -0.022
# Rural with low human development                              -0.0909      0.007    -13.376      0.000      -0.104      -0.078
# Urbanized                                                      0.0651      0.006     10.353      0.000       0.053       0.077
# percentage_population_age_range_60_more                        0.0622      0.008      7.699      0.000       0.046       0.078
# percentage_urban_population                                    0.1196      0.010     12.536      0.000       0.101       0.138
# demographic_density                                            0.0053      0.005      1.024      0.306      -0.005       0.015
# percentage_male_population                                     0.0269      0.006      4.617      0.000       0.015       0.038
# percentage_indigenous_population                               0.0414      0.005      8.031      0.000       0.031       0.052
# per_capita_income                                             -0.0102      0.009     -1.101      0.271      -0.028       0.008
# gini                                                           0.0099      0.007      1.398      0.162      -0.004       0.024
# percentage_estimated_households_in_informal_settlements        0.0193      0.005      3.604      0.000       0.009       0.030
# demographic_density_in_informal_settlements                    0.0160      0.006      2.889      0.004       0.005       0.027
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0071      0.006     -1.279      0.201      -0.018       0.004
# percentage_self_employed_workers                               0.0057      0.007      0.775      0.438      -0.009       0.020
# unemployment_rate                                             -0.0194      0.007     -2.902      0.004      -0.033      -0.006
# percentage_workers_commerce                                   -0.0040      0.007     -0.542      0.588      -0.018       0.010
# percentage_workers_services                                    0.0545      0.009      6.262      0.000       0.037       0.072
# percentage_workers_industry                                    0.0191      0.007      2.580      0.010       0.005       0.034
# expected_years_of_schooling_at_age_18                          0.0309      0.006      4.952      0.000       0.019       0.043
# delta_first_death_period                                       0.1675      0.007     23.666      0.000       0.154       0.181
# ==============================================================================================================================
# llf: -21331.95
# deviance:  5506.18
# pearson_chi2:  5585.99
# Estimated dispersion:  1.01
# aic:  42707.9
# Selected alpha: 0.08
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5538
# Model Family:        NegativeBinomial   Df Model:                           21
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21407.
# Date:                Wed, 19 Jun 2024   Deviance:                       5574.8
# Time:                        06:11:42   Pearson chi2:                 5.64e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.5990
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -5.9597      0.005  -1219.401      0.000      -5.969      -5.950
# Semi-urbanized                                                -0.0532      0.005    -10.578      0.000      -0.063      -0.043
# Rural with high human development                              0.0605      0.008      7.149      0.000       0.044       0.077
# Urbanized with informal settlements                           -0.0291      0.008     -3.697      0.000      -0.045      -0.014
# Rural with low human development                              -0.0882      0.007    -13.120      0.000      -0.101      -0.075
# Urbanized                                                      0.0730      0.006     11.486      0.000       0.061       0.085
# delta_first_death_period                                       0.1643      0.007     22.787      0.000       0.150       0.178
# percentage_population_age_range_60_more                        0.0742      0.008      9.070      0.000       0.058       0.090
# percentage_urban_population                                    0.1309      0.010     13.549      0.000       0.112       0.150
# demographic_density                                            0.0033      0.005      0.679      0.497      -0.006       0.013
# percentage_male_population                                     0.0238      0.005      4.337      0.000       0.013       0.035
# percentage_indigenous_population                               0.0430      0.005      8.732      0.000       0.033       0.053
# per_capita_income                                             -0.0114      0.009     -1.229      0.219      -0.029       0.007
# gini                                                           0.0068      0.007      0.965      0.335      -0.007       0.021
# percentage_estimated_households_in_informal_settlements        0.0156      0.005      3.080      0.002       0.006       0.026
# demographic_density_in_informal_settlements                    0.0163      0.005      3.259      0.001       0.007       0.026
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0094      0.006     -1.691      0.091      -0.020       0.001
# percentage_self_employed_workers                               0.0154      0.007      2.119      0.034       0.001       0.030
# unemployment_rate                                             -0.0219      0.007     -3.212      0.001      -0.035      -0.009
# percentage_workers_commerce                                   -0.0008      0.007     -0.112      0.911      -0.015       0.013
# percentage_workers_services                                    0.0420      0.009      4.840      0.000       0.025       0.059
# percentage_workers_industry                                    0.0189      0.007      2.592      0.010       0.005       0.033
# expected_years_of_schooling_at_age_18                          0.0232      0.006      3.699      0.000       0.011       0.035
# ==============================================================================================================================
# llf: -21407.29
# deviance:  5574.84
# pearson_chi2:  5644.53
# Estimated dispersion:  1.02
# aic:  42858.59

# %%
x_bootstrap
# Out:
#       const  Semi-urbanized  Rural with high human development  \
# 1418    1.0        0.456604                           0.828420
# 3238    1.0       -0.860770                          -0.556115
# 1279    1.0        1.402458                          -0.563814
# 1207    1.0        1.374694                          -0.565919
# 364     1.0        0.500858                          -0.560549
# ...     ...             ...                                ...
# 728     1.0        1.458991                          -0.557718
# 4826    1.0       -0.864811                           1.813702
# 2526    1.0        1.099081                          -0.184275
# 4968    1.0       -0.864823                           1.853968
# 2792    1.0       -0.818381                          -0.528545
#
#       Urbanized with informal settlements  Rural with low human development  \
# 1418                            -0.334782                         -0.324070
# 3238                             0.320993                         -0.333342
# 1279                            -0.243816                         -0.278838
# 1207                            -0.210680                         -0.220599
# 364                              0.957967                         -0.301398
# ...                                   ...                               ...
# 728                             -0.352604                         -0.263566
# 4826                            -0.321491                         -0.333387
# 2526                            -0.319624                         -0.322684
# 4968                            -0.318711                         -0.333387
# 2792                            -0.018047                         -0.333117
#
#       Urbanized  delta_first_death_period  \
# 1418  -0.812839                 -1.105789
# 3238   1.405318                  1.066754
# 1279  -0.836473                  0.285840
# 1207  -0.851750                  0.656274
# 364   -0.423193                  0.375945
# ...         ...                       ...
# 728   -0.858319                  0.135664
# 4826  -0.127324                 -1.556316
# 2526  -0.737832                 -0.264805
# 4968  -0.160159                  0.816461
# 2792   1.503525                  0.075594
#
#       percentage_population_age_range_60_more  percentage_urban_population  \
# 1418                                 0.706258                    -1.407957
# 3238                                 0.290904                     0.474719
# 1279                                -0.476842                     0.527027
# 1207                                -1.047237                    -0.815832
# 364                                 -1.147015                     0.796210
# ...                                       ...                          ...
# 728                                  0.176606                    -1.281736
# 4826                                 2.864454                     0.318173
# 2526                                 0.642422                    -0.928741
# 4968                                 0.909690                    -0.621702
# 2792                                -0.673496                     0.920374
#
#       demographic_density  ...      gini  \
# 1418            -0.172384  ... -0.369034
# 3238             0.010804  ... -0.217652
# 1279            -0.137732  ... -0.369034
# 1207             0.078866  ...  0.842020
# 364             -0.185349  ... -0.520416
# ...                   ...  ...       ...
# 728             -0.182279  ...  0.236493
# 4826            -0.163176  ... -1.580088
# 2526            -0.170555  ... -0.520416
# 4968            -0.060999  ... -2.034234
# 2792            -0.152441  ... -0.066270
#
#       percentage_estimated_households_in_informal_settlements  \
# 1418                                          -0.231671
# 3238                                           0.115101
# 1279                                          -0.231671
# 1207                                          -0.171691
# 364                                           -0.231671
# ...                                                 ...
# 728                                           -0.231671
# 4826                                          -0.231671
# 2526                                          -0.231671
# 4968                                          -0.231671
# 2792                                          -0.231671
#
#       demographic_density_in_informal_settlements  \
# 1418                                    -0.174949
# 3238                                     1.922059
# 1279                                    -0.174949
# 1207                                    -0.174949
# 364                                     -0.174949
# ...                                           ...
# 728                                     -0.174949
# 4826                                    -0.174949
# 2526                                    -0.174949
# 4968                                    -0.174949
# 2792                                    -0.174949
#
#       percentage_hospitalizations_diseases_inadequate_sanitation  \
# 1418                                           0.413033
# 3238                                          -0.462661
# 1279                                           6.093207
# 1207                                          -0.634787
# 364                                           -0.533663
# ...                                                 ...
# 728                                           -0.204471
# 4826                                          -0.361536
# 2526                                          -0.619726
# 4968                                          -0.679970
# 2792                                          -0.520753
#
#       percentage_self_employed_workers  unemployment_rate  \
# 1418                         -1.718124          -0.547265
# 3238                         -0.269622           0.626415
# 1279                         -0.009765           0.205563
# 1207                         -0.278758           1.238088
# 364                          -1.055284           0.129758
# ...                                ...                ...
# 728                          -0.680724          -0.910609
# 4826                          1.373772          -0.688420
# 2526                         -0.088940          -0.714560
# 4968                          1.502686          -1.287023
# 2792                         -0.762945          -0.071519
#
#       percentage_workers_commerce  percentage_workers_services  \
# 1418                    -0.672077                    -0.655702
# 3238                     1.477362                     1.992942
# 1279                     3.574598                    -1.231788
# 1207                     0.619402                     0.494219
# 364                      2.101539                     1.494493
# ...                           ...                          ...
# 728                     -1.278097                    -0.810975
# 4826                     0.444633                    -0.317027
# 2526                    -0.181814                    -0.160628
# 4968                     0.283481                    -1.187906
# 2792                     1.400191                    -0.007606
#
#       percentage_workers_industry  expected_years_of_schooling_at_age_18
# 1418                    -1.016939                              -0.103302
# 3238                    -0.302421                              -0.522284
# 1279                     1.669515                              -0.467634
# 1207                    -0.015268                              -0.412984
# 364                     -0.878971                               0.525170
# ...                           ...                                    ...
# 728                     -0.868876                              -0.340118
# 4826                     0.159717                               1.390458
# 2526                    -0.868876                              -0.148844
# 4968                     1.488923                               0.370329
# 2792                     0.749727                              -0.294576
#
# [5560 rows x 23 columns]

# %%
y_bootstrap
# Out:
# 1418      9.0
# 3238    249.0
# 1279     22.0
# 1207    100.0
# 364      11.0
#         ...
# 728       7.0
# 4826      4.0
# 2526      8.0
# 4968     13.0
# 2792     49.0
# Name: deaths, Length: 5560, dtype: float64

# %%
list_offset_bootstrap
# Out:
# 1418     7.871693
# 3238    10.938023
# 1279     9.518780
# 1207    10.763970
# 364      8.147578
#           ...
# 728      8.852379
# 4826     8.113127
# 2526     8.543446
# 4968     8.837391
# 2792     9.541082
# Name: population, Length: 5560, dtype: float64
