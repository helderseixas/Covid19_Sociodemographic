# %% [markdown]
# # Variable sensitive analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import pickle

from util import save_model, summarize_results

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv('data/output/df_without_collinearity_standardized.csv', index_col=0)

# %%
df_y = pd.read_csv('data/output/df_mortality.csv', index_col=0)

# %%
list_population =  df_y['population']
list_offset = np.log(list_population)

# %%
df_cluster_labels = pd.read_csv('data/output/df_labeled_cluster.csv', index_col=0)[['cluster_label']].copy()
custom_order = pd.CategoricalDtype(
    categories=[
        'Urbanized',
        'Urbanized with informal settlements',        
        'Semi-urbanized',
        'Rural with high human development',
        'Rural with low human development'
    ],
    ordered=True
)
df_cluster_labels['cluster_label'] = df_cluster_labels['cluster_label'].astype(custom_order)
df_cluster_labels = df_cluster_labels.sort_values('cluster_label')

# %%
df_cluster_probabilities = pd.read_csv('data/output/df_standardized_pca_all_spherical_5_probability.csv', index_col=0)
df_cluster_probabilities.columns = ['Semi-urbanized', 'Rural with high human development', 'Urbanized with informal settlements', 'Rural with low human development', 'Urbanized']

# %% [markdown]
# ## Variable Sensitivity Analysis

# %%
def tunning_negative_binomial_model(x, y, list_offset):
    list_nb_glm_models = np.array([])
    list_llf_models = np.array([])
    list_alpha = np.arange(0.01, 2.1, 0.01)

    for alpha in list_alpha:
        nb_glm_model = sm.GLM(y, x, family=sm.families.NegativeBinomial(alpha=alpha), offset=list_offset).fit()
        llf = nb_glm_model.llf
        list_nb_glm_models = np.append(list_nb_glm_models, nb_glm_model)
        list_llf_models = np.append(list_llf_models, llf)

    print('Selected alpha:', list_alpha[abs(list_llf_models) == min(abs(list_llf_models))][0])
    return list_nb_glm_models[abs(list_llf_models) == min(abs(list_llf_models))][0]

# %%
list_columns_y = ['deaths_accumulated_first_semester_2020', 'deaths_accumulated_2020', 'deaths_2021', 'deaths_2022', 'deaths']
list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
list_delta_first_death_columns = ['delta_first_death_2020-06-30', 'delta_first_death_2020-12-31', 'delta_first_death_2021-12-31', 'delta_first_death_2022-12-31', 'delta_first_death_general_period']
   
for i in range(5):
    column_y = list_columns_y[i]
    period = list_periods[i]
    column_delta_first_death = list_delta_first_death_columns[i]
    print('\n*** Period: ', period)
        
    y = df_y[column_y]
       
    # Model 2      
    print('\*** Model 2')
    print('===>Full model:')
    with open('models/model_2_'+period+'.pkl', 'rb') as file:
        model = pickle.load(file)
    summarize_results(model)
    
    x = df_cluster_labels.copy()
    x = pd.get_dummies(x, columns=['cluster_label'], drop_first=True, dtype=int)
    x = x.sort_index()        
    x = pd.concat([x,df_variables], axis=1)    
    scaler = StandardScaler()
    delta_standardized = scaler.fit_transform(df_y[[column_delta_first_death]])
    x['delta_first_death_period'] = delta_standardized[:,0]    

    for variable in x.columns:
        print('\n*** Removed variable: ',variable)
        x_analysis = x.drop(columns=[variable])
        x_analysis = sm.add_constant(x_analysis)
        model = tunning_negative_binomial_model(x_analysis,y,list_offset)        
        filename = 'model_2_'+period+'_'+variable
        save_model(model,filename,'models/sensitivity_analysis/variable')
        summarize_results(model)
        
    # Model 3    
    print('\*** Model 3')
    print('===>Full model:')
    with open('models/model_3_'+period+'.pkl', 'rb') as file:
        model = pickle.load(file)
    summarize_results(model)
    
    x = df_cluster_probabilities.copy()
    x['delta_first_death_period'] = df_y[column_delta_first_death]
    scaler = StandardScaler()
    x_standardized = scaler.fit_transform(x)
    x = pd.DataFrame(x_standardized, index=x.index, columns=x.columns)        
    
    for variable in x.columns:
        print('\n*** Removed variable: ',variable)
        x_analysis = x.drop(columns=[variable])
        x_analysis = sm.add_constant(x_analysis)
        model = tunning_negative_binomial_model(x_analysis,y,list_offset)        
        filename = 'model_3_'+period+'_'+variable
        save_model(model,filename,'models/sensitivity_analysis/variable')
        summarize_results(model)
# Out:
# *** Period:  2020_1
# \*** Model 2
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5538
# Model Family:                            NegativeBinomial   Df Model:                           21
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9126.6
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4528.0
# Time:                                            16:18:24   Pearson chi2:                 5.78e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6433
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6246      0.041   -236.366      0.000      -9.704      -9.545
# cluster_label_Urbanized with informal settlements              0.0060      0.075      0.080      0.936      -0.141       0.152
# cluster_label_Semi-urbanized                                   0.3789      0.062      6.120      0.000       0.258       0.500
# cluster_label_Rural with high human development                0.1883      0.099      1.911      0.056      -0.005       0.381
# cluster_label_Rural with low human development                 0.3871      0.101      3.839      0.000       0.189       0.585
# percentage_population_age_range_60_more                       -0.0835      0.025     -3.342      0.001      -0.132      -0.035
# percentage_urban_population                                    0.0713      0.031      2.308      0.021       0.011       0.132
# demographic_density                                            0.0311      0.012      2.556      0.011       0.007       0.055
# percentage_male_population                                    -0.0134      0.021     -0.647      0.517      -0.054       0.027
# percentage_indigenous_population                               0.0244      0.013      1.844      0.065      -0.002       0.050
# per_capita_income                                             -0.3007      0.028    -10.912      0.000      -0.355      -0.247
# gini                                                           0.0281      0.022      1.251      0.211      -0.016       0.072
# percentage_estimated_households_in_informal_settlements        0.0858      0.012      6.988      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0146      0.014     -1.078      0.281      -0.041       0.012
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0022      0.016     -0.133      0.894      -0.034       0.030
# percentage_self_employed_workers                               0.1230      0.024      5.177      0.000       0.076       0.170
# unemployment_rate                                              0.1011      0.020      5.136      0.000       0.063       0.140
# percentage_workers_commerce                                   -0.0732      0.023     -3.165      0.002      -0.119      -0.028
# percentage_workers_services                                    0.0998      0.028      3.558      0.000       0.045       0.155
# percentage_workers_industry                                    0.0927      0.025      3.749      0.000       0.044       0.141
# expected_years_of_schooling_at_age_18                          0.0633      0.021      3.016      0.003       0.022       0.104
# delta_first_death_period                                       0.8744      0.017     50.923      0.000       0.841       0.908
# ==============================================================================================================================
# llf: -9126.62
# deviance:  4527.98
# pearson_chi2:  5781.98
# Estimated dispersion:  1.04
# aic:  18297.25
#
# *** Removed variable:  cluster_label_Urbanized with informal settlements
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9126.6
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4528.0
# Time:                                            16:18:44   Pearson chi2:                 5.78e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6433
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6239      0.040   -243.253      0.000      -9.701      -9.546
# cluster_label_Semi-urbanized                                   0.3775      0.060      6.344      0.000       0.261       0.494
# cluster_label_Rural with high human development                0.1885      0.099      1.913      0.056      -0.005       0.382
# cluster_label_Rural with low human development                 0.3852      0.098      3.946      0.000       0.194       0.576
# percentage_population_age_range_60_more                       -0.0840      0.024     -3.501      0.000      -0.131      -0.037
# percentage_urban_population                                    0.0712      0.031      2.307      0.021       0.011       0.132
# demographic_density                                            0.0313      0.012      2.606      0.009       0.008       0.055
# percentage_male_population                                    -0.0136      0.021     -0.663      0.507      -0.054       0.027
# percentage_indigenous_population                               0.0243      0.013      1.843      0.065      -0.002       0.050
# per_capita_income                                             -0.3007      0.027    -10.939      0.000      -0.355      -0.247
# gini                                                           0.0282      0.022      1.255      0.209      -0.016       0.072
# percentage_estimated_households_in_informal_settlements        0.0861      0.011      7.564      0.000       0.064       0.108
# demographic_density_in_informal_settlements                   -0.0142      0.013     -1.106      0.269      -0.039       0.011
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0021      0.016     -0.129      0.897      -0.034       0.030
# percentage_self_employed_workers                               0.1230      0.024      5.177      0.000       0.076       0.170
# unemployment_rate                                              0.1012      0.020      5.156      0.000       0.063       0.140
# percentage_workers_commerce                                   -0.0732      0.023     -3.164      0.002      -0.119      -0.028
# percentage_workers_services                                    0.1000      0.028      3.575      0.000       0.045       0.155
# percentage_workers_industry                                    0.0925      0.025      3.757      0.000       0.044       0.141
# expected_years_of_schooling_at_age_18                          0.0632      0.021      3.016      0.003       0.022       0.104
# delta_first_death_period                                       0.8745      0.017     51.116      0.000       0.841       0.908
# ==============================================================================================================================
# llf: -9126.63
# deviance:  4527.99
# pearson_chi2:  5782.74
# Estimated dispersion:  1.04
# aic:  18295.25
#
# *** Removed variable:  cluster_label_Semi-urbanized
# Selected alpha: 0.44
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9146.6
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4523.7
# Time:                                            16:19:17   Pearson chi2:                 5.80e+03
# No. Iterations:                                        15   Pseudo R-squ. (CS):             0.6362
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.4196      0.023   -410.645      0.000      -9.465      -9.375
# cluster_label_Urbanized with informal settlements             -0.1331      0.072     -1.836      0.066      -0.275       0.009
# cluster_label_Rural with high human development                0.0003      0.094      0.003      0.997      -0.184       0.185
# cluster_label_Rural with low human development                -0.0632      0.069     -0.916      0.359      -0.198       0.072
# percentage_population_age_range_60_more                       -0.1084      0.025     -4.370      0.000      -0.157      -0.060
# percentage_urban_population                                    0.0427      0.031      1.389      0.165      -0.018       0.103
# demographic_density                                            0.0447      0.012      3.677      0.000       0.021       0.069
# percentage_male_population                                    -0.0305      0.021     -1.450      0.147      -0.072       0.011
# percentage_indigenous_population                               0.0215      0.013      1.615      0.106      -0.005       0.048
# per_capita_income                                             -0.3555      0.026    -13.809      0.000      -0.406      -0.305
# gini                                                           0.0598      0.022      2.709      0.007       0.017       0.103
# percentage_estimated_households_in_informal_settlements        0.0790      0.012      6.407      0.000       0.055       0.103
# demographic_density_in_informal_settlements                   -0.0120      0.014     -0.880      0.379      -0.039       0.015
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0092      0.016      0.563      0.574      -0.023       0.041
# percentage_self_employed_workers                               0.1300      0.024      5.441      0.000       0.083       0.177
# unemployment_rate                                              0.1144      0.020      5.797      0.000       0.076       0.153
# percentage_workers_commerce                                   -0.0919      0.023     -3.954      0.000      -0.137      -0.046
# percentage_workers_services                                    0.0777      0.028      2.769      0.006       0.023       0.133
# percentage_workers_industry                                    0.0640      0.025      2.607      0.009       0.016       0.112
# expected_years_of_schooling_at_age_18                          0.0530      0.021      2.528      0.011       0.012       0.094
# delta_first_death_period                                       0.8915      0.017     51.852      0.000       0.858       0.925
# ==============================================================================================================================
# llf: -9146.62
# deviance:  4523.67
# pearson_chi2:  5797.43
# Estimated dispersion:  1.05
# aic:  18335.25
#
# *** Removed variable:  cluster_label_Rural with high human development
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9128.5
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4531.7
# Time:                                            16:19:42   Pearson chi2:                 5.79e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6430
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.5879      0.036   -268.432      0.000      -9.658      -9.518
# cluster_label_Urbanized with informal settlements              0.0099      0.075      0.133      0.895      -0.137       0.156
# cluster_label_Semi-urbanized                                   0.3443      0.059      5.832      0.000       0.229       0.460
# cluster_label_Rural with low human development                 0.3446      0.098      3.510      0.000       0.152       0.537
# percentage_population_age_range_60_more                       -0.0759      0.025     -3.075      0.002      -0.124      -0.028
# percentage_urban_population                                    0.0649      0.031      2.114      0.035       0.005       0.125
# demographic_density                                            0.0317      0.012      2.612      0.009       0.008       0.056
# percentage_male_population                                    -0.0117      0.021     -0.566      0.572      -0.052       0.029
# percentage_indigenous_population                               0.0261      0.013      1.980      0.048       0.000       0.052
# per_capita_income                                             -0.3004      0.028    -10.896      0.000      -0.354      -0.246
# gini                                                           0.0264      0.022      1.177      0.239      -0.018       0.070
# percentage_estimated_households_in_informal_settlements        0.0856      0.012      6.971      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0144      0.014     -1.069      0.285      -0.041       0.012
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0035      0.016     -0.213      0.831      -0.036       0.029
# percentage_self_employed_workers                               0.1353      0.023      5.907      0.000       0.090       0.180
# unemployment_rate                                              0.1036      0.020      5.275      0.000       0.065       0.142
# percentage_workers_commerce                                   -0.0784      0.023     -3.416      0.001      -0.123      -0.033
# percentage_workers_services                                    0.0925      0.028      3.325      0.001       0.038       0.147
# percentage_workers_industry                                    0.0875      0.025      3.564      0.000       0.039       0.136
# expected_years_of_schooling_at_age_18                          0.0662      0.021      3.159      0.002       0.025       0.107
# delta_first_death_period                                       0.8733      0.017     50.935      0.000       0.840       0.907
# ==============================================================================================================================
# llf: -9128.47
# deviance:  4531.69
# pearson_chi2:  5787.39
# Estimated dispersion:  1.04
# aic:  18298.95
#
# *** Removed variable:  cluster_label_Rural with low human development
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9134.4
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4543.5
# Time:                                            16:20:14   Pearson chi2:                 5.83e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6423
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.5228      0.030   -313.678      0.000      -9.582      -9.463
# cluster_label_Urbanized with informal settlements             -0.0688      0.072     -0.951      0.342      -0.211       0.073
# cluster_label_Semi-urbanized                                   0.2088      0.042      4.958      0.000       0.126       0.291
# cluster_label_Rural with high human development                0.1013      0.096      1.057      0.291      -0.087       0.289
# percentage_population_age_range_60_more                       -0.1080      0.024     -4.478      0.000      -0.155      -0.061
# percentage_urban_population                                    0.0619      0.031      2.011      0.044       0.002       0.122
# demographic_density                                            0.0385      0.012      3.193      0.001       0.015       0.062
# percentage_male_population                                    -0.0172      0.021     -0.827      0.408      -0.058       0.024
# percentage_indigenous_population                               0.0311      0.013      2.374      0.018       0.005       0.057
# per_capita_income                                             -0.3252      0.026    -12.272      0.000      -0.377      -0.273
# gini                                                           0.0531      0.022      2.457      0.014       0.011       0.095
# percentage_estimated_households_in_informal_settlements        0.0831      0.012      6.781      0.000       0.059       0.107
# demographic_density_in_informal_settlements                   -0.0125      0.013     -0.929      0.353      -0.039       0.014
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0148      0.016      0.936      0.349      -0.016       0.046
# percentage_self_employed_workers                               0.1361      0.024      5.790      0.000       0.090       0.182
# unemployment_rate                                              0.1061      0.020      5.391      0.000       0.068       0.145
# percentage_workers_commerce                                   -0.0924      0.023     -4.057      0.000      -0.137      -0.048
# percentage_workers_services                                    0.0910      0.028      3.253      0.001       0.036       0.146
# percentage_workers_industry                                    0.0835      0.025      3.390      0.001       0.035       0.132
# expected_years_of_schooling_at_age_18                          0.0537      0.021      2.582      0.010       0.013       0.094
# delta_first_death_period                                       0.8849      0.017     51.959      0.000       0.851       0.918
# ==============================================================================================================================
# llf: -9134.37
# deviance:  4543.47
# pearson_chi2:  5825.07
# Estimated dispersion:  1.05
# aic:  18310.73
#
# *** Removed variable:  percentage_population_age_range_60_more
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9132.1
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4539.0
# Time:                                            16:20:47   Pearson chi2:                 5.72e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6425
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6264      0.041   -236.848      0.000      -9.706      -9.547
# cluster_label_Urbanized with informal settlements              0.0722      0.072      1.005      0.315      -0.069       0.213
# cluster_label_Semi-urbanized                                   0.4100      0.061      6.714      0.000       0.290       0.530
# cluster_label_Rural with high human development                0.1366      0.097      1.406      0.160      -0.054       0.327
# cluster_label_Rural with low human development                 0.4671      0.097      4.800      0.000       0.276       0.658
# percentage_urban_population                                    0.0806      0.031      2.622      0.009       0.020       0.141
# demographic_density                                            0.0292      0.012      2.405      0.016       0.005       0.053
# percentage_male_population                                     0.0106      0.019      0.552      0.581      -0.027       0.048
# percentage_indigenous_population                               0.0283      0.013      2.145      0.032       0.002       0.054
# per_capita_income                                             -0.3166      0.027    -11.613      0.000      -0.370      -0.263
# gini                                                           0.0421      0.022      1.902      0.057      -0.001       0.085
# percentage_estimated_households_in_informal_settlements        0.0864      0.012      7.037      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0159      0.013     -1.181      0.238      -0.042       0.011
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0042      0.016     -0.254      0.800      -0.036       0.028
# percentage_self_employed_workers                               0.1235      0.024      5.205      0.000       0.077       0.170
# unemployment_rate                                              0.1039      0.020      5.292      0.000       0.065       0.142
# percentage_workers_commerce                                   -0.0624      0.023     -2.723      0.006      -0.107      -0.017
# percentage_workers_services                                    0.0968      0.028      3.451      0.001       0.042       0.152
# percentage_workers_industry                                    0.1099      0.024      4.542      0.000       0.062       0.157
# expected_years_of_schooling_at_age_18                          0.0539      0.021      2.598      0.009       0.013       0.095
# delta_first_death_period                                       0.8819      0.017     51.760      0.000       0.848       0.915
# ==============================================================================================================================
# llf: -9132.13
# deviance:  4538.99
# pearson_chi2:  5722.97
# Estimated dispersion:  1.03
# aic:  18306.25
#
# *** Removed variable:  percentage_urban_population
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9129.4
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4533.5
# Time:                                            16:21:07   Pearson chi2:                 5.83e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6429
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6119      0.040   -238.499      0.000      -9.691      -9.533
# cluster_label_Urbanized with informal settlements             -0.0014      0.075     -0.019      0.985      -0.148       0.145
# cluster_label_Semi-urbanized                                   0.3581      0.061      5.850      0.000       0.238       0.478
# cluster_label_Rural with high human development                0.1632      0.098      1.665      0.096      -0.029       0.355
# cluster_label_Rural with low human development                 0.3692      0.100      3.676      0.000       0.172       0.566
# percentage_population_age_range_60_more                       -0.0891      0.025     -3.576      0.000      -0.138      -0.040
# demographic_density                                            0.0303      0.012      2.495      0.013       0.007       0.054
# percentage_male_population                                    -0.0198      0.021     -0.961      0.337      -0.060       0.021
# percentage_indigenous_population                               0.0232      0.013      1.752      0.080      -0.003       0.049
# per_capita_income                                             -0.2909      0.027    -10.684      0.000      -0.344      -0.238
# gini                                                           0.0197      0.022      0.890      0.374      -0.024       0.063
# percentage_estimated_households_in_informal_settlements        0.0863      0.012      7.026      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0140      0.014     -1.040      0.298      -0.041       0.012
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0008      0.016     -0.049      0.961      -0.033       0.031
# percentage_self_employed_workers                               0.1189      0.024      5.019      0.000       0.072       0.165
# unemployment_rate                                              0.1055      0.020      5.395      0.000       0.067       0.144
# percentage_workers_commerce                                   -0.0537      0.022     -2.479      0.013      -0.096      -0.011
# percentage_workers_services                                    0.1190      0.027      4.485      0.000       0.067       0.171
# percentage_workers_industry                                    0.1072      0.024      4.485      0.000       0.060       0.154
# expected_years_of_schooling_at_age_18                          0.0641      0.021      3.058      0.002       0.023       0.105
# delta_first_death_period                                       0.8731      0.017     50.844      0.000       0.839       0.907
# ==============================================================================================================================
# llf: -9129.37
# deviance:  4533.47
# pearson_chi2:  5827.38
# Estimated dispersion:  1.05
# aic:  18300.73
#
# *** Removed variable:  demographic_density
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9130.2
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4535.2
# Time:                                            16:21:26   Pearson chi2:                 5.78e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6428
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6419      0.040   -238.840      0.000      -9.721      -9.563
# cluster_label_Urbanized with informal settlements              0.0448      0.074      0.608      0.543      -0.100       0.189
# cluster_label_Semi-urbanized                                   0.4083      0.061      6.665      0.000       0.288       0.528
# cluster_label_Rural with high human development                0.1956      0.099      1.985      0.047       0.002       0.389
# cluster_label_Rural with low human development                 0.4297      0.100      4.296      0.000       0.234       0.626
# percentage_population_age_range_60_more                       -0.0802      0.025     -3.214      0.001      -0.129      -0.031
# percentage_urban_population                                    0.0691      0.031      2.237      0.025       0.009       0.130
# percentage_male_population                                    -0.0186      0.021     -0.898      0.369      -0.059       0.022
# percentage_indigenous_population                               0.0247      0.013      1.864      0.062      -0.001       0.051
# per_capita_income                                             -0.2840      0.027    -10.449      0.000      -0.337      -0.231
# gini                                                           0.0236      0.022      1.054      0.292      -0.020       0.067
# percentage_estimated_households_in_informal_settlements        0.0851      0.012      6.930      0.000       0.061       0.109
# demographic_density_in_informal_settlements                   -0.0018      0.012     -0.147      0.883      -0.026       0.022
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0021      0.016     -0.126      0.900      -0.034       0.030
# percentage_self_employed_workers                               0.1223      0.024      5.143      0.000       0.076       0.169
# unemployment_rate                                              0.1019      0.020      5.175      0.000       0.063       0.140
# percentage_workers_commerce                                   -0.0740      0.023     -3.199      0.001      -0.119      -0.029
# percentage_workers_services                                    0.1016      0.028      3.626      0.000       0.047       0.157
# percentage_workers_industry                                    0.0913      0.025      3.691      0.000       0.043       0.140
# expected_years_of_schooling_at_age_18                          0.0635      0.021      3.024      0.002       0.022       0.105
# delta_first_death_period                                       0.8783      0.017     51.234      0.000       0.845       0.912
# ==============================================================================================================================
# llf: -9130.22
# deviance:  4535.18
# pearson_chi2:  5780.58
# Estimated dispersion:  1.04
# aic:  18302.44
#
# *** Removed variable:  percentage_male_population
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9126.8
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4528.4
# Time:                                            16:21:46   Pearson chi2:                 5.78e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6432
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6254      0.041   -236.481      0.000      -9.705      -9.546
# cluster_label_Urbanized with informal settlements              0.0126      0.074      0.169      0.865      -0.133       0.158
# cluster_label_Semi-urbanized                                   0.3836      0.062      6.233      0.000       0.263       0.504
# cluster_label_Rural with high human development                0.1856      0.098      1.885      0.059      -0.007       0.379
# cluster_label_Rural with low human development                 0.3898      0.101      3.868      0.000       0.192       0.587
# percentage_population_age_range_60_more                       -0.0779      0.024     -3.297      0.001      -0.124      -0.032
# percentage_urban_population                                    0.0737      0.031      2.407      0.016       0.014       0.134
# demographic_density                                            0.0318      0.012      2.622      0.009       0.008       0.056
# percentage_indigenous_population                               0.0242      0.013      1.824      0.068      -0.002       0.050
# per_capita_income                                             -0.3009      0.028    -10.924      0.000      -0.355      -0.247
# gini                                                           0.0290      0.022      1.299      0.194      -0.015       0.073
# percentage_estimated_households_in_informal_settlements        0.0858      0.012      6.985      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0145      0.014     -1.071      0.284      -0.041       0.012
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0023      0.016     -0.142      0.887      -0.035       0.030
# percentage_self_employed_workers                               0.1223      0.024      5.149      0.000       0.076       0.169
# unemployment_rate                                              0.1025      0.020      5.231      0.000       0.064       0.141
# percentage_workers_commerce                                   -0.0700      0.022     -3.113      0.002      -0.114      -0.026
# percentage_workers_services                                    0.0997      0.028      3.555      0.000       0.045       0.155
# percentage_workers_industry                                    0.0940      0.025      3.816      0.000       0.046       0.142
# expected_years_of_schooling_at_age_18                          0.0634      0.021      3.022      0.003       0.022       0.104
# delta_first_death_period                                       0.8759      0.017     51.375      0.000       0.843       0.909
# ==============================================================================================================================
# llf: -9126.83
# deviance:  4528.39
# pearson_chi2:  5779.29
# Estimated dispersion:  1.04
# aic:  18295.65
#
# *** Removed variable:  percentage_indigenous_population
# Selected alpha: 0.43
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9128.4
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4531.5
# Time:                                            16:22:06   Pearson chi2:                 5.81e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6430
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6271      0.041   -236.527      0.000      -9.707      -9.547
# cluster_label_Urbanized with informal settlements             -0.0029      0.075     -0.039      0.969      -0.149       0.143
# cluster_label_Semi-urbanized                                   0.3749      0.062      6.055      0.000       0.254       0.496
# cluster_label_Rural with high human development                0.2012      0.098      2.046      0.041       0.008       0.394
# cluster_label_Rural with low human development                 0.4115      0.100      4.120      0.000       0.216       0.607
# percentage_population_age_range_60_more                       -0.0876      0.025     -3.520      0.000      -0.136      -0.039
# percentage_urban_population                                    0.0690      0.031      2.234      0.025       0.008       0.129
# demographic_density                                            0.0312      0.012      2.566      0.010       0.007       0.055
# percentage_male_population                                    -0.0122      0.021     -0.589      0.556      -0.053       0.028
# per_capita_income                                             -0.3019      0.028    -10.958      0.000      -0.356      -0.248
# gini                                                           0.0360      0.022      1.626      0.104      -0.007       0.079
# percentage_estimated_households_in_informal_settlements        0.0864      0.012      7.044      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0150      0.014     -1.109      0.267      -0.041       0.011
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0058      0.016     -0.356      0.722      -0.038       0.026
# percentage_self_employed_workers                               0.1191      0.024      5.038      0.000       0.073       0.165
# unemployment_rate                                              0.0995      0.020      5.062      0.000       0.061       0.138
# percentage_workers_commerce                                   -0.0750      0.023     -3.245      0.001      -0.120      -0.030
# percentage_workers_services                                    0.1049      0.028      3.749      0.000       0.050       0.160
# percentage_workers_industry                                    0.0957      0.025      3.870      0.000       0.047       0.144
# expected_years_of_schooling_at_age_18                          0.0576      0.021      2.768      0.006       0.017       0.098
# delta_first_death_period                                       0.8742      0.017     50.896      0.000       0.841       0.908
# ==============================================================================================================================
# llf: -9128.36
# deviance:  4531.46
# pearson_chi2:  5809.47
# Estimated dispersion:  1.05
# aic:  18298.72
#
# *** Removed variable:  per_capita_income
# Selected alpha: 0.45
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9191.7
# Date:                                    Thu, 06 Jun 2024   Deviance:                       4570.2
# Time:                                            16:22:35   Pearson chi2:                 5.80e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6258
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.7396      0.040   -244.081      0.000      -9.818      -9.661
# cluster_label_Urbanized with informal settlements              0.0664      0.076      0.873      0.383      -0.083       0.215
# cluster_label_Semi-urbanized                                   0.6292      0.058     10.812      0.000       0.515       0.743
# cluster_label_Rural with high human development                0.1753      0.100      1.753      0.080      -0.021       0.371
# cluster_label_Rural with low human development                 0.6861      0.098      6.978      0.000       0.493       0.879
# percentage_population_age_range_60_more                       -0.1341      0.025     -5.373      0.000      -0.183      -0.085
# percentage_urban_population                                    0.0152      0.031      0.493      0.622      -0.045       0.076
# demographic_density                                            0.0030      0.012      0.244      0.807      -0.021       0.027
# percentage_male_population                                    -0.0188      0.021     -0.902      0.367      -0.060       0.022
# percentage_indigenous_population                               0.0277      0.013      2.063      0.039       0.001       0.054
# gini                                                          -0.0579      0.021     -2.695      0.007      -0.100      -0.016
# percentage_estimated_households_in_informal_settlements        0.0862      0.013      6.871      0.000       0.062       0.111
# demographic_density_in_informal_settlements                   -0.0174      0.014     -1.259      0.208      -0.045       0.010
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0086      0.017      0.522      0.602      -0.024       0.041
# percentage_self_employed_workers                               0.1009      0.024      4.213      0.000       0.054       0.148
# ...
# percentage_estimated_households_in_informal_settlements        0.0162      0.005      3.042      0.002       0.006       0.027
# demographic_density_in_informal_settlements                    0.0109      0.006      1.935      0.053      -0.000       0.022
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0179      0.006     -3.159      0.002      -0.029      -0.007
# percentage_self_employed_workers                               0.0188      0.007      2.622      0.009       0.005       0.033
# unemployment_rate                                             -0.0212      0.007     -3.100      0.002      -0.035      -0.008
# percentage_workers_commerce                                    0.0297      0.007      4.051      0.000       0.015       0.044
# percentage_workers_services                                    0.0560      0.009      6.432      0.000       0.039       0.073
# percentage_workers_industry                                    0.0376      0.008      4.978      0.000       0.023       0.052
# expected_years_of_schooling_at_age_18                          0.0344      0.006      5.349      0.000       0.022       0.047
# ==============================================================================================================================
# llf: -21658.26
# deviance:  5715.17
# pearson_chi2:  5655.8
# Estimated dispersion:  1.02
# aic:  43358.52
# \*** Model 3
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        16:59:15   Pearson chi2:                 5.64e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9520      0.005  -1184.849      0.000      -5.962      -5.942
# Semi-urbanized                         -0.1039      0.003    -31.752      0.000      -0.110      -0.097
# Rural with high human development       0.0609      0.005     12.217      0.000       0.051       0.071
# Urbanized with informal settlements     0.0203      0.004      4.937      0.000       0.012       0.028
# Rural with low human development       -0.1319      0.005    -28.984      0.000      -0.141      -0.123
# Urbanized                               0.1277      0.003     36.646      0.000       0.121       0.135
# delta_first_death_period                0.1734      0.007     24.989      0.000       0.160       0.187
# =======================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.19
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  Semi-urbanized
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        16:59:28   Pearson chi2:                 5.64e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9520      0.005  -1184.586      0.000      -5.962      -5.942
# Rural with high human development       0.1345      0.006     21.554      0.000       0.122       0.147
# Urbanized with informal settlements     0.0665      0.005     14.597      0.000       0.058       0.075
# Rural with low human development       -0.0813      0.005    -15.153      0.000      -0.092      -0.071
# Urbanized                               0.2219      0.005     43.303      0.000       0.212       0.232
# delta_first_death_period                0.1733      0.007     24.971      0.000       0.160       0.187
# =======================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.18
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  Rural with high human development
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        16:59:40   Pearson chi2:                 5.64e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9520      0.005  -1184.586      0.000      -5.962      -5.942
# Semi-urbanized                         -0.1898      0.009    -21.554      0.000      -0.207      -0.173
# Urbanized with informal settlements    -0.0180      0.006     -3.211      0.001      -0.029      -0.007
# Rural with low human development       -0.1737      0.006    -28.159      0.000      -0.186      -0.162
# Urbanized                               0.0498      0.009      5.753      0.000       0.033       0.067
# delta_first_death_period                0.1733      0.007     24.971      0.000       0.160       0.187
# =======================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.18
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  Urbanized with informal settlements
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        16:59:55   Pearson chi2:                 5.64e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -5.9520      0.005  -1184.586      0.000      -5.962      -5.942
# Semi-urbanized                       -0.1493      0.010    -14.597      0.000      -0.169      -0.129
# Rural with high human development     0.0287      0.009      3.211      0.001       0.011       0.046
# Rural with low human development     -0.1540      0.006    -23.948      0.000      -0.167      -0.141
# Urbanized                             0.0865      0.010      8.935      0.000       0.068       0.105
# delta_first_death_period              0.1733      0.007     24.971      0.000       0.160       0.187
# =====================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.18
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  Rural with low human development
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        17:00:05   Pearson chi2:                 5.64e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9520      0.005  -1184.586      0.000      -5.962      -5.942
# Semi-urbanized                          0.1672      0.011     15.153      0.000       0.146       0.189
# Rural with high human development       0.2530      0.009     28.159      0.000       0.235       0.271
# Urbanized with informal settlements     0.1410      0.006     23.948      0.000       0.129       0.153
# Urbanized                               0.3734      0.009     39.525      0.000       0.355       0.392
# delta_first_death_period                0.1733      0.007     24.971      0.000       0.160       0.187
# =======================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.18
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  Urbanized
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5554
# Model Family:        NegativeBinomial   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21590.
# Date:                Thu, 06 Jun 2024   Deviance:                       5579.6
# Time:                        17:00:15   Pearson chi2:                 5.64e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5087
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9520      0.005  -1184.586      0.000      -5.962      -5.942
# Semi-urbanized                         -0.2447      0.006    -43.303      0.000      -0.256      -0.234
# Rural with high human development      -0.0389      0.007     -5.753      0.000      -0.052      -0.026
# Urbanized with informal settlements    -0.0425      0.005     -8.935      0.000      -0.052      -0.033
# Rural with low human development       -0.2004      0.005    -39.525      0.000      -0.210      -0.190
# delta_first_death_period                0.1733      0.007     24.971      0.000       0.160       0.187
# =======================================================================================================
# llf: -21590.46
# deviance:  5579.56
# pearson_chi2:  5642.18
# Estimated dispersion:  1.02
# aic:  43192.92
#
# *** Removed variable:  delta_first_death_period
# Selected alpha: 0.09999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21898.
# Date:                Thu, 06 Jun 2024   Deviance:                       5785.8
# Time:                        17:01:28   Pearson chi2:                 5.65e+03
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.4241
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -5.9275      0.005  -1164.460      0.000      -5.937      -5.917
# Semi-urbanized                         -0.0993      0.003    -29.462      0.000      -0.106      -0.093
# Rural with high human development       0.0080      0.005      1.717      0.086      -0.001       0.017
# Urbanized with informal settlements     0.0533      0.004     13.039      0.000       0.045       0.061
# Rural with low human development       -0.1145      0.005    -24.625      0.000      -0.124      -0.105
# Urbanized                               0.1385      0.004     38.607      0.000       0.131       0.146
# =======================================================================================================
# llf: -21898.12
# deviance:  5785.83
# pearson_chi2:  5647.75
# Estimated dispersion:  1.02
# aic:  43806.24
