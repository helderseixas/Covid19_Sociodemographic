# %% [markdown]
# # Summarizing statistics

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv("data/output/df_base_without_missing_points.csv", index_col=0)

# %%
df_labeled_cluster = pd.read_csv('data/output/df_labeled_cluster.csv', index_col=0)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Analysis for national data

# %%
df_variables_analysis = df_variables[df_variables.columns[5:]]

# %%
statistics = []
for column in df_variables_analysis.columns:
    mean = df_variables_analysis[column].mean()
    std_dev = df_variables_analysis[column].std()
    median = df_variables_analysis[column].median()
    q1 = df_variables_analysis[column].quantile(0.25)
    q3 = df_variables_analysis[column].quantile(0.75)
    statistics.append({
        'Variable': column,
        'Mean (SD)': f"{mean:.2f} ({std_dev:.2f})",
        'Median (Q1, Q3)': f"{median:.2f} ({q1:.2f}, {q3:.2f})"
    })

# Create a new DataFrame with the calculated statistics
df_statistics = pd.DataFrame(statistics)

# %%
df_statistics = df_statistics.set_index('Variable')

# %%
len(df_statistics)
# Out:
# 31

# %%
df_statistics.index
# Out:
# Index(['percentage_population_age_range_0_19',
#        'percentage_population_age_range_20_39',
#        'percentage_population_age_range_40_59',
#        'percentage_population_age_range_60_more',
#        'percentage_urban_population', 'demographic_density',
#        'average_residents_per_households',
#        'percentage_population_in_households_more_2_residents_per_bedroom',
#        'percentage_male_population', 'percentage_indigenous_population',
#        'percentage_black_and_brown_population', 'life_expectancy_at_birth',
#        'per_capita_income', 'gini', 'per_capita_cash_transfer_program',
#        'percentage_estimated_households_in_informal_settlements',
#        'percentage_population_in_informal_settlements',
#        'demographic_density_in_informal_settlements',
#        'percentage_population_in_households_without_bathroom',
#        'percentage_hospitalizations_diseases_inadequate_sanitation',
#        'activity_rate', 'percentage_self_employed_workers',
#        'unemployment_rate', 'percentage_informal_workers',
#        'percentage_poor_population_spending_more_1_hour_to_work',
#        'percentage_workers_agriculture', 'percentage_workers_commerce',
#        'percentage_workers_services', 'percentage_workers_industry',
#        'illiteracy_rate', 'expected_years_of_schooling_at_age_18'],
#       dtype='object', name='Variable')

# %%
variable_labels = ['% population 0-19 years',
                   '% population 20-39 years',
                   '% population 40-59 years',
                   '% population 60+ years',
                   '% urban population',
                   'Population density (inhabitants/km²)',
                   'Average household size',
                   '% crowded households',
                   '% male population',
                   '% indigenous population',
                   '% black and brown population',
                   'Life expectancy (years)',
                   'Per capita income (BRL)',
                   'Gini coefficient',
                   'Social transfer per capita (BRL)',
                   '% informal settlement households',
                   '% population in informal settlements',
                   'Population density in informal settlement (inhabitants/ha)',
                   '% households without bathroom',
                   '% sanitation-related hospitalizations',
                   'Activity rate',
                   '% self-employed workers', 
                   'Unemployment rate',
                   '% informal workers',
                   '% poor population spending 1+ hour to work',
                   '% agriculture workers',
                   '% commerce workers', 
                   '% service workers', 
                   '% industry workers',
                   'Illiteracy rate',
                   'Expected years of schooling at age 18']

# %%
df_statistics.index = variable_labels

# %%
variable_labels
# Out:
# ['% population 0-19 years',
#  '% population 20-39 years',
#  '% population 40-59 years',
#  '% population 60+ years',
#  '% urban population',
#  'Population density (inhabitants/km²)',
#  'Average household size',
#  '% crowded households',
#  '% male population',
#  '% indigenous population',
#  '% black and brown population',
#  'Life expectancy (years)',
#  'Per capita income (BRL)',
#  'Gini coefficient',
#  'Social transfer per capita (BRL)',
#  '% informal settlement households',
#  '% population in informal settlements',
#  'Population density in informal settlement (inhabitants/ha)',
#  '% households without bathroom',
#  '% sanitation-related hospitalizations',
#  'Activity rate',
#  '% self-employed workers',
#  'Unemployment rate',
#  '% informal workers',
#  '% poor population spending 1+ hour to work',
#  '% agriculture workers',
#  '% commerce workers',
#  '% service workers',
#  '% industry workers',
#  'Illiteracy rate',
#  'Expected years of schooling at age 18']

# %%
df_statistics_sorted = df_statistics.loc[np.concatenate((variable_labels[:4], variable_labels[11:12], variable_labels[4:11], variable_labels[12:]))]

# %%
df_statistics_sorted
# Out:
#                                                           Mean (SD)  \
# % population 0-19 years                                27.55 (4.85)
# % population 20-39 years                               28.76 (2.96)
# % population 40-59 years                               26.28 (2.66)
# % population 60+ years                                 17.43 (4.59)
# Life expectancy (years)                                73.09 (2.68)
# % urban population                                    63.81 (22.04)
# Population density (inhabitants/km²)                116.04 (596.27)
# Average household size                                  2.84 (0.32)
# % crowded households                                  25.13 (12.99)
# % male population                                      50.00 (1.58)
# % indigenous population                                 1.20 (6.14)
# % black and brown population                          56.01 (22.66)
# Per capita income (BRL)                             493.34 (242.96)
# Gini coefficient                                        0.49 (0.07)
# Social transfer per capita (BRL)                    137.84 (110.38)
# % informal settlement households                        1.05 (4.51)
# % population in informal settlements                    0.52 (3.28)
# Population density in informal settlement (inha...     4.65 (26.60)
# % households without bathroom                           3.87 (7.97)
# % sanitation-related hospitalizations                   3.16 (4.65)
# Activity rate                                          55.37 (9.24)
# % self-employed workers                                24.69 (9.85)
# Unemployment rate                                       6.74 (3.83)
# % informal workers                                    56.51 (19.27)
# % poor population spending 1+ hour to work              1.39 (1.56)
# % agriculture workers                                 35.57 (18.25)
# % commerce workers                                     10.57 (4.41)
# % service workers                                      32.46 (8.89)
# % industry workers                                      9.61 (8.92)
# Illiteracy rate                                        11.81 (7.56)
# Expected years of schooling at age 18                   9.46 (1.10)
#
#                                                             Median (Q1, Q3)
# % population 0-19 years                                26.88 (24.27, 30.12)
# % population 20-39 years                               28.87 (26.96, 30.57)
# % population 40-59 years                               26.72 (24.88, 28.07)
# % population 60+ years                                 17.26 (14.33, 20.27)
# Life expectancy (years)                                73.47 (71.15, 75.16)
# % urban population                                     64.64 (47.07, 82.16)
# Population density (inhabitants/km²)                   24.27 (11.34, 53.50)
# Average household size                                    2.78 (2.65, 2.95)
# % crowded households                                   23.07 (15.41, 32.58)
# % male population                                      49.89 (49.07, 50.77)
# % indigenous population                                   0.07 (0.03, 0.19)
# % black and brown population                           60.79 (37.46, 75.30)
# Per capita income (BRL)                             467.38 (281.03, 650.37)
# Gini coefficient                                          0.49 (0.45, 0.54)
# Social transfer per capita (BRL)                      99.48 (47.28, 214.78)
# % informal settlement households                          0.00 (0.00, 0.00)
# % population in informal settlements                      0.00 (0.00, 0.00)
# Population density in informal settlement (inha...        0.00 (0.00, 0.00)
# % households without bathroom                             0.43 (0.06, 3.80)
# % sanitation-related hospitalizations                     1.47 (0.59, 3.71)
# Activity rate                                          55.63 (49.24, 61.22)
# % self-employed workers                                22.66 (18.08, 28.69)
# Unemployment rate                                         6.27 (4.16, 8.62)
# % informal workers                                     57.17 (40.26, 73.68)
# % poor population spending 1+ hour to work                0.90 (0.33, 1.91)
# % agriculture workers                                  36.47 (21.84, 49.30)
# % commerce workers                                      10.04 (7.25, 13.45)
# % service workers                                      31.89 (26.13, 38.00)
# % industry workers                                       6.53 (3.32, 13.29)
# Illiteracy rate                                          9.38 (5.57, 17.97)
# Expected years of schooling at age 18                    9.47 (8.75, 10.21)

# %%
df_statistics_sorted.to_csv('data/output/df_sociodemographic_statistics.csv', index=True)

# %% [markdown]
# ### Analysis by cluster

# %%
df_variables['cluster_label'] = df_labeled_cluster['cluster_label']

# %%
df_variables_analysis = df_variables[df_variables.columns[5:]]

# %%
labels_sorted = ['Urbanized','Urbanized with informal settlements','Semi-urbanized','Rural with high human development','Rural with low human development']

# %%
statistics = []
for column in df_variables_analysis.columns[:-1]:
    row = {'Variable': column}
    for cluster in labels_sorted:        
        df_variables_analysis_cluster = df_variables_analysis[df_variables_analysis['cluster_label'] == cluster]
        median = df_variables_analysis_cluster[column].median()
        q1 = df_variables_analysis_cluster[column].quantile(0.25)
        q3 = df_variables_analysis_cluster[column].quantile(0.75)
        row[cluster] = f"{median:.2f} ({q1:.2f}, {q3:.2f})"
    statistics.append(row)

# Create a new DataFrame with the calculated statistics
df_statistics = pd.DataFrame(statistics)

# %%
df_statistics = df_statistics.set_index('Variable')

# %%
df_statistics.index = variable_labels

# %%
df_statistics_sorted = df_statistics.loc[np.concatenate((variable_labels[:4], variable_labels[11:12], variable_labels[4:11], variable_labels[12:]))]

# %%
df_statistics_sorted
# Out:
#                                                                   Urbanized  \
# % population 0-19 years                                25.12 (23.46, 26.87)
# % population 20-39 years                               28.66 (27.06, 30.35)
# % population 40-59 years                               27.56 (26.68, 28.48)
# % population 60+ years                                 18.46 (16.19, 20.76)
# Life expectancy (years)                                75.06 (74.01, 76.00)
# % urban population                                     82.90 (74.07, 90.82)
# Population density (inhabitants/km²)                   32.92 (16.82, 74.94)
# Average household size                                    2.70 (2.61, 2.78)
# % crowded households                                   17.59 (13.56, 22.22)
# % male population                                      49.52 (48.86, 50.19)
# % indigenous population                                   0.07 (0.03, 0.13)
# % black and brown population                           44.19 (32.39, 57.27)
# Per capita income (BRL)                             646.90 (549.92, 770.12)
# Gini coefficient                                          0.46 (0.42, 0.50)
# Social transfer per capita (BRL)                       49.89 (30.34, 76.40)
# % informal settlement households                          0.00 (0.00, 0.00)
# % population in informal settlements                      0.00 (0.00, 0.00)
# Population density in informal settlement (inha...        0.00 (0.00, 0.00)
# % households without bathroom                             0.06 (0.02, 0.17)
# % sanitation-related hospitalizations                     0.91 (0.40, 2.00)
# Activity rate                                          59.30 (55.68, 62.66)
# % self-employed workers                                20.11 (16.98, 24.03)
# Unemployment rate                                         5.94 (4.35, 7.57)
# % informal workers                                     38.27 (29.97, 47.55)
# % poor population spending 1+ hour to work                0.43 (0.19, 0.90)
# % agriculture workers                                  20.95 (12.39, 29.96)
# % commerce workers                                      12.38 (9.80, 15.02)
# % service workers                                      36.03 (31.27, 41.58)
# % industry workers                                      13.86 (7.72, 21.44)
# Illiteracy rate                                           5.75 (4.12, 7.78)
# Expected years of schooling at age 18                    9.96 (9.34, 10.59)
#
#                                                    Urbanized with informal settlements  \
# % population 0-19 years                                           27.80 (25.82, 30.43)
# % population 20-39 years                                          31.74 (30.17, 33.37)
# % population 40-59 years                                          26.82 (25.09, 27.79)
# % population 60+ years                                            13.29 (11.09, 15.90)
# Life expectancy (years)                                           74.39 (73.23, 75.70)
# % urban population                                                96.07 (89.29, 99.72)
# Population density (inhabitants/km²)                          463.72 (158.88, 1819.34)
# Average household size                                               2.83 (2.71, 2.97)
# % crowded households                                              31.84 (26.42, 38.90)
# % male population                                                 48.22 (47.57, 48.89)
# % indigenous population                                              0.16 (0.09, 0.29)
# % black and brown population                                      68.47 (54.58, 74.26)
# Per capita income (BRL)                                        620.89 (466.69, 820.97)
# Gini coefficient                                                     0.51 (0.46, 0.56)
# Social transfer per capita (BRL)                                 72.54 (43.97, 119.79)
# % informal settlement households                                    9.54 (3.46, 18.15)
# % population in informal settlements                                4.81 (0.51, 12.29)
# Population density in informal settlement (inha...                49.01 (8.01, 109.21)
# % households without bathroom                                        0.22 (0.08, 0.78)
# % sanitation-related hospitalizations                                0.74 (0.43, 1.47)
# Activity rate                                                     57.66 (53.78, 61.45)
# % self-employed workers                                           19.57 (17.21, 22.22)
# Unemployment rate                                                   9.96 (8.06, 11.96)
# % informal workers                                                37.56 (28.78, 45.66)
# % poor population spending 1+ hour to work                           1.45 (0.69, 3.12)
# % agriculture workers                                                3.00 (1.13, 8.83)
# % commerce workers                                                16.43 (14.64, 19.01)
# % service workers                                                 47.94 (42.32, 52.12)
# % industry workers                                                 10.01 (6.56, 16.07)
# Illiteracy rate                                                      4.61 (3.26, 8.24)
# Expected years of schooling at age 18                               9.53 (9.05, 10.05)
#
#                                                              Semi-urbanized  \
# % population 0-19 years                                29.63 (27.61, 31.83)
# % population 20-39 years                               29.31 (27.95, 30.70)
# % population 40-59 years                               25.15 (23.91, 26.36)
# % population 60+ years                                 15.72 (13.74, 17.83)
# Life expectancy (years)                                70.98 (69.68, 72.29)
# % urban population                                     54.68 (41.15, 66.28)
# Population density (inhabitants/km²)                    20.59 (8.81, 46.51)
# Average household size                                    2.92 (2.80, 3.05)
# % crowded households                                   30.91 (25.67, 36.69)
# % male population                                      50.00 (49.20, 50.85)
# % indigenous population                                   0.09 (0.03, 0.31)
# % black and brown population                           74.65 (66.63, 80.73)
# Per capita income (BRL)                             277.95 (238.25, 334.07)
# Gini coefficient                                          0.52 (0.49, 0.55)
# Social transfer per capita (BRL)                    219.56 (164.17, 279.66)
# % informal settlement households                          0.00 (0.00, 0.00)
# % population in informal settlements                      0.00 (0.00, 0.00)
# Population density in informal settlement (inha...        0.00 (0.00, 0.00)
# % households without bathroom                             3.69 (1.60, 7.50)
# % sanitation-related hospitalizations                     2.42 (1.03, 5.47)
# Activity rate                                          49.41 (44.77, 53.94)
# % self-employed workers                                22.62 (18.05, 27.80)
# Unemployment rate                                        7.56 (5.54, 10.12)
# % informal workers                                     73.61 (65.30, 79.65)
# % poor population spending 1+ hour to work                1.62 (0.94, 2.53)
# % agriculture workers                                  43.84 (34.65, 52.21)
# % commerce workers                                       9.24 (6.85, 11.78)
# % service workers                                      30.41 (25.98, 35.12)
# % industry workers                                        3.64 (2.21, 6.03)
# Illiteracy rate                                        18.84 (14.31, 22.63)
# Expected years of schooling at age 18                     8.94 (8.41, 9.48)
#
#                                                    Rural with high human development  \
# % population 0-19 years                                         23.10 (21.13, 24.97)
# % population 20-39 years                                        25.55 (23.86, 27.18)
# % population 40-59 years                                        28.37 (27.38, 29.44)
# % population 60+ years                                          22.51 (20.26, 25.38)
# Life expectancy (years)                                         74.66 (73.57, 75.80)
# % urban population                                              47.14 (34.06, 58.35)
# Population density (inhabitants/km²)                            18.77 (11.27, 28.25)
# Average household size                                             2.62 (2.54, 2.71)
# % crowded households                                             11.81 (8.39, 16.03)
# % male population                                               50.65 (50.00, 51.32)
# % indigenous population                                            0.04 (0.00, 0.10)
# % black and brown population                                    26.58 (15.50, 42.79)
# Per capita income (BRL)                                      579.40 (479.55, 720.21)
# Gini coefficient                                                   0.46 (0.42, 0.49)
# Social transfer per capita (BRL)                                52.94 (27.94, 82.26)
# % informal settlement households                                   0.00 (0.00, 0.00)
# % population in informal settlements                               0.00 (0.00, 0.00)
# Population density in informal settlement (inha...                 0.00 (0.00, 0.00)
# % households without bathroom                                      0.12 (0.03, 0.37)
# % sanitation-related hospitalizations                              1.25 (0.40, 2.74)
# Activity rate                                                   63.81 (57.88, 70.85)
# % self-employed workers                                         35.04 (27.34, 44.68)
# Unemployment rate                                                  2.53 (1.38, 4.04)
# % informal workers                                              57.34 (47.41, 65.68)
# % poor population spending 1+ hour to work                         0.29 (0.07, 0.73)
# % agriculture workers                                           50.67 (43.23, 58.98)
# % commerce workers                                                 6.99 (5.40, 8.75)
# % service workers                                               24.60 (20.21, 29.29)
# % industry workers                                                6.37 (3.56, 10.40)
# Illiteracy rate                                                    6.87 (4.53, 9.08)
# Expected years of schooling at age 18                            10.21 (9.50, 10.89)
#
#                                                    Rural with low human development
# % population 0-19 years                                        38.23 (35.62, 41.96)
# % population 20-39 years                                       30.78 (29.43, 31.95)
# % population 40-59 years                                       20.15 (18.38, 21.85)
# % population 60+ years                                          10.25 (8.21, 12.52)
# Life expectancy (years)                                        70.09 (68.47, 71.41)
# % urban population                                             43.33 (31.62, 53.58)
# Population density (inhabitants/km²)                            10.62 (2.39, 20.67)
# Average household size                                            3.55 (3.34, 4.02)
# % crowded households                                           53.43 (45.55, 65.29)
# % male population                                              51.18 (50.38, 51.90)
# % indigenous population                                           0.16 (0.05, 8.04)
# % black and brown population                                   81.43 (74.59, 86.01)
# Per capita income (BRL)                                     195.93 (169.71, 229.36)
# Gini coefficient                                                  0.59 (0.55, 0.62)
# Social transfer per capita (BRL)                            307.56 (248.57, 383.70)
# % informal settlement households                                  0.00 (0.00, 0.00)
# % population in informal settlements                              0.00 (0.00, 0.00)
# Population density in informal settlement (inha...                0.00 (0.00, 0.00)
# % households without bathroom                                  25.66 (17.47, 36.38)
# % sanitation-related hospitalizations                            7.23 (3.01, 14.67)
# Activity rate                                                  47.17 (41.42, 51.34)
# % self-employed workers                                        28.24 (22.06, 36.31)
# Unemployment rate                                                 6.91 (4.82, 9.67)
# % informal workers                                             82.06 (76.52, 86.76)
# % poor population spending 1+ hour to work                        3.67 (2.37, 5.49)
# % agriculture workers                                          54.08 (44.38, 61.48)
# % commerce workers                                                7.38 (5.11, 9.67)
# % service workers                                              25.80 (21.95, 30.43)
# % industry workers                                                2.71 (1.66, 4.34)
# Illiteracy rate                                                20.02 (13.98, 24.63)
# Expected years of schooling at age 18                             8.14 (7.37, 8.83)

# %%
df_statistics_sorted.to_csv('data/output/df_sociodemographic_cluster_statistics.csv', index=True)
