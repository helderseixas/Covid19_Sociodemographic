# %% [markdown]
# # Summarizing statistics

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv("data/df_base_without_missing_points.csv", index_col=0)

# %%
df_deaths = pd.read_csv('data/df_mortality.csv', index_col=0)

# %%
df_labeled_cluster = pd.read_csv('data/df_labeled_cluster.csv', index_col=0)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Analysis for national data

# %%
df_variables_analysis = df_variables[df_variables.columns[7:]]

# %%
statistics = []
for column in df_variables_analysis.columns:
    mean = df_variables_analysis[column].mean()
    std_dev = df_variables_analysis[column].std()
    median = df_variables_analysis[column].median()
    q1 = df_variables_analysis[column].quantile(0.25)
    q3 = df_variables_analysis[column].quantile(0.75)
    statistics.append({
        'Variable': column,
        'Mean (SD)': f"{mean:.2f} ({std_dev:.2f})",
        'Median (Q1, Q3)': f"{median:.2f} ({q1:.2f}, {q3:.2f})"
    })

# Create a new DataFrame with the calculated statistics
df_statistics = pd.DataFrame(statistics)

# %%
df_statistics = df_statistics.set_index('Variable')

# %%
len(df_statistics)
# Out:
# 31

# %%
df_statistics.index
# Out:
# Index(['percentage_population_age_range_0_19',
#        'percentage_population_age_range_20_39',
#        'percentage_population_age_range_40_59',
#        'percentage_population_age_range_60_more',
#        'percentage_urban_population', 'average_residents_per_households',
#        'percentage_population_in_households_more_2_residents_per_bedroom',
#        'percentage_male_population', 'percentage_indigenous_population',
#        'percentage_black_and_brown_population', 'life_expectancy_at_birth',
#        'density_median_effectively_domiciled_area', 'per_capita_income',
#        'gini', 'per_capita_cash_transfer_program',
#        'percentage_estimated_households_in_informal_settlements',
#        'percentage_population_in_informal_settlements',
#        'demographic_density_in_informal_settlements',
#        'percentage_population_in_households_without_bathroom',
#        'percentage_hospitalizations_diseases_inadequate_sanitation',
#        'activity_rate', 'percentage_self_employed_workers',
#        'unemployment_rate', 'percentage_informal_workers',
#        'percentage_poor_population_spending_more_1_hour_to_work',
#        'percentage_workers_agriculture', 'percentage_workers_commerce',
#        'percentage_workers_services', 'percentage_workers_industry',
#        'illiteracy_rate', 'expected_years_of_schooling_at_age_18'],
#       dtype='object', name='Variable')

# %%
variable_labels = ['% population 0-19 years',
                   '% population 20-39 years',
                   '% population 40-59 years',
                   '% population 60+ years',
                   '% urban population',
                   'Average household size',
                   '% crowded households',
                   '% male population',
                   '% indigenous population',
                   '% black and brown population',
                   'Life expectancy (years)',
                   'Median density of effectively domiciled areas (inhabitants/km²)',
                   'Per capita income (BRL)',
                   'Gini coefficient',
                   'Social transfer per capita (BRL)',
                   '% informal settlement households',
                   '% population in informal settlements',
                   'Population density in informal settlement (inhabitants/ha)',
                   '% households without bathroom',
                   '% sanitation-related hospitalizations',
                   'Activity rate',
                   '% self-employed workers', 
                   'Unemployment rate',
                   '% informal workers',
                   '% poor population spending 1+ hour to work',
                   '% agriculture workers',
                   '% commerce workers', 
                   '% service workers', 
                   '% industry workers',
                   'Illiteracy rate',
                   'Expected years of schooling at age 18']

# %%
df_statistics.index = variable_labels

# %%
variable_labels
# Out:
# ['% population 0-19 years',
#  '% population 20-39 years',
#  '% population 40-59 years',
#  '% population 60+ years',
#  '% urban population',
#  'Average household size',
#  '% crowded households',
#  '% male population',
#  '% indigenous population',
#  '% black and brown population',
#  'Life expectancy (years)',
#  'Median density of effectively domiciled areas (inhabitants/km²)',
#  'Per capita income (BRL)',
#  'Gini coefficient',
#  'Social transfer per capita (BRL)',
#  '% informal settlement households',
#  '% population in informal settlements',
#  'Population density in informal settlement (inhabitants/ha)',
#  '% households without bathroom',
#  '% sanitation-related hospitalizations',
#  'Activity rate',
#  '% self-employed workers',
#  'Unemployment rate',
#  '% informal workers',
#  '% poor population spending 1+ hour to work',
#  '% agriculture workers',
#  '% commerce workers',
#  '% service workers',
#  '% industry workers',
#  'Illiteracy rate',
#  'Expected years of schooling at age 18']

# %%
df_statistics_sorted = df_statistics.loc[np.concatenate((variable_labels[:4], variable_labels[11:12], variable_labels[4:11], variable_labels[12:]))]

# %%
df_statistics_sorted
# Out:
#                                                             Mean (SD)  \
# % population 0-19 years                                  27.55 (4.85)
# % population 20-39 years                                 28.76 (2.96)
# % population 40-59 years                                 26.28 (2.66)
# % population 60+ years                                   17.43 (4.59)
# Median density of effectively domiciled areas (...  2880.61 (2043.02)
# % urban population                                      63.81 (22.04)
# Average household size                                    2.84 (0.32)
# % crowded households                                    25.13 (12.99)
# % male population                                        50.00 (1.58)
# % indigenous population                                   1.20 (6.14)
# % black and brown population                            56.01 (22.66)
# Life expectancy (years)                                  73.09 (2.68)
# Per capita income (BRL)                               493.34 (242.96)
# Gini coefficient                                          0.49 (0.07)
# Social transfer per capita (BRL)                      137.84 (110.38)
# % informal settlement households                          1.05 (4.51)
# % population in informal settlements                      0.52 (3.28)
# Population density in informal settlement (inha...       4.65 (26.60)
# % households without bathroom                             3.87 (7.97)
# % sanitation-related hospitalizations                     3.16 (4.65)
# Activity rate                                            55.37 (9.24)
# % self-employed workers                                  24.69 (9.85)
# Unemployment rate                                         6.74 (3.83)
# % informal workers                                      56.51 (19.27)
# % poor population spending 1+ hour to work                1.39 (1.56)
# % agriculture workers                                   35.57 (18.25)
# % commerce workers                                       10.57 (4.41)
# % service workers                                        32.46 (8.89)
# % industry workers                                        9.61 (8.92)
# Illiteracy rate                                          11.81 (7.56)
# Expected years of schooling at age 18                     9.46 (1.10)
#
#                                                                Median (Q1, Q3)
# % population 0-19 years                                   26.88 (24.27, 30.12)
# % population 20-39 years                                  28.87 (26.96, 30.57)
# % population 40-59 years                                  26.72 (24.88, 28.07)
# % population 60+ years                                    17.26 (14.33, 20.27)
# Median density of effectively domiciled areas (...  2447.15 (1585.06, 3610.04)
# % urban population                                        64.64 (47.07, 82.16)
# Average household size                                       2.78 (2.65, 2.95)
# % crowded households                                      23.07 (15.41, 32.58)
# % male population                                         49.89 (49.07, 50.77)
# % indigenous population                                      0.07 (0.03, 0.19)
# % black and brown population                              60.79 (37.46, 75.30)
# Life expectancy (years)                                   73.47 (71.15, 75.16)
# Per capita income (BRL)                                467.38 (281.03, 650.37)
# Gini coefficient                                             0.49 (0.45, 0.54)
# Social transfer per capita (BRL)                         99.48 (47.28, 214.78)
# % informal settlement households                             0.00 (0.00, 0.00)
# % population in informal settlements                         0.00 (0.00, 0.00)
# Population density in informal settlement (inha...           0.00 (0.00, 0.00)
# % households without bathroom                                0.43 (0.06, 3.80)
# % sanitation-related hospitalizations                        1.47 (0.59, 3.71)
# Activity rate                                             55.63 (49.24, 61.22)
# % self-employed workers                                   22.66 (18.08, 28.69)
# Unemployment rate                                            6.27 (4.16, 8.62)
# % informal workers                                        57.17 (40.26, 73.68)
# % poor population spending 1+ hour to work                   0.90 (0.33, 1.91)
# % agriculture workers                                     36.47 (21.84, 49.30)
# % commerce workers                                         10.04 (7.25, 13.45)
# % service workers                                         31.89 (26.13, 38.00)
# % industry workers                                          6.53 (3.32, 13.29)
# Illiteracy rate                                             9.38 (5.57, 17.97)
# Expected years of schooling at age 18                       9.47 (8.75, 10.21)

# %%
df_statistics_sorted.to_csv('data/df_sociodemographic_statistics.csv', index=True)

# %% [markdown]
# ### Analysis by cluster

# %%
df_variables['cluster_label'] = df_labeled_cluster['cluster_label']

# %%
df_variables_analysis = df_variables[df_variables.columns[7:]]

# %%
labels_sorted = ['Urbanized','Urbanized with informal settlements','Semi-urbanized','Rural with high human development','Rural with low human development']

# %%
statistics = []
for column in df_variables_analysis.columns[:-1]:
    row = {'Variable': column}
    for cluster in labels_sorted:        
        df_variables_analysis_cluster = df_variables_analysis[df_variables_analysis['cluster_label'] == cluster]
        median = df_variables_analysis_cluster[column].median()
        q1 = df_variables_analysis_cluster[column].quantile(0.25)
        q3 = df_variables_analysis_cluster[column].quantile(0.75)
        row[cluster] = f"{median:.2f} ({q1:.2f}, {q3:.2f})"
    statistics.append(row)

# Create a new DataFrame with the calculated statistics
df_statistics = pd.DataFrame(statistics)

# %%
df_statistics = df_statistics.set_index('Variable')

# %%
df_statistics
# Out:
#                                                                      Urbanized  \
# Variable
# percentage_population_age_range_0_19                      25.06 (23.44, 26.83)
# percentage_population_age_range_20_39                     28.63 (27.03, 30.30)
# percentage_population_age_range_40_59                     27.57 (26.69, 28.48)
# percentage_population_age_range_60_more                   18.56 (16.24, 20.80)
# percentage_urban_population                               82.69 (74.07, 90.72)
# average_residents_per_households                             2.69 (2.61, 2.78)
# percentage_population_in_households_more_2_resi...        17.50 (13.50, 22.00)
# percentage_male_population                                49.53 (48.89, 50.20)
# percentage_indigenous_population                             0.07 (0.03, 0.13)
# percentage_black_and_brown_population                     43.96 (32.51, 56.62)
# life_expectancy_at_birth                                  75.06 (74.01, 76.01)
# density_median_effectively_domiciled_area           2737.49 (1979.37, 3600.55)
# per_capita_income                                      645.37 (550.30, 768.66)
# gini                                                         0.46 (0.42, 0.50)
# per_capita_cash_transfer_program                          49.88 (30.71, 75.68)
# percentage_estimated_households_in_informal_set...           0.00 (0.00, 0.00)
# percentage_population_in_informal_settlements                0.00 (0.00, 0.00)
# demographic_density_in_informal_settlements                  0.00 (0.00, 0.00)
# percentage_population_in_households_without_bat...           0.06 (0.02, 0.17)
# percentage_hospitalizations_diseases_inadequate...           0.91 (0.40, 2.00)
# activity_rate                                             59.32 (55.74, 62.65)
# percentage_self_employed_workers                          20.11 (16.99, 24.03)
# unemployment_rate                                            5.91 (4.35, 7.51)
# percentage_informal_workers                               38.51 (30.19, 47.72)
# percentage_poor_population_spending_more_1_hour...           0.43 (0.19, 0.90)
# percentage_workers_agriculture                            21.33 (12.65, 30.17)
# percentage_workers_commerce                                12.34 (9.77, 14.97)
# percentage_workers_services                               36.00 (31.29, 41.36)
# percentage_workers_industry                                13.86 (7.72, 21.34)
# illiteracy_rate                                              5.78 (4.18, 7.78)
# expected_years_of_schooling_at_age_18                       9.99 (9.37, 10.60)
#
#                                                    Urbanized with informal settlements  \
# Variable
# percentage_population_age_range_0_19                              27.79 (25.70, 30.45)
# percentage_population_age_range_20_39                             31.59 (30.13, 33.23)
# percentage_population_age_range_40_59                             26.81 (24.99, 27.77)
# percentage_population_age_range_60_more                           13.59 (11.14, 15.99)
# percentage_urban_population                                       95.17 (88.42, 99.28)
# average_residents_per_households                                     2.83 (2.71, 2.96)
# percentage_population_in_households_more_2_resi...                31.27 (25.54, 38.49)
# percentage_male_population                                        48.16 (47.53, 48.86)
# percentage_indigenous_population                                     0.15 (0.09, 0.29)
# percentage_black_and_brown_population                             68.82 (55.23, 74.98)
# life_expectancy_at_birth                                          74.24 (72.97, 75.65)
# density_median_effectively_domiciled_area                   6650.86 (4888.58, 9000.86)
# per_capita_income                                              600.48 (449.73, 799.41)
# gini                                                                 0.52 (0.47, 0.56)
# per_capita_cash_transfer_program                                 78.57 (44.63, 121.40)
# percentage_estimated_households_in_informal_set...                  7.49 (2.81, 15.99)
# percentage_population_in_informal_settlements                       3.61 (0.00, 10.98)
# demographic_density_in_informal_settlements                        37.04 (0.00, 93.56)
# percentage_population_in_households_without_bat...                   0.25 (0.09, 0.85)
# percentage_hospitalizations_diseases_inadequate...                   0.79 (0.43, 1.48)
# activity_rate                                                     57.29 (53.53, 60.74)
# percentage_self_employed_workers                                  19.66 (17.12, 22.39)
# unemployment_rate                                                  10.07 (8.05, 12.16)
# percentage_informal_workers                                       37.83 (28.98, 46.61)
# percentage_poor_population_spending_more_1_hour...                   1.33 (0.67, 2.89)
# percentage_workers_agriculture                                      3.85 (1.27, 10.82)
# percentage_workers_commerce                                       16.45 (14.53, 19.27)
# percentage_workers_services                                       46.71 (41.64, 51.34)
# percentage_workers_industry                                        10.09 (6.58, 16.06)
# illiteracy_rate                                                      4.94 (3.35, 9.03)
# expected_years_of_schooling_at_age_18                                9.49 (9.02, 9.98)
#
#                                                                 Semi-urbanized  \
# Variable
# percentage_population_age_range_0_19                      29.60 (27.60, 31.81)
# percentage_population_age_range_20_39                     29.29 (27.94, 30.68)
# percentage_population_age_range_40_59                     25.16 (23.92, 26.39)
# percentage_population_age_range_60_more                   15.74 (13.77, 17.88)
# percentage_urban_population                               54.48 (41.14, 65.88)
# average_residents_per_households                             2.92 (2.80, 3.05)
# percentage_population_in_households_more_2_resi...        30.88 (25.62, 36.66)
# percentage_male_population                                50.01 (49.21, 50.86)
# percentage_indigenous_population                             0.09 (0.03, 0.31)
# percentage_black_and_brown_population                     74.63 (66.63, 80.69)
# life_expectancy_at_birth                                  70.99 (69.69, 72.32)
# density_median_effectively_domiciled_area           2477.85 (1713.30, 3641.04)
# per_capita_income                                      278.00 (238.35, 334.92)
# gini                                                         0.52 (0.49, 0.55)
# per_capita_cash_transfer_program                       219.46 (163.72, 280.04)
# percentage_estimated_households_in_informal_set...           0.00 (0.00, 0.00)
# percentage_population_in_informal_settlements                0.00 (0.00, 0.00)
# demographic_density_in_informal_settlements                  0.00 (0.00, 0.00)
# percentage_population_in_households_without_bat...           3.68 (1.59, 7.52)
# percentage_hospitalizations_diseases_inadequate...           2.42 (1.03, 5.50)
# activity_rate                                             49.45 (44.84, 53.97)
# percentage_self_employed_workers                          22.67 (18.12, 27.84)
# unemployment_rate                                           7.52 (5.52, 10.08)
# percentage_informal_workers                               73.62 (65.32, 79.66)
# percentage_poor_population_spending_more_1_hour...           1.61 (0.94, 2.52)
# percentage_workers_agriculture                            43.94 (34.84, 52.24)
# percentage_workers_commerce                                 9.20 (6.84, 11.75)
# percentage_workers_services                               30.38 (25.92, 35.08)
# percentage_workers_industry                                  3.63 (2.21, 5.96)
# illiteracy_rate                                           18.82 (14.28, 22.60)
# expected_years_of_schooling_at_age_18                        8.94 (8.41, 9.48)
#
#                                                    Rural with high human development  \
# Variable
# percentage_population_age_range_0_19                            23.05 (21.10, 24.95)
# percentage_population_age_range_20_39                           25.59 (23.88, 27.16)
# percentage_population_age_range_40_59                           28.38 (27.40, 29.44)
# percentage_population_age_range_60_more                         22.53 (20.23, 25.41)
# percentage_urban_population                                     47.36 (34.06, 58.47)
# average_residents_per_households                                   2.62 (2.54, 2.71)
# percentage_population_in_households_more_2_resi...               11.63 (8.24, 15.72)
# percentage_male_population                                      50.65 (49.99, 51.32)
# percentage_indigenous_population                                   0.03 (0.00, 0.10)
# percentage_black_and_brown_population                           25.56 (15.04, 41.89)
# life_expectancy_at_birth                                        74.70 (73.62, 75.81)
# density_median_effectively_domiciled_area                  1174.42 (732.94, 1706.26)
# per_capita_income                                            586.84 (480.01, 729.03)
# gini                                                               0.46 (0.42, 0.49)
# per_capita_cash_transfer_program                                52.05 (26.61, 82.12)
# percentage_estimated_households_in_informal_set...                 0.00 (0.00, 0.00)
# percentage_population_in_informal_settlements                      0.00 (0.00, 0.00)
# demographic_density_in_informal_settlements                        0.00 (0.00, 0.00)
# percentage_population_in_households_without_bat...                 0.12 (0.03, 0.38)
# percentage_hospitalizations_diseases_inadequate...                 1.25 (0.40, 2.73)
# activity_rate                                                   63.97 (58.04, 71.19)
# percentage_self_employed_workers                                35.04 (27.34, 44.71)
# unemployment_rate                                                  2.48 (1.36, 3.94)
# percentage_informal_workers                                     56.71 (46.87, 65.49)
# percentage_poor_population_spending_more_1_hour...                 0.27 (0.06, 0.70)
# percentage_workers_agriculture                                  50.44 (42.89, 58.87)
# percentage_workers_commerce                                        6.96 (5.40, 8.77)
# percentage_workers_services                                     24.51 (20.18, 29.37)
# percentage_workers_industry                                       6.48 (3.58, 10.54)
# illiteracy_rate                                                    6.72 (4.38, 9.02)
# expected_years_of_schooling_at_age_18                            10.21 (9.50, 10.88)
#
#                                                    Rural with low human development
# Variable
# percentage_population_age_range_0_19                           38.21 (35.66, 41.98)
# percentage_population_age_range_20_39                          30.77 (29.41, 31.96)
# percentage_population_age_range_40_59                          20.12 (18.37, 21.86)
# percentage_population_age_range_60_more                         10.26 (8.20, 12.53)
# percentage_urban_population                                    43.27 (31.43, 53.02)
# average_residents_per_households                                  3.55 (3.34, 4.02)
# percentage_population_in_households_more_2_resi...             53.40 (45.70, 65.30)
# percentage_male_population                                     51.18 (50.34, 51.91)
# percentage_indigenous_population                                  0.16 (0.05, 8.18)
# percentage_black_and_brown_population                          81.48 (74.50, 85.97)
# life_expectancy_at_birth                                       70.07 (68.44, 71.38)
# density_median_effectively_domiciled_area                2520.89 (1782.06, 3771.44)
# per_capita_income                                           195.22 (169.40, 228.03)
# gini                                                              0.59 (0.55, 0.62)
# per_capita_cash_transfer_program                            307.95 (249.75, 385.25)
# percentage_estimated_households_in_informal_set...                0.00 (0.00, 0.00)
# percentage_population_in_informal_settlements                     0.00 (0.00, 0.00)
# demographic_density_in_informal_settlements                       0.00 (0.00, 0.00)
# percentage_population_in_households_without_bat...             25.76 (17.55, 36.41)
# percentage_hospitalizations_diseases_inadequate...               7.29 (3.10, 14.68)
# activity_rate                                                  47.10 (41.09, 51.36)
# percentage_self_employed_workers                               28.04 (21.88, 36.34)
# unemployment_rate                                                 6.88 (4.81, 9.59)
# percentage_informal_workers                                    82.08 (76.54, 86.80)
# percentage_poor_population_spending_more_1_hour...                3.78 (2.38, 5.50)
# percentage_workers_agriculture                                 54.11 (44.70, 61.52)
# percentage_workers_commerce                                       7.37 (5.10, 9.57)
# percentage_workers_services                                    25.85 (21.91, 30.30)
# percentage_workers_industry                                       2.70 (1.64, 4.31)
# illiteracy_rate                                                20.14 (14.36, 24.78)
# expected_years_of_schooling_at_age_18                             8.11 (7.37, 8.82)

# %%
df_statistics.index = variable_labels

# %%
df_statistics_sorted = df_statistics.loc[np.concatenate((variable_labels[:4], variable_labels[11:12], variable_labels[4:11], variable_labels[12:]))]

# %%
df_statistics_sorted
# Out:
#                                                                      Urbanized  \
# % population 0-19 years                                   25.06 (23.44, 26.83)
# % population 20-39 years                                  28.63 (27.03, 30.30)
# % population 40-59 years                                  27.57 (26.69, 28.48)
# % population 60+ years                                    18.56 (16.24, 20.80)
# Median density of effectively domiciled areas (...  2737.49 (1979.37, 3600.55)
# % urban population                                        82.69 (74.07, 90.72)
# Average household size                                       2.69 (2.61, 2.78)
# % crowded households                                      17.50 (13.50, 22.00)
# % male population                                         49.53 (48.89, 50.20)
# % indigenous population                                      0.07 (0.03, 0.13)
# % black and brown population                              43.96 (32.51, 56.62)
# Life expectancy (years)                                   75.06 (74.01, 76.01)
# Per capita income (BRL)                                645.37 (550.30, 768.66)
# Gini coefficient                                             0.46 (0.42, 0.50)
# Social transfer per capita (BRL)                          49.88 (30.71, 75.68)
# % informal settlement households                             0.00 (0.00, 0.00)
# % population in informal settlements                         0.00 (0.00, 0.00)
# Population density in informal settlement (inha...           0.00 (0.00, 0.00)
# % households without bathroom                                0.06 (0.02, 0.17)
# % sanitation-related hospitalizations                        0.91 (0.40, 2.00)
# Activity rate                                             59.32 (55.74, 62.65)
# % self-employed workers                                   20.11 (16.99, 24.03)
# Unemployment rate                                            5.91 (4.35, 7.51)
# % informal workers                                        38.51 (30.19, 47.72)
# % poor population spending 1+ hour to work                   0.43 (0.19, 0.90)
# % agriculture workers                                     21.33 (12.65, 30.17)
# % commerce workers                                         12.34 (9.77, 14.97)
# % service workers                                         36.00 (31.29, 41.36)
# % industry workers                                         13.86 (7.72, 21.34)
# Illiteracy rate                                              5.78 (4.18, 7.78)
# Expected years of schooling at age 18                       9.99 (9.37, 10.60)
#
#                                                    Urbanized with informal settlements  \
# % population 0-19 years                                           27.79 (25.70, 30.45)
# % population 20-39 years                                          31.59 (30.13, 33.23)
# % population 40-59 years                                          26.81 (24.99, 27.77)
# % population 60+ years                                            13.59 (11.14, 15.99)
# Median density of effectively domiciled areas (...          6650.86 (4888.58, 9000.86)
# % urban population                                                95.17 (88.42, 99.28)
# Average household size                                               2.83 (2.71, 2.96)
# % crowded households                                              31.27 (25.54, 38.49)
# % male population                                                 48.16 (47.53, 48.86)
# % indigenous population                                              0.15 (0.09, 0.29)
# % black and brown population                                      68.82 (55.23, 74.98)
# Life expectancy (years)                                           74.24 (72.97, 75.65)
# Per capita income (BRL)                                        600.48 (449.73, 799.41)
# Gini coefficient                                                     0.52 (0.47, 0.56)
# Social transfer per capita (BRL)                                 78.57 (44.63, 121.40)
# % informal settlement households                                    7.49 (2.81, 15.99)
# % population in informal settlements                                3.61 (0.00, 10.98)
# Population density in informal settlement (inha...                 37.04 (0.00, 93.56)
# % households without bathroom                                        0.25 (0.09, 0.85)
# % sanitation-related hospitalizations                                0.79 (0.43, 1.48)
# Activity rate                                                     57.29 (53.53, 60.74)
# % self-employed workers                                           19.66 (17.12, 22.39)
# Unemployment rate                                                  10.07 (8.05, 12.16)
# % informal workers                                                37.83 (28.98, 46.61)
# % poor population spending 1+ hour to work                           1.33 (0.67, 2.89)
# % agriculture workers                                               3.85 (1.27, 10.82)
# % commerce workers                                                16.45 (14.53, 19.27)
# % service workers                                                 46.71 (41.64, 51.34)
# % industry workers                                                 10.09 (6.58, 16.06)
# Illiteracy rate                                                      4.94 (3.35, 9.03)
# Expected years of schooling at age 18                                9.49 (9.02, 9.98)
#
#                                                                 Semi-urbanized  \
# % population 0-19 years                                   29.60 (27.60, 31.81)
# % population 20-39 years                                  29.29 (27.94, 30.68)
# % population 40-59 years                                  25.16 (23.92, 26.39)
# % population 60+ years                                    15.74 (13.77, 17.88)
# Median density of effectively domiciled areas (...  2477.85 (1713.30, 3641.04)
# % urban population                                        54.48 (41.14, 65.88)
# Average household size                                       2.92 (2.80, 3.05)
# % crowded households                                      30.88 (25.62, 36.66)
# % male population                                         50.01 (49.21, 50.86)
# % indigenous population                                      0.09 (0.03, 0.31)
# % black and brown population                              74.63 (66.63, 80.69)
# Life expectancy (years)                                   70.99 (69.69, 72.32)
# Per capita income (BRL)                                278.00 (238.35, 334.92)
# Gini coefficient                                             0.52 (0.49, 0.55)
# Social transfer per capita (BRL)                       219.46 (163.72, 280.04)
# % informal settlement households                             0.00 (0.00, 0.00)
# % population in informal settlements                         0.00 (0.00, 0.00)
# Population density in informal settlement (inha...           0.00 (0.00, 0.00)
# % households without bathroom                                3.68 (1.59, 7.52)
# % sanitation-related hospitalizations                        2.42 (1.03, 5.50)
# Activity rate                                             49.45 (44.84, 53.97)
# % self-employed workers                                   22.67 (18.12, 27.84)
# Unemployment rate                                           7.52 (5.52, 10.08)
# % informal workers                                        73.62 (65.32, 79.66)
# % poor population spending 1+ hour to work                   1.61 (0.94, 2.52)
# % agriculture workers                                     43.94 (34.84, 52.24)
# % commerce workers                                          9.20 (6.84, 11.75)
# % service workers                                         30.38 (25.92, 35.08)
# % industry workers                                           3.63 (2.21, 5.96)
# Illiteracy rate                                           18.82 (14.28, 22.60)
# Expected years of schooling at age 18                        8.94 (8.41, 9.48)
#
#                                                    Rural with high human development  \
# % population 0-19 years                                         23.05 (21.10, 24.95)
# % population 20-39 years                                        25.59 (23.88, 27.16)
# % population 40-59 years                                        28.38 (27.40, 29.44)
# % population 60+ years                                          22.53 (20.23, 25.41)
# Median density of effectively domiciled areas (...         1174.42 (732.94, 1706.26)
# % urban population                                              47.36 (34.06, 58.47)
# Average household size                                             2.62 (2.54, 2.71)
# % crowded households                                             11.63 (8.24, 15.72)
# % male population                                               50.65 (49.99, 51.32)
# % indigenous population                                            0.03 (0.00, 0.10)
# % black and brown population                                    25.56 (15.04, 41.89)
# Life expectancy (years)                                         74.70 (73.62, 75.81)
# Per capita income (BRL)                                      586.84 (480.01, 729.03)
# Gini coefficient                                                   0.46 (0.42, 0.49)
# Social transfer per capita (BRL)                                52.05 (26.61, 82.12)
# % informal settlement households                                   0.00 (0.00, 0.00)
# % population in informal settlements                               0.00 (0.00, 0.00)
# Population density in informal settlement (inha...                 0.00 (0.00, 0.00)
# % households without bathroom                                      0.12 (0.03, 0.38)
# % sanitation-related hospitalizations                              1.25 (0.40, 2.73)
# Activity rate                                                   63.97 (58.04, 71.19)
# % self-employed workers                                         35.04 (27.34, 44.71)
# Unemployment rate                                                  2.48 (1.36, 3.94)
# % informal workers                                              56.71 (46.87, 65.49)
# % poor population spending 1+ hour to work                         0.27 (0.06, 0.70)
# % agriculture workers                                           50.44 (42.89, 58.87)
# % commerce workers                                                 6.96 (5.40, 8.77)
# % service workers                                               24.51 (20.18, 29.37)
# % industry workers                                                6.48 (3.58, 10.54)
# Illiteracy rate                                                    6.72 (4.38, 9.02)
# Expected years of schooling at age 18                            10.21 (9.50, 10.88)
#
#                                                    Rural with low human development
# % population 0-19 years                                        38.21 (35.66, 41.98)
# % population 20-39 years                                       30.77 (29.41, 31.96)
# % population 40-59 years                                       20.12 (18.37, 21.86)
# % population 60+ years                                          10.26 (8.20, 12.53)
# Median density of effectively domiciled areas (...       2520.89 (1782.06, 3771.44)
# % urban population                                             43.27 (31.43, 53.02)
# Average household size                                            3.55 (3.34, 4.02)
# % crowded households                                           53.40 (45.70, 65.30)
# % male population                                              51.18 (50.34, 51.91)
# % indigenous population                                           0.16 (0.05, 8.18)
# % black and brown population                                   81.48 (74.50, 85.97)
# Life expectancy (years)                                        70.07 (68.44, 71.38)
# Per capita income (BRL)                                     195.22 (169.40, 228.03)
# Gini coefficient                                                  0.59 (0.55, 0.62)
# Social transfer per capita (BRL)                            307.95 (249.75, 385.25)
# % informal settlement households                                  0.00 (0.00, 0.00)
# % population in informal settlements                              0.00 (0.00, 0.00)
# Population density in informal settlement (inha...                0.00 (0.00, 0.00)
# % households without bathroom                                  25.76 (17.55, 36.41)
# % sanitation-related hospitalizations                            7.29 (3.10, 14.68)
# Activity rate                                                  47.10 (41.09, 51.36)
# % self-employed workers                                        28.04 (21.88, 36.34)
# Unemployment rate                                                 6.88 (4.81, 9.59)
# % informal workers                                             82.08 (76.54, 86.80)
# % poor population spending 1+ hour to work                        3.78 (2.38, 5.50)
# % agriculture workers                                          54.11 (44.70, 61.52)
# % commerce workers                                                7.37 (5.10, 9.57)
# % service workers                                              25.85 (21.91, 30.30)
# % industry workers                                                2.70 (1.64, 4.31)
# Illiteracy rate                                                20.14 (14.36, 24.78)
# Expected years of schooling at age 18                             8.11 (7.37, 8.82)

# %%
df_statistics_sorted.to_csv('data/df_sociodemographic_cluster_statistics.csv', index=True)

# %%
df_statistics_deaths = df_deaths[['expected_deaths_1s_2020', 'expected_deaths_2020', 'expected_deaths_2021', 'expected_deaths_2022', 'expected_deaths_entire']].describe().T[['mean','std','50%','25%','75%']]

# %%
df_statistics_deaths
# Out:
#                                   mean            std       50%        25%  \
# expected_deaths_1s_2020   33373.610252   60057.841004    9017.5       0.00
# expected_deaths_2020     132683.882914  105810.515536  111182.5   56274.00
# expected_deaths_2021     342614.742806  188291.231765  316697.5  200719.00
# expected_deaths_2022      58296.018345   49911.924880   50921.0   24662.00
# expected_deaths_entire   533594.657014  254935.572058  502554.5  346675.75
#
#                                75%
# expected_deaths_1s_2020   39711.75
# expected_deaths_2020     186831.00
# expected_deaths_2021     454850.50
# expected_deaths_2022      81084.00
# expected_deaths_entire   691419.75

# %%
df_statistics_deaths.to_csv('data/df_statistics_deaths.csv', index=True)

# %%
df_deaths
# Out:
#       code_municipality_6  code_municipality_7  population        date  \
# 0                  110001              1100015       21495  2022-12-31
# 1                  110002              1100023       96833  2022-12-31
# 2                  110003              1100031        5363  2022-12-31
# 3                  110004              1100049       86895  2022-12-31
# 4                  110005              1100056       15890  2022-12-31
# ...                   ...                  ...         ...         ...
# 5565               522200              5222005       14956  2022-12-31
# 5566               522205              5222054        8768  2022-12-31
# 5567               522220              5222203        4215  2022-12-31
# 5568               522230              5222302        5815  2022-12-31
# 5569               530010              5300108     2817068  2022-12-31
#
#           region  deaths  new_deaths  deaths_accumulated_first_semester_2020  \
# 0          North    93.0         0.0                                     0.0
# 1          North   540.0         0.0                                    20.0
# 2          North    15.0         0.0                                     1.0
# 3          North   351.0         0.0                                     6.0
# 4          North    76.0         0.0                                     2.0
# ...          ...     ...         ...                                     ...
# 5565  Midwestern    47.0         0.0                                     0.0
# 5566  Midwestern    34.0         0.0                                     1.0
# 5567  Midwestern     7.0         0.0                                     0.0
# 5568  Midwestern    11.0         0.0                                     1.0
# 5569  Midwestern  9685.0         1.0                                   564.0
#
#       delta_first_death_2020-06-30  deaths_accumulated_2020  ...  \
# 0                              0.0                     16.0  ...
# 1                             44.0                    122.0  ...
# 2                              0.0                      4.0  ...
# 3                             85.0                     60.0  ...
# 4                             41.0                      8.0  ...
# ...                            ...                      ...  ...
# 5565                           0.0                      7.0  ...
# 5566                          20.0                      8.0  ...
# 5567                           0.0                      2.0  ...
# 5568                           2.0                      3.0  ...
# 5569                          99.0                   3098.0  ...
#
#       expected_deaths_entire  SMR_1s_2020  expected_deaths_1s_2020  \
# 0                   927589.0     0.000000                      0.0
# 1                  1457150.0    24.894038                  50555.0
# 2                   480554.0    13.141078                  26687.0
# 3                   930313.0     7.787050                  15814.0
# 4                  1042295.0    12.169543                  24714.0
# ...                      ...          ...                      ...
# 5565                651089.0     0.000000                      0.0
# 5566                973173.0    15.117139                  30700.0
# 5567                653860.0     0.000000                      0.0
# 5568                390316.0    21.654932                  43977.0
# 5569                811205.0    23.606865                  47941.0
#
#         SMR_2020  expected_deaths_2020    SMR_2021  expected_deaths_2021  \
# 0      81.397176              165302.0  326.452891              662963.0
# 1     160.620832              326190.0  504.112758             1023756.0
# 2      71.951180              146119.0  152.495985              309690.0
# 3      77.981293              158365.0  343.801163              698194.0
# 4      57.032977              115823.0  383.454846              778723.0
# ...          ...                   ...         ...                   ...
# 5565   46.779420               95000.0  217.209158              441110.0
# 5566  123.098813              249990.0  345.055836              700742.0
# 5567   96.067202              195094.0  116.817075              237233.0
# 5568   58.049813              117888.0  121.589069              246924.0
# 5569  130.072886              264153.0  238.490840              484329.0
#
#         SMR_2022  expected_deaths_2022  inverse_death_weighted_SMR
# 0      48.908622               99324.0                   84.999061
# 1      52.788852              107204.0                  123.047283
# 2      12.184808               24745.0                   39.547968
# 3      36.317572               73754.0                   77.494077
# 4      72.753324              147748.0                  102.197185
# ...          ...                   ...                         ...
# 5565   56.617871              114980.0                   71.476035
# 5566   11.050776               22442.0                   69.829597
# 5567  109.086653              221534.0                  107.162622
# 5568   12.558551               25504.0                   33.621383
# 5569   30.885743               62723.0                   73.635251
#
# [5560 rows x 87 columns]
