# %% [markdown]
# # Parameter sensitive analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import pickle

import util

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv('data/output/df_without_collinearity_standardized.csv', index_col=0)

# %%
df_political = pd.read_csv('data/output/df_political_without_missing_points.csv', index_col=0)[['percentual_votes_for_bolsonaro']]

# %%
df_vaccination_fully_vaccinated_people = pd.read_csv('data/output/df_vaccination.csv', index_col=0)[['% people fully vaccinated (1/2020)', '% people fully vaccinated (2020)', '% people fully vaccinated (2020-2021)', '% people fully vaccinated (2020-2022)']]

# %%
df_y = pd.read_csv('data/output/df_mortality.csv', index_col=0)

# %%
df_cluster_probabilities = pd.read_csv('data/df_standardized_pca_2spherical_5_probability.csv', index_col=0)
df_cluster_probabilities.columns = ['Semi-urbanized', 'Urbanized', 'Rural with high human development', 'Urbanized with informal settlements', 'Rural with low human development']

# %%
list_population =  df_y['population']
list_offset = np.log(list_population)

# %% [markdown]
# ## Parameter Sensitivity Analysis

# %%
list_columns_y = ['deaths_accumulated_first_semester_2020', 'deaths_accumulated_2020', 'deaths_2021', 'deaths_2022', 'deaths']
# list_columns_y = ['deaths']
list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
# list_periods = ['2020_2022']
list_delta_first_death_columns = ['delta_first_death_2020-06-30', 'delta_first_death_2020-12-31', 'delta_first_death_2021-12-31', 'delta_first_death_2022-12-31', 'delta_first_death_general_period']
# list_delta_first_death_columns = ['delta_first_death_general_period']

vaccination_columns = [0,1,2,3,3]

for sample in range(30):
    print('\n*** Sample: ', sample)
    for i in range(len(list_periods)):
        column_y = list_columns_y[i]
        period = list_periods[i]
        column_delta_first_death = list_delta_first_death_columns[i]
        list_offset_extra = np.log(df_y[column_delta_first_death]+1)
        print('\n*** Period: ', period)
            
        y = df_y[column_y]

        print('\*** Model 9')
        print('===>Full model:')
        with open('models/model_9_'+period+'.pkl', 'rb') as file:
            model = pickle.load(file)
        util.summarize_results(model)

        x = df_cluster_probabilities.drop(columns=['Urbanized']).copy()
        x = sm.add_constant(x)

        x_bootstrap = x.sample(frac=1, replace=True)
        y_bootstrap = y.loc[x_bootstrap.index]
        list_offset_bootstrap = list_offset.loc[x_bootstrap.index]
        list_offset_extra_bootstrap = list_offset_extra.loc[x_bootstrap.index]
        model = util.tunning_negative_binomial_model(x_bootstrap,y_bootstrap,list_offset_bootstrap, list_offset_extra_bootstrap)
        filename = 'model_9_'+period+'_sample_'+str(sample)
        util.save_model(model,filename,'models/sensitivity_analysis/parameter')
        util.summarize_results(model)

        # print('\*** Model 10')
        # print('===>Full model:')
        # with open('models/model_10_'+period+'.pkl', 'rb') as file:
        #     model = pickle.load(file)
        # summarize_results(model)
        #
        # x = df_variables.copy()
        # scaler = StandardScaler()
        # percentage_votes_for_bolsonaro_standardized = scaler.fit_transform(df_political)
        # x['percentage_votes_for_bolsonaro'] = percentage_votes_for_bolsonaro_standardized[:,0]
        # vaccination_column = vaccination_columns[i]
        # vaccination_standardized = scaler.fit_transform(df_vaccination_fully_vaccinated_people)
        # x['% people fully vaccinated'] = vaccination_standardized[:, vaccination_column]
        # x = sm.add_constant(x)
        #
        # x_bootstrap = x.sample(frac=1, replace=True)
        # y_bootstrap = y.loc[x_bootstrap.index]
        # list_offset_bootstrap = list_offset.loc[x_bootstrap.index]
        # list_offset_extra_bootstrap = list_offset_extra.loc[x_bootstrap.index]
        # model = tunning_negative_binomial_model(x_bootstrap,y_bootstrap,list_offset_bootstrap, list_offset_extra_bootstrap)
        # filename = 'model_10_'+period+'_sample_'+str(sample)
        # save_model(model,filename,'models/sensitivity_analysis/parameter')
        # summarize_results(model)
# Out:
# *** Sample:  0
#
# *** Period:  2020_1
# \*** Model 9
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8535.4
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3482.4
# Time:                                            22:39:26   Pearson chi2:                 5.38e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.08756
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.8334      0.033   -387.719      0.000     -12.898     -12.769
# Semi-urbanized                          0.9164      0.043     21.241      0.000       0.832       1.001
# Rural with high human development       1.1544      0.106     10.915      0.000       0.947       1.362
# Urbanized with informal settlements     0.8521      0.060     14.299      0.000       0.735       0.969
# Rural with low human development        1.0493      0.062     16.941      0.000       0.928       1.171
# =======================================================================================================
# llf: -8535.45
# deviance:  3482.39
# pearson_chi2:  5381.89
# Estimated dispersion:  0.97
# aic:  17080.9
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8494.2
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3488.0
# Time:                                            22:39:36   Pearson chi2:                 5.55e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.08840
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.8187      0.033   -389.473      0.000     -12.883     -12.754
# Semi-urbanized                          0.8908      0.043     20.911      0.000       0.807       0.974
# Rural with high human development       1.1635      0.111     10.502      0.000       0.946       1.381
# Urbanized with informal settlements     0.8803      0.059     14.925      0.000       0.765       0.996
# Rural with low human development        1.0756      0.060     17.795      0.000       0.957       1.194
# =======================================================================================================
# llf: -8494.18
# deviance:  3487.98
# pearson_chi2:  5548.54
# Estimated dispersion:  1.0
# aic:  16998.37
#
# *** Period:  2020
# \*** Model 9
# ===>Full model:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15677.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5508.7
# Time:                             22:39:36   Pearson chi2:                 7.49e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.03944
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5785      0.015   -842.768      0.000     -12.608     -12.549
# Semi-urbanized                         -0.0031      0.021     -0.150      0.881      -0.044       0.038
# Rural with high human development       0.3351      0.039      8.698      0.000       0.260       0.411
# Urbanized with informal settlements     0.2962      0.033      8.972      0.000       0.232       0.361
# Rural with low human development       -0.1867      0.036     -5.237      0.000      -0.257      -0.117
# =======================================================================================================
# llf: -15676.7
# deviance:  5508.73
# pearson_chi2:  7492.53
# Estimated dispersion:  1.35
# aic:  31363.4
# Selected alpha: 0.16
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15572.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5432.9
# Time:                             22:39:45   Pearson chi2:                 7.27e+03
# No. Iterations:                         10   Pseudo R-squ. (CS):            0.03922
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5885      0.015   -832.085      0.000     -12.618     -12.559
# Semi-urbanized                          0.0056      0.021      0.266      0.790      -0.035       0.047
# Rural with high human development       0.4184      0.039     10.744      0.000       0.342       0.495
# Urbanized with informal settlements     0.2864      0.035      8.301      0.000       0.219       0.354
# Rural with low human development       -0.1292      0.035     -3.713      0.000      -0.197      -0.061
# =======================================================================================================
# llf: -15571.51
# deviance:  5432.89
# pearson_chi2:  7273.95
# Estimated dispersion:  1.31
# aic:  31153.02
#
# *** Period:  2021
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19736.
# Date:                Thu, 02 Jan 2025   Deviance:                       5629.4
# Time:                        22:39:45   Pearson chi2:                 5.72e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4891
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7873      0.011  -1094.647      0.000     -11.808     -11.766
# Semi-urbanized                         -0.7333      0.016    -47.185      0.000      -0.764      -0.703
# Rural with high human development      -0.2450      0.024    -10.138      0.000      -0.292      -0.198
# Urbanized with informal settlements    -0.3844      0.026    -14.663      0.000      -0.436      -0.333
# Rural with low human development       -1.2163      0.030    -41.208      0.000      -1.274      -1.158
# =======================================================================================================
# llf: -19735.82
# deviance:  5629.4
# pearson_chi2:  5723.22
# Estimated dispersion:  1.03
# aic:  39481.63
# Selected alpha: 0.11
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19782.
# Date:                Thu, 02 Jan 2025   Deviance:                       5711.1
# Time:                        22:39:51   Pearson chi2:                 5.77e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.4832
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7854      0.011  -1088.343      0.000     -11.807     -11.764
# Semi-urbanized                         -0.7290      0.015    -47.185      0.000      -0.759      -0.699
# Rural with high human development      -0.2560      0.024    -10.558      0.000      -0.304      -0.208
# Urbanized with informal settlements    -0.3791      0.027    -14.132      0.000      -0.432      -0.327
# Rural with low human development       -1.1886      0.029    -40.931      0.000      -1.245      -1.132
# =======================================================================================================
# llf: -19781.95
# deviance:  5711.07
# pearson_chi2:  5770.99
# Estimated dispersion:  1.04
# aic:  39573.9
#
# *** Period:  2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11551.
# Date:                Thu, 02 Jan 2025   Deviance:                       4514.5
# Time:                        22:39:51   Pearson chi2:                 7.35e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2562
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5573      0.014   -958.175      0.000     -13.585     -13.530
# Semi-urbanized                         -0.5234      0.022    -23.386      0.000      -0.567      -0.480
# Rural with high human development       0.2826      0.038      7.345      0.000       0.207       0.358
# Urbanized with informal settlements    -0.5477      0.030    -18.426      0.000      -0.606      -0.489
# Rural with low human development       -1.2644      0.051    -24.959      0.000      -1.364      -1.165
# =======================================================================================================
# llf: -11551.39
# deviance:  4514.51
# pearson_chi2:  7346.81
# Estimated dispersion:  1.32
# aic:  23112.77
# Selected alpha: 0.09999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11351.
# Date:                Thu, 02 Jan 2025   Deviance:                       4429.0
# Time:                        22:40:00   Pearson chi2:                 7.58e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2505
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5558      0.014   -941.913      0.000     -13.584     -13.528
# Semi-urbanized                         -0.5423      0.023    -24.075      0.000      -0.586      -0.498
# Rural with high human development       0.2687      0.040      6.684      0.000       0.190       0.347
# Urbanized with informal settlements    -0.5310      0.031    -17.288      0.000      -0.591      -0.471
# Rural with low human development       -1.2613      0.051    -24.535      0.000      -1.362      -1.161
# =======================================================================================================
# llf: -11351.17
# deviance:  4428.96
# pearson_chi2:  7578.18
# Estimated dispersion:  1.36
# aic:  22712.35
#
# *** Period:  2020_2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21596.
# Date:                Thu, 02 Jan 2025   Deviance:                       5589.9
# Time:                        22:40:00   Pearson chi2:                 5.61e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4486
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4089      0.010  -1294.996      0.000     -12.428     -12.390
# Semi-urbanized                         -0.5913      0.014    -43.715      0.000      -0.618      -0.565
# Rural with high human development      -0.2028      0.021     -9.616      0.000      -0.244      -0.161
# Urbanized with informal settlements    -0.1846      0.023     -7.866      0.000      -0.231      -0.139
# Rural with low human development       -0.9665      0.025    -38.900      0.000      -1.015      -0.918
# =======================================================================================================
# llf: -21595.62
# deviance:  5589.89
# pearson_chi2:  5605.5
# Estimated dispersion:  1.01
# aic:  43201.24
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21492.
# Date:                Thu, 02 Jan 2025   Deviance:                       5618.8
# Time:                        22:40:06   Pearson chi2:                 5.66e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.4504
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4100      0.010  -1282.187      0.000     -12.429     -12.391
# Semi-urbanized                         -0.5944      0.014    -43.755      0.000      -0.621      -0.568
# Rural with high human development      -0.2232      0.021    -10.501      0.000      -0.265      -0.182
# Urbanized with informal settlements    -0.1713      0.024     -7.103      0.000      -0.219      -0.124
# Rural with low human development       -0.9595      0.024    -39.353      0.000      -1.007      -0.912
# =======================================================================================================
# llf: -21491.85
# deviance:  5618.78
# pearson_chi2:  5656.93
# Estimated dispersion:  1.02
# aic:  42993.7
#
# *** Sample:  1
#
# *** Period:  2020_1
# \*** Model 9
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8535.4
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3482.4
# Time:                                            22:40:06   Pearson chi2:                 5.38e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.08756
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.8334      0.033   -387.719      0.000     -12.898     -12.769
# Semi-urbanized                          0.9164      0.043     21.241      0.000       0.832       1.001
# Rural with high human development       1.1544      0.106     10.915      0.000       0.947       1.362
# Urbanized with informal settlements     0.8521      0.060     14.299      0.000       0.735       0.969
# Rural with low human development        1.0493      0.062     16.941      0.000       0.928       1.171
# =======================================================================================================
# llf: -8535.45
# deviance:  3482.39
# pearson_chi2:  5381.89
# Estimated dispersion:  0.97
# aic:  17080.9
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8346.6
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3407.6
# Time:                                            22:40:17   Pearson chi2:                 5.14e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.08127
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.8145      0.033   -386.694      0.000     -12.879     -12.750
# Semi-urbanized                          0.8850      0.043     20.455      0.000       0.800       0.970
# Rural with high human development       1.0679      0.103     10.409      0.000       0.867       1.269
# Urbanized with informal settlements     0.8233      0.060     13.803      0.000       0.706       0.940
# Rural with low human development        0.9945      0.062     15.954      0.000       0.872       1.117
# =======================================================================================================
# llf: -8346.6
# deviance:  3407.65
# pearson_chi2:  5136.2
# Estimated dispersion:  0.92
# aic:  16703.21
#
# *** Period:  2020
# \*** Model 9
# ===>Full model:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15677.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5508.7
# Time:                             22:40:17   Pearson chi2:                 7.49e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.03944
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5785      0.015   -842.768      0.000     -12.608     -12.549
# Semi-urbanized                         -0.0031      0.021     -0.150      0.881      -0.044       0.038
# Rural with high human development       0.3351      0.039      8.698      0.000       0.260       0.411
# Urbanized with informal settlements     0.2962      0.033      8.972      0.000       0.232       0.361
# Rural with low human development       -0.1867      0.036     -5.237      0.000      -0.257      -0.117
# =======================================================================================================
# llf: -15676.7
# deviance:  5508.73
# pearson_chi2:  7492.53
# Estimated dispersion:  1.35
# aic:  31363.4
# Selected alpha: 0.16
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15768.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5519.4
# Time:                             22:40:27   Pearson chi2:                 7.66e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.04424
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5561      0.015   -845.729      0.000     -12.585     -12.527
# Semi-urbanized                         -0.0181      0.021     -0.875      0.382      -0.059       0.022
# Rural with high human development       0.3448      0.039      8.918      0.000       0.269       0.421
# Urbanized with informal settlements     0.2868      0.033      8.612      0.000       0.222       0.352
# Rural with low human development       -0.2439      0.037     -6.597      0.000      -0.316      -0.171
# =======================================================================================================
# llf: -15768.46
# deviance:  5519.43
# pearson_chi2:  7657.24
# Estimated dispersion:  1.38
# aic:  31546.92
#
# *** Period:  2021
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19736.
# Date:                Thu, 02 Jan 2025   Deviance:                       5629.4
# Time:                        22:40:27   Pearson chi2:                 5.72e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4891
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7873      0.011  -1094.647      0.000     -11.808     -11.766
# Semi-urbanized                         -0.7333      0.016    -47.185      0.000      -0.764      -0.703
# Rural with high human development      -0.2450      0.024    -10.138      0.000      -0.292      -0.198
# Urbanized with informal settlements    -0.3844      0.026    -14.663      0.000      -0.436      -0.333
# Rural with low human development       -1.2163      0.030    -41.208      0.000      -1.274      -1.158
# =======================================================================================================
# llf: -19735.82
# deviance:  5629.4
# pearson_chi2:  5723.22
# Estimated dispersion:  1.03
# aic:  39481.63
# Selected alpha: 0.11
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19574.
# Date:                Thu, 02 Jan 2025   Deviance:                       5450.7
# Time:                        22:40:34   Pearson chi2:                 5.52e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4786
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7864      0.011  -1080.581      0.000     -11.808     -11.765
# Semi-urbanized                         -0.7389      0.016    -47.046      0.000      -0.770      -0.708
# Rural with high human development      -0.2402      0.024     -9.964      0.000      -0.287      -0.193
# Urbanized with informal settlements    -0.4110      0.026    -16.065      0.000      -0.461      -0.361
# Rural with low human development       -1.1660      0.029    -40.056      0.000      -1.223      -1.109
# =======================================================================================================
# llf: -19573.88
# deviance:  5450.74
# pearson_chi2:  5523.0
# Estimated dispersion:  0.99
# aic:  39157.75
#
# *** Period:  2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11551.
# Date:                Thu, 02 Jan 2025   Deviance:                       4514.5
# Time:                        22:40:34   Pearson chi2:                 7.35e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2562
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5573      0.014   -958.175      0.000     -13.585     -13.530
# Semi-urbanized                         -0.5234      0.022    -23.386      0.000      -0.567      -0.480
# Rural with high human development       0.2826      0.038      7.345      0.000       0.207       0.358
# Urbanized with informal settlements    -0.5477      0.030    -18.426      0.000      -0.606      -0.489
# Rural with low human development       -1.2644      0.051    -24.959      0.000      -1.364      -1.165
# =======================================================================================================
# llf: -11551.39
# deviance:  4514.51
# pearson_chi2:  7346.81
# Estimated dispersion:  1.32
# aic:  23112.77
# Selected alpha: 0.09999999999999999
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11453.
# Date:                Thu, 02 Jan 2025   Deviance:                       4455.9
# Time:                        22:40:43   Pearson chi2:                 7.62e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2659
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5418      0.014   -935.467      0.000     -13.570     -13.513
# Semi-urbanized                         -0.5284      0.023    -23.408      0.000      -0.573      -0.484
# Rural with high human development       0.2545      0.039      6.544      0.000       0.178       0.331
# Urbanized with informal settlements    -0.5523      0.029    -19.118      0.000      -0.609      -0.496
# Rural with low human development       -1.3430      0.050    -26.718      0.000      -1.442      -1.245
# =======================================================================================================
# llf: -11452.51
# deviance:  4455.93
# pearson_chi2:  7620.71
# Estimated dispersion:  1.37
# aic:  22915.03
#
# *** Period:  2020_2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21596.
# Date:                Thu, 02 Jan 2025   Deviance:                       5589.9
# Time:                        22:40:43   Pearson chi2:                 5.61e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4486
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4089      0.010  -1294.996      0.000     -12.428     -12.390
# Semi-urbanized                         -0.5913      0.014    -43.715      0.000      -0.618      -0.565
# Rural with high human development      -0.2028      0.021     -9.616      0.000      -0.244      -0.161
# Urbanized with informal settlements    -0.1846      0.023     -7.866      0.000      -0.231      -0.139
# Rural with low human development       -0.9665      0.025    -38.900      0.000      -1.015      -0.918
# =======================================================================================================
# llf: -21595.62
# deviance:  5589.89
# pearson_chi2:  5605.5
# Estimated dispersion:  1.01
# aic:  43201.24
# Selected alpha: 0.08
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21521.
# Date:                Thu, 02 Jan 2025   Deviance:                       5832.6
# Time:                        22:40:49   Pearson chi2:                 5.87e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.5014
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4108      0.009  -1330.409      0.000     -12.429     -12.393
# Semi-urbanized                         -0.5917      0.013    -45.523      0.000      -0.617      -0.566
# Rural with high human development      -0.1832      0.021     -8.883      0.000      -0.224      -0.143
# Urbanized with informal settlements    -0.1551      0.022     -7.018      0.000      -0.198      -0.112
# Rural with low human development       -1.0177      0.024    -42.796      0.000      -1.064      -0.971
# =======================================================================================================
# llf: -21520.61
# deviance:  5832.56
# pearson_chi2:  5869.12
# Estimated dispersion:  1.06
# aic:  43051.22
#
# *** Sample:  2
#
# *** Period:  2020_1
# \*** Model 9
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8535.4
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3482.4
# Time:                                            22:40:50   Pearson chi2:                 5.38e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.08756
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.8334      0.033   -387.719      0.000     -12.898     -12.769
# Semi-urbanized                          0.9164      0.043     21.241      0.000       0.832       1.001
# Rural with high human development       1.1544      0.106     10.915      0.000       0.947       1.362
# Urbanized with informal settlements     0.8521      0.060     14.299      0.000       0.735       0.969
# Rural with low human development        1.0493      0.062     16.941      0.000       0.928       1.171
# =======================================================================================================
# llf: -8535.45
# deviance:  3482.39
# pearson_chi2:  5381.89
# Estimated dispersion:  0.97
# aic:  17080.9
# Selected alpha: 0.38
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5555
# Model Family:                            NegativeBinomial   Df Model:                            4
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8469.1
# Date:                                    Thu, 02 Jan 2025   Deviance:                       3319.3
# Time:                                            22:41:02   Pearson chi2:                 4.61e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1003
# Covariance Type:                                nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.9041      0.032   -397.714      0.000     -12.968     -12.841
# Semi-urbanized                          0.9235      0.042     21.885      0.000       0.841       1.006
# Rural with high human development       1.1626      0.104     11.227      0.000       0.960       1.366
# Urbanized with informal settlements     0.9681      0.058     16.799      0.000       0.855       1.081
# Rural with low human development        1.1353      0.061     18.721      0.000       1.016       1.254
# =======================================================================================================
# llf: -8469.12
# deviance:  3319.29
# pearson_chi2:  4608.99
# Estimated dispersion:  0.83
# aic:  16948.24
#
# *** Period:  2020
# \*** Model 9
# ===>Full model:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15677.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5508.7
# Time:                             22:41:02   Pearson chi2:                 7.49e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.03944
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5785      0.015   -842.768      0.000     -12.608     -12.549
# Semi-urbanized                         -0.0031      0.021     -0.150      0.881      -0.044       0.038
# Rural with high human development       0.3351      0.039      8.698      0.000       0.260       0.411
# Urbanized with informal settlements     0.2962      0.033      8.972      0.000       0.232       0.361
# Rural with low human development       -0.1867      0.036     -5.237      0.000      -0.257      -0.117
# =======================================================================================================
# llf: -15676.7
# deviance:  5508.73
# pearson_chi2:  7492.53
# Estimated dispersion:  1.35
# aic:  31363.4
# Selected alpha: 0.16
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15606.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5425.9
# Time:                             22:41:11   Pearson chi2:                 7.27e+03
# No. Iterations:                         10   Pseudo R-squ. (CS):            0.03463
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5765      0.015   -827.449      0.000     -12.606     -12.547
# Semi-urbanized                         -0.0072      0.021     -0.346      0.729      -0.048       0.034
# Rural with high human development       0.2729      0.039      7.035      0.000       0.197       0.349
# Urbanized with informal settlements     0.3149      0.034      9.289      0.000       0.248       0.381
# ...
# Rural with low human development        1.0848      0.061     17.675      0.000       0.965       1.205
# =======================================================================================================
# llf: -8382.21
# deviance:  3432.47
# pearson_chi2:  5247.51
# Estimated dispersion:  0.94
# aic:  16774.41
#
# *** Period:  2020
# \*** Model 9
# ===>Full model:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15677.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5508.7
# Time:                             22:59:29   Pearson chi2:                 7.49e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.03944
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5785      0.015   -842.768      0.000     -12.608     -12.549
# Semi-urbanized                         -0.0031      0.021     -0.150      0.881      -0.044       0.038
# Rural with high human development       0.3351      0.039      8.698      0.000       0.260       0.411
# Urbanized with informal settlements     0.2962      0.033      8.972      0.000       0.232       0.361
# Rural with low human development       -0.1867      0.036     -5.237      0.000      -0.257      -0.117
# =======================================================================================================
# llf: -15676.7
# deviance:  5508.73
# pearson_chi2:  7492.53
# Estimated dispersion:  1.35
# aic:  31363.4
# Selected alpha: 0.16
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5555
# Model Family:             NegativeBinomial   Df Model:                            4
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -15583.
# Date:                     Thu, 02 Jan 2025   Deviance:                       5425.3
# Time:                             22:59:38   Pearson chi2:                 7.36e+03
# No. Iterations:                         11   Pseudo R-squ. (CS):            0.03401
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.5684      0.015   -851.557      0.000     -12.597     -12.540
# Semi-urbanized                         -0.0112      0.021     -0.541      0.588      -0.052       0.029
# Rural with high human development       0.3271      0.040      8.201      0.000       0.249       0.405
# Urbanized with informal settlements     0.2898      0.033      8.698      0.000       0.224       0.355
# Rural with low human development       -0.1389      0.034     -4.030      0.000      -0.207      -0.071
# =======================================================================================================
# llf: -15583.41
# deviance:  5425.27
# pearson_chi2:  7358.84
# Estimated dispersion:  1.32
# aic:  31176.82
#
# *** Period:  2021
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19736.
# Date:                Thu, 02 Jan 2025   Deviance:                       5629.4
# Time:                        22:59:38   Pearson chi2:                 5.72e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4891
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7873      0.011  -1094.647      0.000     -11.808     -11.766
# Semi-urbanized                         -0.7333      0.016    -47.185      0.000      -0.764      -0.703
# Rural with high human development      -0.2450      0.024    -10.138      0.000      -0.292      -0.198
# Urbanized with informal settlements    -0.3844      0.026    -14.663      0.000      -0.436      -0.333
# Rural with low human development       -1.2163      0.030    -41.208      0.000      -1.274      -1.158
# =======================================================================================================
# llf: -19735.82
# deviance:  5629.4
# pearson_chi2:  5723.22
# Estimated dispersion:  1.03
# aic:  39481.63
# Selected alpha: 0.11
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -19632.
# Date:                Thu, 02 Jan 2025   Deviance:                       5521.7
# Time:                        22:59:47   Pearson chi2:                 5.62e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4734
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -11.7727      0.011  -1096.504      0.000     -11.794     -11.752
# Semi-urbanized                         -0.7465      0.016    -48.015      0.000      -0.777      -0.716
# Rural with high human development      -0.2782      0.024    -11.672      0.000      -0.325      -0.232
# Urbanized with informal settlements    -0.4446      0.027    -16.502      0.000      -0.497      -0.392
# Rural with low human development       -1.1677      0.031    -37.785      0.000      -1.228      -1.107
# =======================================================================================================
# llf: -19632.25
# deviance:  5521.73
# pearson_chi2:  5617.22
# Estimated dispersion:  1.01
# aic:  39274.51
#
# *** Period:  2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11551.
# Date:                Thu, 02 Jan 2025   Deviance:                       4514.5
# Time:                        22:59:47   Pearson chi2:                 7.35e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2562
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5573      0.014   -958.175      0.000     -13.585     -13.530
# Semi-urbanized                         -0.5234      0.022    -23.386      0.000      -0.567      -0.480
# Rural with high human development       0.2826      0.038      7.345      0.000       0.207       0.358
# Urbanized with informal settlements    -0.5477      0.030    -18.426      0.000      -0.606      -0.489
# Rural with low human development       -1.2644      0.051    -24.959      0.000      -1.364      -1.165
# =======================================================================================================
# llf: -11551.39
# deviance:  4514.51
# pearson_chi2:  7346.81
# Estimated dispersion:  1.32
# aic:  23112.77
# Selected alpha: 0.11
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2022   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11577.
# Date:                Thu, 02 Jan 2025   Deviance:                       4448.0
# Time:                        22:59:55   Pearson chi2:                 7.96e+03
# No. Iterations:                     9   Pseudo R-squ. (CS):             0.2471
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -13.5715      0.014   -941.536      0.000     -13.600     -13.543
# Semi-urbanized                         -0.5104      0.023    -22.515      0.000      -0.555      -0.466
# Rural with high human development       0.3243      0.039      8.223      0.000       0.247       0.402
# Urbanized with informal settlements    -0.5250      0.031    -17.138      0.000      -0.585      -0.465
# Rural with low human development       -1.2621      0.052    -24.475      0.000      -1.363      -1.161
# =======================================================================================================
# llf: -11577.13
# deviance:  4448.0
# pearson_chi2:  7963.69
# Estimated dispersion:  1.43
# aic:  23164.27
#
# *** Period:  2020_2022
# \*** Model 9
# ===>Full model:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21596.
# Date:                Thu, 02 Jan 2025   Deviance:                       5589.9
# Time:                        22:59:55   Pearson chi2:                 5.61e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4486
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4089      0.010  -1294.996      0.000     -12.428     -12.390
# Semi-urbanized                         -0.5913      0.014    -43.715      0.000      -0.618      -0.565
# Rural with high human development      -0.2028      0.021     -9.616      0.000      -0.244      -0.161
# Urbanized with informal settlements    -0.1846      0.023     -7.866      0.000      -0.231      -0.139
# Rural with low human development       -0.9665      0.025    -38.900      0.000      -1.015      -0.918
# =======================================================================================================
# llf: -21595.62
# deviance:  5589.89
# pearson_chi2:  5605.5
# Estimated dispersion:  1.01
# aic:  43201.24
# Selected alpha: 0.09
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5555
# Model Family:        NegativeBinomial   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21726.
# Date:                Thu, 02 Jan 2025   Deviance:                       5641.9
# Time:                        23:00:03   Pearson chi2:                 5.67e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.4516
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                 -12.4151      0.009  -1310.696      0.000     -12.434     -12.397
# Semi-urbanized                         -0.6029      0.013    -44.757      0.000      -0.629      -0.576
# Rural with high human development      -0.2122      0.021    -10.137      0.000      -0.253      -0.171
# Urbanized with informal settlements    -0.1535      0.023     -6.597      0.000      -0.199      -0.108
# Rural with low human development       -0.9316      0.025    -37.419      0.000      -0.980      -0.883
# =======================================================================================================
# llf: -21726.38
# deviance:  5641.93
# pearson_chi2:  5670.57
# Estimated dispersion:  1.02
# aic:  43462.76

# %%
x_bootstrap
# Out:
#       const  Semi-urbanized  Rural with high human development  \
# 4617    1.0        0.000050                       4.105485e-05
# 3498    1.0        0.012843                       4.207260e-02
# 751     1.0        0.974890                       6.228059e-04
# 3015    1.0        0.643302                       3.061391e-01
# 3073    1.0        0.864527                       1.043631e-05
# ...     ...             ...                                ...
# 1883    1.0        0.216389                       1.314032e-02
# 27      1.0        0.838449                       2.665368e-02
# 259     1.0        0.616270                       9.919773e-05
# 262     1.0        0.973952                       4.159738e-04
# 1637    1.0        0.000082                       1.046724e-07
#
#       Urbanized with informal settlements  Rural with low human development
# 4617                             0.894154                          0.000003
# 3498                             0.026432                          0.000024
# 751                              0.002663                          0.021627
# 3015                             0.007692                          0.002113
# 3073                             0.009870                          0.125575
# ...                                   ...                               ...
# 1883                             0.116897                          0.000844
# 27                               0.024461                          0.002973
# 259                              0.343004                          0.030690
# 262                              0.004651                          0.020583
# 1637                             0.999364                          0.000072
#
# [5560 rows x 5 columns]

# %%
y_bootstrap
# Out:
# 4617    909.0
# 3498    134.0
# 751       6.0
# 3015     19.0
# 3073     16.0
#         ...
# 1883    204.0
# 27      103.0
# 259     115.0
# 262      44.0
# 1637     94.0
# Name: deaths, Length: 5560, dtype: float64

# %%
list_offset_bootstrap
# Out:
# 4617    12.140547
# 3498    10.279009
# 751      8.392083
# 3015     8.733272
# 3073     9.768755
#           ...
# 1883    11.163538
# 27      10.239674
# 259     11.198475
# 262     10.111477
# 1637    10.624663
# Name: population, Length: 5560, dtype: float64

# %%
df_variables.columns
# Out:
# Index(['percentage_population_age_range_60_more',
#        'percentage_urban_population', 'percentage_male_population',
#        'percentage_indigenous_population',
#        'density_median_effectively_domiciled_area', 'gini',
#        'percentage_estimated_households_in_informal_settlements',
#        'demographic_density_in_informal_settlements',
#        'percentage_hospitalizations_diseases_inadequate_sanitation',
#        'percentage_self_employed_workers', 'unemployment_rate',
#        'percentage_workers_commerce', 'percentage_workers_services',
#        'percentage_workers_industry', 'expected_years_of_schooling_at_age_18'],
#       dtype='object')
