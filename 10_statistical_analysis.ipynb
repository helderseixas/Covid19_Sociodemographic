# %% [markdown]
# # Statistical analysis

# %%
import pandas as pd
import numpy as np
import pickle

from util import calculate_95_ci

# %% [markdown]
# ## Loading data

# %%
df_deaths = pd.read_csv('data/output/df_mortality.csv', index_col=0)
df_labeled_cluster = pd.read_csv('data/output/df_labeled_cluster.csv', index_col=0)
df_deaths['cluster_label'] = df_labeled_cluster['cluster_label']

# %% [markdown]
# ## Mortality analysis by cluster

# %% [markdown]
# ### Mortality rate ratio using 'Urbanized' as the reference group

# %%
df_analysis_cluster = pd.DataFrame()
df_analysis_cluster['Sociodemographic cluster'] = ['Urbanized','Urbanized with informal settlements','Semi-urbanized','Rural with high human development','Rural with low human development','Residual degrees of freedom','Deviance','Pearson chi-squared','$R_{CU}^{2}$','AIC']
df_analysis_cluster = df_analysis_cluster.set_index('Sociodemographic cluster')

list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
list_death_rate_columns = ['Death rate (1/2020)', 'Death rate (2020)', 'Death rate (2021)', 'Death rate (2022)', 'Death rate (accumulated period)']
list_period_labels = ['2020 (first half)','2020','2021','2022','2020-2022']

for i in range(len(list_periods)):
    period = list_periods[i]
    period_label = list_period_labels[i]
    death_rate_column = list_death_rate_columns[i]
    
    mortality_rate = df_deaths.groupby('cluster_label')[death_rate_column].mean()
    ci_data = df_deaths.groupby('cluster_label')[death_rate_column].apply(calculate_95_ci)
    df_analysis_cluster[['Mean', 'Lower CI', 'Upper CI']] = pd.DataFrame(ci_data.tolist(), index=ci_data.index).round(2)
    df_analysis_cluster[period_label+' - Death rate (95% CI)'] = df_analysis_cluster['Mean'].astype(str) + '\n' + '('+df_analysis_cluster['Lower CI'].astype(str) + '-'+df_analysis_cluster['Upper CI'].astype(str) + ')'
    df_analysis_cluster = df_analysis_cluster.drop(columns=['Mean', 'Lower CI', 'Upper CI'])
    
    for model in [1,2]:
        model_label = str(model)
        model_file = str(model)
        with open('models/model_'+model_file+'_'+period+'.pkl', 'rb') as file:
            model = pickle.load(file)

        # Extract the coefficients and standard errors
        params = model.params[1:5]
        conf = model.conf_int()[1:5]
        conf.columns = ['Lower CI', 'Upper CI']
        
        # Calculate the rate ratios and their confidence intervals
        rate_ratios = np.exp(params)
        conf['Lower CI'] = np.exp(conf['Lower CI'])
        conf['Upper CI'] = np.exp(conf['Upper CI'])
        
        # Combine into a single DataFrame
        rate_ratio_df = pd.DataFrame({
            'Rate Ratio': rate_ratios,
            'Lower CI': conf['Lower CI'],
            'Upper CI': conf['Upper CI']
        }) 
        
        rate_ratio_df.index = rate_ratio_df.index.astype(str).str.replace('cluster_label_','')
        
        rate_ratio_df = rate_ratio_df.round(2)
        
        column_rate_ratio = period_label+' - RR (95% CI) - Model '+model_label
        df_analysis_cluster[column_rate_ratio] = rate_ratio_df['Rate Ratio'].astype(str) + '\n' + '('+rate_ratio_df['Lower CI'].astype(str) + '-'+rate_ratio_df['Upper CI'].astype(str) + ')'        
        
        df_analysis_cluster.loc['Residual degrees of freedom', column_rate_ratio] = model.df_resid
        df_analysis_cluster.loc['Deviance', column_rate_ratio] = round(model.deviance,2)
        df_analysis_cluster.loc['Pearson chi-squared', column_rate_ratio] = round(model.pearson_chi2,2)
        df_analysis_cluster.loc['$R_{CU}^{2}$', column_rate_ratio] = round(model.pseudo_rsquared('cs'),2)
        df_analysis_cluster.loc['AIC', column_rate_ratio] = round(model.aic,2)
        
        
        df_analysis_cluster[column_rate_ratio] = df_analysis_cluster[column_rate_ratio].fillna('1 [Reference]')

df_analysis_cluster.to_csv('data/output/df_analysis_cluster.csv', index=True)

# %%
df_analysis_cluster
# Out:
#                                     2020 (first half) - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                                 9.24\n(8.56-9.92)
# Urbanized with informal settlements                    47.19\n(42.74-51.64)
# Semi-urbanized                                         17.88\n(16.83-18.93)
# Rural with high human development                         4.58\n(3.72-5.43)
# Rural with low human development                        30.19\n(27.0-33.39)
# Residual degrees of freedom                                  nan\n(nan-nan)
# Deviance                                                     nan\n(nan-nan)
# Pearson chi-squared                                          nan\n(nan-nan)
# $R_{CU}^{2}$                                                 nan\n(nan-nan)
# AIC                                                          nan\n(nan-nan)
#
#                                     2020 (first half) - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                                       1 [Reference]
# Urbanized with informal settlements                         1.36\n(1.13-1.63)
# Semi-urbanized                                              1.87\n(1.63-2.14)
# Rural with high human development                           1.01\n(0.83-1.23)
# Rural with low human development                            2.65\n(2.12-3.32)
# Residual degrees of freedom                                              5539
# Deviance                                                               5337.7
# Pearson chi-squared                                                    6892.1
# $R_{CU}^{2}$                                                             0.33
# AIC                                                                  20391.05
#
#                                     2020 (first half) - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                                       1 [Reference]
# Urbanized with informal settlements                         1.01\n(0.87-1.16)
# Semi-urbanized                                              1.46\n(1.29-1.65)
# Rural with high human development                            1.21\n(1.0-1.46)
# Rural with low human development                            1.47\n(1.21-1.79)
# Residual degrees of freedom                                              5538
# Deviance                                                              4527.98
# Pearson chi-squared                                                   5781.98
# $R_{CU}^{2}$                                                             0.64
# AIC                                                                  18297.25
#
#                                     2020 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                  68.86\n(66.9-70.83)
# Urbanized with informal settlements      115.8\n(110.31-121.3)
# Semi-urbanized                            63.41\n(61.57-65.26)
# Rural with high human development         52.26\n(48.76-55.77)
# Rural with low human development           64.4\n(59.79-69.01)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2020 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            1.06\n(0.96-1.16)
# Semi-urbanized                                 1.23\n(1.15-1.31)
# Rural with high human development               1.08\n(1.0-1.18)
# Rural with low human development               1.29\n(1.15-1.44)
# Residual degrees of freedom                                 5539
# Deviance                                                  6233.4
# Pearson chi-squared                                      5856.69
# $R_{CU}^{2}$                                                 0.2
# AIC                                                     32933.61
#
#                                     2020 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            1.04\n(0.96-1.13)
# Semi-urbanized                                  1.13\n(1.07-1.2)
# Rural with high human development              1.22\n(1.13-1.32)
# Rural with low human development               1.06\n(0.95-1.17)
# Residual degrees of freedom                                 5538
# Deviance                                                 5658.02
# Pearson chi-squared                                      5790.51
# $R_{CU}^{2}$                                                0.44
# AIC                                                     31365.19
#
#                                     2021 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                              243.29\n(239.23-247.35)
# Urbanized with informal settlements    192.68\n(184.22-201.14)
# Semi-urbanized                         123.63\n(120.71-126.54)
# Rural with high human development      193.64\n(186.67-200.62)
# Rural with low human development          83.94\n(78.38-89.51)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2021 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.79\n(0.73-0.84)
# Semi-urbanized                                  0.73\n(0.7-0.76)
# Rural with high human development                0.95\n(0.9-1.0)
# Rural with low human development               0.58\n(0.54-0.63)
# Residual degrees of freedom                                 5539
# Deviance                                                 5867.71
# Pearson chi-squared                                      5831.72
# $R_{CU}^{2}$                                                0.53
# AIC                                                     40064.49
#
#                                     2021 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.81\n(0.76-0.86)
# Semi-urbanized                                 0.76\n(0.72-0.79)
# Rural with high human development              0.98\n(0.93-1.03)
# Rural with low human development               0.61\n(0.56-0.66)
# Residual degrees of freedom                                 5538
# Deviance                                                 5789.12
# Pearson chi-squared                                      5930.56
# $R_{CU}^{2}$                                                0.63
# AIC                                                     39342.44
#
#                                     2022 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                 41.82\n(40.58-43.07)
# Urbanized with informal settlements        27.89\n(26.19-29.6)
# Semi-urbanized                            22.93\n(22.13-23.74)
# Rural with high human development         37.97\n(35.51-40.43)
# Rural with low human development            11.35\n(10.2-12.5)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2022 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements             0.9\n(0.83-0.97)
# Semi-urbanized                                 0.84\n(0.79-0.89)
# Rural with high human development              0.93\n(0.86-1.01)
# Rural with low human development               0.64\n(0.57-0.73)
# Residual degrees of freedom                                 5539
# Deviance                                                 6275.74
# Pearson chi-squared                                      5739.46
# $R_{CU}^{2}$                                                0.35
# AIC                                                      24906.0
#
#                                     2022 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.95\n(0.89-1.01)
# Semi-urbanized                                 0.88\n(0.83-0.93)
# Rural with high human development              1.03\n(0.95-1.11)
# Rural with low human development               0.74\n(0.66-0.83)
# Residual degrees of freedom                                 5538
# Deviance                                                 4681.19
# Pearson chi-squared                                      5094.09
# $R_{CU}^{2}$                                                0.62
# AIC                                                     22587.67
#
#                                     2020-2022 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                    353.97\n(348.7-359.25)
# Urbanized with informal settlements         336.37\n(323.17-349.58)
# Semi-urbanized                              209.97\n(206.09-213.85)
# Rural with high human development           283.88\n(275.03-292.72)
# Rural with low human development            159.69\n(150.64-168.75)
# Residual degrees of freedom                          nan\n(nan-nan)
# Deviance                                             nan\n(nan-nan)
# Pearson chi-squared                                  nan\n(nan-nan)
# $R_{CU}^{2}$                                         nan\n(nan-nan)
# AIC                                                  nan\n(nan-nan)
#
#                                     2020-2022 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                               1 [Reference]
# Urbanized with informal settlements                   0.85\n(0.8-0.9)
# Semi-urbanized                                      0.84\n(0.81-0.87)
# Rural with high human development                    1.0\n(0.95-1.04)
# Rural with low human development                    0.74\n(0.69-0.79)
# Residual degrees of freedom                                      5539
# Deviance                                                      5715.17
# Pearson chi-squared                                            5655.8
# $R_{CU}^{2}$                                                      0.5
# AIC                                                          43358.52
#
#                                     2020-2022 - RR (95% CI) - Model 2
# Sociodemographic cluster
# Urbanized                                               1 [Reference]
# Urbanized with informal settlements                   0.85\n(0.8-0.9)
# Semi-urbanized                                      0.82\n(0.79-0.85)
# Rural with high human development                   1.03\n(0.99-1.08)
# Rural with low human development                     0.7\n(0.65-0.74)
# Residual degrees of freedom                                      5538
# Deviance                                                      5637.35
# Pearson chi-squared                                           5728.63
# $R_{CU}^{2}$                                                     0.57
# AIC                                                          42839.08

# %% [markdown]
# ### Rate ratio for the cluster probabilities

# %% [markdown]
# #### Model 3

# %%
df_analysis_cluster_probabilities = pd.DataFrame()
df_analysis_cluster_probabilities['Variable'] = ['Urbanized (probability)','Urbanized with informal settlements (probability)','Semi-urbanized (probability)','Rural with high human development (probability)','Rural with low human development (probability)','Days since first death','Residual degrees of freedom','Deviance','Pearson chi-squared','$R_{CU}^{2}$','AIC']
df_analysis_cluster_probabilities = df_analysis_cluster_probabilities.set_index('Variable')

for i in range(len(list_periods)):
    period = list_periods[i]
    period_label = list_period_labels[i]
    
    with open('models/model_3_'+period+'.pkl', 'rb') as file:
        model = pickle.load(file)

    # Extract the coefficients and standard errors
    params = model.params[1:]
    conf = model.conf_int()[1:]
    conf.columns = ['Lower CI', 'Upper CI']
    
    # Calculate the rate ratios and their confidence intervals
    rate_ratios = np.exp(params)
    conf['Lower CI'] = np.exp(conf['Lower CI'])
    conf['Upper CI'] = np.exp(conf['Upper CI'])
    
    # Combine into a single DataFrame
    rate_ratio_df = pd.DataFrame({
        'Rate Ratio': rate_ratios,
        'Lower CI': conf['Lower CI'],
        'Upper CI': conf['Upper CI']
    })
    
    rate_ratio_df = rate_ratio_df.round(2)
    
    rate_ratio_df.index = rate_ratio_df.index.astype(str) + ' (probability)'
    index_list = rate_ratio_df.index.tolist()
    index_list[-1] = 'Days since first death'
    rate_ratio_df.index = index_list
    
    df_analysis_cluster_probabilities[period_label] = rate_ratio_df['Rate Ratio'].astype(str) + '\n' + '('+rate_ratio_df['Lower CI'].astype(str) + '-'+rate_ratio_df['Upper CI'].astype(str) + ')'
    
    df_analysis_cluster_probabilities.loc['Residual degrees of freedom', period_label] = model.df_resid
    df_analysis_cluster_probabilities.loc['Deviance', period_label] = round(model.deviance,2)
    df_analysis_cluster_probabilities.loc['Pearson chi-squared', period_label] = round(model.pearson_chi2,2)    
    df_analysis_cluster_probabilities.loc['$R_{CU}^{2}$', period_label] = round(model.pseudo_rsquared('cs'),2)
    df_analysis_cluster_probabilities.loc['AIC', period_label] = round(model.aic,2)
    
df_analysis_cluster_probabilities.to_csv('data/output/df_analysis_cluster_probabilities.csv', index=True)

# %%
df_analysis_cluster_probabilities
# Out:
#                                                    2020 (first half)  \
# Variable
# Urbanized (probability)                             0.82\n(0.8-0.84)
# Urbanized with informal settlements (probability)   1.02\n(1.0-1.04)
# Semi-urbanized (probability)                       1.16\n(1.14-1.19)
# Rural with high human development (probability)    0.93\n(0.89-0.98)
# Rural with low human development (probability)     1.15\n(1.12-1.17)
# Days since first death                             2.49\n(2.41-2.58)
# Residual degrees of freedom                                     5554
# Deviance                                                     4559.35
# Pearson chi-squared                                          5650.48
# $R_{CU}^{2}$                                                     0.6
# AIC                                                         18553.88
#
#                                                                 2020  \
# Variable
# Urbanized (probability)                             1.0\n(0.99-1.01)
# Urbanized with informal settlements (probability)  1.03\n(1.02-1.04)
# Semi-urbanized (probability)                       0.98\n(0.97-0.99)
# Rural with high human development (probability)    1.05\n(1.03-1.07)
# Rural with low human development (probability)     0.95\n(0.94-0.97)
# Days since first death                             1.67\n(1.63-1.71)
# Residual degrees of freedom                                     5554
# Deviance                                                     5748.75
# Pearson chi-squared                                          5978.82
# $R_{CU}^{2}$                                                     0.4
# AIC                                                         31605.42
#
#                                                                 2021  \
# Variable
# Urbanized (probability)                            1.17\n(1.16-1.18)
# Urbanized with informal settlements (probability)    1.0\n(1.0-1.01)
# Semi-urbanized (probability)                       0.89\n(0.88-0.89)
# Rural with high human development (probability)    1.07\n(1.06-1.08)
# Rural with low human development (probability)     0.86\n(0.85-0.87)
# Days since first death                             1.26\n(1.24-1.28)
# Residual degrees of freedom                                     5554
# Deviance                                                     5715.11
# Pearson chi-squared                                          5825.26
# $R_{CU}^{2}$                                                    0.59
# AIC                                                         39569.35
#
#                                                                 2022  \
# Variable
# Urbanized (probability)                             1.11\n(1.1-1.12)
# Urbanized with informal settlements (probability)  0.94\n(0.93-0.95)
# Semi-urbanized (probability)                       0.91\n(0.89-0.92)
# Rural with high human development (probability)     1.2\n(1.18-1.23)
# Rural with low human development (probability)      0.82\n(0.8-0.83)
# Days since first death                             2.26\n(2.16-2.37)
# Residual degrees of freedom                                     5554
# Deviance                                                     4665.64
# Pearson chi-squared                                          5304.86
# $R_{CU}^{2}$                                                    0.52
# AIC                                                         23265.91
#
#                                                            2020-2022
# Variable
# Urbanized (probability)                            1.14\n(1.13-1.14)
# Urbanized with informal settlements (probability)  1.02\n(1.01-1.03)
# Semi-urbanized (probability)                         0.9\n(0.9-0.91)
# Rural with high human development (probability)    1.06\n(1.05-1.07)
# Rural with low human development (probability)     0.88\n(0.87-0.88)
# Days since first death                             1.19\n(1.17-1.21)
# Residual degrees of freedom                                     5554
# Deviance                                                     5579.56
# Pearson chi-squared                                          5642.19
# $R_{CU}^{2}$                                                    0.51
# AIC                                                         43192.92

# %%
df_analysis_cluster
# Out:
#                                     2020 (first half) - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                                 9.24\n(8.56-9.92)
# Urbanized with informal settlements                    47.19\n(42.74-51.64)
# Semi-urbanized                                         17.88\n(16.83-18.93)
# Rural with high human development                         4.58\n(3.72-5.43)
# Rural with low human development                        30.19\n(27.0-33.39)
# Residual degrees of freedom                                  nan\n(nan-nan)
# Deviance                                                     nan\n(nan-nan)
# Pearson chi-squared                                          nan\n(nan-nan)
# $R_{CU}^{2}$                                                 nan\n(nan-nan)
# AIC                                                          nan\n(nan-nan)
#
#                                     2020 (first half) - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                                       1 [Reference]
# Urbanized with informal settlements                         1.36\n(1.13-1.63)
# Semi-urbanized                                              1.87\n(1.63-2.14)
# Rural with high human development                           1.01\n(0.83-1.23)
# Rural with low human development                            2.65\n(2.12-3.32)
# Residual degrees of freedom                                              5539
# Deviance                                                               5337.7
# Pearson chi-squared                                                    6892.1
# $R_{CU}^{2}$                                                             0.33
# AIC                                                                  20391.05
#
#                                     2020 (first half) - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                                       1 [Reference]
# Urbanized with informal settlements                         1.01\n(0.87-1.16)
# Semi-urbanized                                              1.46\n(1.29-1.65)
# Rural with high human development                            1.21\n(1.0-1.46)
# Rural with low human development                            1.47\n(1.21-1.79)
# Residual degrees of freedom                                              5538
# Deviance                                                              4527.98
# Pearson chi-squared                                                   5781.98
# $R_{CU}^{2}$                                                             0.64
# AIC                                                                  18297.25
#
#                                     2020 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                  68.86\n(66.9-70.83)
# Urbanized with informal settlements      115.8\n(110.31-121.3)
# Semi-urbanized                            63.41\n(61.57-65.26)
# Rural with high human development         52.26\n(48.76-55.77)
# Rural with low human development           64.4\n(59.79-69.01)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2020 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            1.06\n(0.96-1.16)
# Semi-urbanized                                 1.23\n(1.15-1.31)
# Rural with high human development               1.08\n(1.0-1.18)
# Rural with low human development               1.29\n(1.15-1.44)
# Residual degrees of freedom                                 5539
# Deviance                                                  6233.4
# Pearson chi-squared                                      5856.69
# $R_{CU}^{2}$                                                 0.2
# AIC                                                     32933.61
#
#                                     2020 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            1.04\n(0.96-1.13)
# Semi-urbanized                                  1.13\n(1.07-1.2)
# Rural with high human development              1.22\n(1.13-1.32)
# Rural with low human development               1.06\n(0.95-1.17)
# Residual degrees of freedom                                 5538
# Deviance                                                 5658.02
# Pearson chi-squared                                      5790.51
# $R_{CU}^{2}$                                                0.44
# AIC                                                     31365.19
#
#                                     2021 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                              243.29\n(239.23-247.35)
# Urbanized with informal settlements    192.68\n(184.22-201.14)
# Semi-urbanized                         123.63\n(120.71-126.54)
# Rural with high human development      193.64\n(186.67-200.62)
# Rural with low human development          83.94\n(78.38-89.51)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2021 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.79\n(0.73-0.84)
# Semi-urbanized                                  0.73\n(0.7-0.76)
# Rural with high human development                0.95\n(0.9-1.0)
# Rural with low human development               0.58\n(0.54-0.63)
# Residual degrees of freedom                                 5539
# Deviance                                                 5867.71
# Pearson chi-squared                                      5831.72
# $R_{CU}^{2}$                                                0.53
# AIC                                                     40064.49
#
#                                     2021 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.81\n(0.76-0.86)
# Semi-urbanized                                 0.76\n(0.72-0.79)
# Rural with high human development              0.98\n(0.93-1.03)
# Rural with low human development               0.61\n(0.56-0.66)
# Residual degrees of freedom                                 5538
# Deviance                                                 5789.12
# Pearson chi-squared                                      5930.56
# $R_{CU}^{2}$                                                0.63
# AIC                                                     39342.44
#
#                                     2022 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                 41.82\n(40.58-43.07)
# Urbanized with informal settlements        27.89\n(26.19-29.6)
# Semi-urbanized                            22.93\n(22.13-23.74)
# Rural with high human development         37.97\n(35.51-40.43)
# Rural with low human development            11.35\n(10.2-12.5)
# Residual degrees of freedom                     nan\n(nan-nan)
# Deviance                                        nan\n(nan-nan)
# Pearson chi-squared                             nan\n(nan-nan)
# $R_{CU}^{2}$                                    nan\n(nan-nan)
# AIC                                             nan\n(nan-nan)
#
#                                     2022 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements             0.9\n(0.83-0.97)
# Semi-urbanized                                 0.84\n(0.79-0.89)
# Rural with high human development              0.93\n(0.86-1.01)
# Rural with low human development               0.64\n(0.57-0.73)
# Residual degrees of freedom                                 5539
# Deviance                                                 6275.74
# Pearson chi-squared                                      5739.46
# $R_{CU}^{2}$                                                0.35
# AIC                                                      24906.0
#
#                                     2022 - RR (95% CI) - Model 2  \
# Sociodemographic cluster
# Urbanized                                          1 [Reference]
# Urbanized with informal settlements            0.95\n(0.89-1.01)
# Semi-urbanized                                 0.88\n(0.83-0.93)
# Rural with high human development              1.03\n(0.95-1.11)
# Rural with low human development               0.74\n(0.66-0.83)
# Residual degrees of freedom                                 5538
# Deviance                                                 4681.19
# Pearson chi-squared                                      5094.09
# $R_{CU}^{2}$                                                0.62
# AIC                                                     22587.67
#
#                                     2020-2022 - Death rate (95% CI)  \
# Sociodemographic cluster
# Urbanized                                    353.97\n(348.7-359.25)
# Urbanized with informal settlements         336.37\n(323.17-349.58)
# Semi-urbanized                              209.97\n(206.09-213.85)
# Rural with high human development           283.88\n(275.03-292.72)
# Rural with low human development            159.69\n(150.64-168.75)
# Residual degrees of freedom                          nan\n(nan-nan)
# Deviance                                             nan\n(nan-nan)
# Pearson chi-squared                                  nan\n(nan-nan)
# $R_{CU}^{2}$                                         nan\n(nan-nan)
# AIC                                                  nan\n(nan-nan)
#
#                                     2020-2022 - RR (95% CI) - Model 1  \
# Sociodemographic cluster
# Urbanized                                               1 [Reference]
# Urbanized with informal settlements                   0.85\n(0.8-0.9)
# Semi-urbanized                                      0.84\n(0.81-0.87)
# Rural with high human development                    1.0\n(0.95-1.04)
# Rural with low human development                    0.74\n(0.69-0.79)
# Residual degrees of freedom                                      5539
# Deviance                                                      5715.17
# Pearson chi-squared                                            5655.8
# $R_{CU}^{2}$                                                      0.5
# AIC                                                          43358.52
#
#                                     2020-2022 - RR (95% CI) - Model 2
# Sociodemographic cluster
# Urbanized                                               1 [Reference]
# Urbanized with informal settlements                   0.85\n(0.8-0.9)
# Semi-urbanized                                      0.82\n(0.79-0.85)
# Rural with high human development                   1.03\n(0.99-1.08)
# Rural with low human development                     0.7\n(0.65-0.74)
# Residual degrees of freedom                                      5538
# Deviance                                                      5637.35
# Pearson chi-squared                                           5728.63
# $R_{CU}^{2}$                                                     0.57
# AIC                                                          42839.08

# %% [markdown]
# #### Model 4 and 5

# %%
df_analysis_models_4_5 = pd.DataFrame()
df_analysis_models_4_5['Variables'] = ['const','Urbanized','Urbanized with informal settlements','Semi-urbanized','Rural with high human development','Rural with low human development','percentage_population_age_range_60_more',
       'percentage_urban_population', 'demographic_density',
       'percentage_male_population', 'percentage_indigenous_population',
       'per_capita_income', 'gini',
       'percentage_estimated_households_in_informal_settlements',
       'demographic_density_in_informal_settlements',
       'percentage_hospitalizations_diseases_inadequate_sanitation',
       'percentage_self_employed_workers', 'unemployment_rate',
       'percentage_workers_commerce', 'percentage_workers_services',
       'percentage_workers_industry', 'expected_years_of_schooling_at_age_18',
       'delta_first_death_period','Residual degrees of freedom','Deviance',"Pearson's chi-squared",'Cragg-Uhler R²', 'McFadden R²','Akaike Information Criterion (AIC)']
df_analysis_models_4_5 = df_analysis_models_4_5.set_index('Variables')

list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
list_death_rate_columns = ['Death rate (1/2020)', 'Death rate (2020)', 'Death rate (2021)', 'Death rate (2022)', 'Death rate (accumulated period)']
list_period_labels = ['2020 (first half)','2020','2021','2022','2020-2022']

for i in range(len(list_periods)):
    period = list_periods[i]
    period_label = list_period_labels[i]
    death_rate_column = list_death_rate_columns[i]
    
    mortality_rate = df_deaths.groupby('cluster_label')[death_rate_column].mean()
    ci_data = df_deaths.groupby('cluster_label')[death_rate_column].apply(calculate_95_ci)
    df_analysis_models_4_5[['Mean', 'Lower CI', 'Upper CI']] = pd.DataFrame(ci_data.tolist(), index=ci_data.index).round(2)
    df_analysis_models_4_5[period_label+' - Death rate (95% CI)'] = df_analysis_models_4_5['Mean'].astype(str) + '\n' + '('+df_analysis_models_4_5['Lower CI'].astype(str) + '-'+df_analysis_models_4_5['Upper CI'].astype(str) + ')'
    df_analysis_models_4_5 = df_analysis_models_4_5.drop(columns=['Mean', 'Lower CI', 'Upper CI'])
    
    for model in [6,4,5]:
        model_label = str(model)
        model_file = str(model)
        with open('models/model_'+model_file+'_'+period+'.pkl', 'rb') as file:
            model = pickle.load(file)

        # Extract the coefficients and standard errors
        params = model.params[0:]
        conf = model.conf_int()[0:]
        conf.columns = ['Lower CI', 'Upper CI']
        
        # Calculate the rate ratios and their confidence intervals
        rate_ratios = np.exp(params)
        conf['Lower CI'] = np.exp(conf['Lower CI'])
        conf['Upper CI'] = np.exp(conf['Upper CI'])
        
        # Combine into a single DataFrame
        rate_ratio_df = pd.DataFrame({
            'Rate Ratio': rate_ratios,
            'Lower CI': conf['Lower CI'],
            'Upper CI': conf['Upper CI']
        }) 
        
        rate_ratio_df = rate_ratio_df.round(2)
        
        column_rate_ratio = period_label+' - RR (95% CI) - Model '+model_label
        df_analysis_models_4_5[column_rate_ratio] = rate_ratio_df['Rate Ratio'].astype(str) + '\n' + '('+rate_ratio_df['Lower CI'].astype(str) + '-'+rate_ratio_df['Upper CI'].astype(str) + ')'        
        
        df_analysis_models_4_5.loc['Residual degrees of freedom', column_rate_ratio] = model.df_resid
        df_analysis_models_4_5.loc['Deviance', column_rate_ratio] = round(model.deviance,2)
        df_analysis_models_4_5.loc["Pearson's chi-squared", column_rate_ratio] = round(model.pearson_chi2,2)
        df_analysis_models_4_5.loc['Cragg-Uhler R²', column_rate_ratio] = round(model.pseudo_rsquared('cs'),2)
        df_analysis_models_4_5.loc['McFadden R²', column_rate_ratio] = round(model.pseudo_rsquared('mcf'),2)
        df_analysis_models_4_5.loc['Akaike Information Criterion (AIC)', column_rate_ratio] = round(model.aic,2)

df_analysis_models_4_5.index = ['Intercept','Urbanized','Urbanized with informal settlements','Semi-urbanized','Rural with high human development','Rural with low human development','% population 60+ years','% urban population','Population density (inhabitants/km²)','% male population','% indigenous population','Per capita income (BRL)','Gini coefficient','% informal settlement households', 'Population density in informal settlement (inhabitants/ha)', '% sanitation-related hospitalizations', '% self-employed workers', 'Unemployment rate', '% commerce workers', '% service workers', '% industry workers', 'Expected years of schooling at age 18', 'Days since first death','Residual degrees of freedom','Deviance',"Pearson's chi-squared",'Cragg-Uhler R²', 'McFadden R²','Akaike Information Criterion (AIC)']

df_analysis_models_4_5.to_csv('data/output/df_analysis_models_4_5.csv', index=True)

# %%
params
# Out:
# const                                                        -5.953647
# Semi-urbanized                                               -0.052944
# Rural with high human development                             0.077273
# Urbanized with informal settlements                          -0.037258
# Rural with low human development                             -0.090941
# Urbanized                                                     0.065097
# percentage_population_age_range_60_more                       0.062248
# percentage_urban_population                                   0.119591
# demographic_density                                           0.005254
# percentage_male_population                                    0.026923
# percentage_indigenous_population                              0.041404
# per_capita_income                                            -0.010168
# gini                                                          0.009866
# percentage_estimated_households_in_informal_settlements       0.019257
# demographic_density_in_informal_settlements                   0.016041
# percentage_hospitalizations_diseases_inadequate_sanitation   -0.007123
# percentage_self_employed_workers                              0.005692
# unemployment_rate                                            -0.019433
# percentage_workers_commerce                                  -0.003996
# percentage_workers_services                                   0.054476
# percentage_workers_industry                                   0.019136
# expected_years_of_schooling_at_age_18                         0.030875
# delta_first_death_period                                      0.167516
# dtype: float64

# %% [markdown]
# ## Analysis of the sociodemographic variables

# %%
df_analysis_variables = pd.DataFrame()

for i in range(len(list_periods)):
    period = list_periods[i]
    period_label = list_period_labels[i]
    
    with open('models/model_2_'+period+'.pkl', 'rb') as file:
        model = pickle.load(file)

    # Extract the coefficients and standard errors
    params = model.params[5:]
    conf = model.conf_int()[5:]
    conf.columns = ['Lower CI', 'Upper CI']
    
    # Calculate the rate ratios and their confidence intervals
    rate_ratios = np.exp(params)
    conf['Lower CI'] = np.exp(conf['Lower CI'])
    conf['Upper CI'] = np.exp(conf['Upper CI'])
    
    # Combine into a single DataFrame
    rate_ratio_df = pd.DataFrame({
        'Rate Ratio': rate_ratios,
        'Lower CI': conf['Lower CI'],
        'Upper CI': conf['Upper CI']
    })
    
    rate_ratio_df = rate_ratio_df.round(2)
    
    df_analysis_variables[period_label] = rate_ratio_df['Rate Ratio'].astype(str) + '\n' + '('+rate_ratio_df['Lower CI'].astype(str) + '-'+rate_ratio_df['Upper CI'].astype(str) + ')'
    
df_analysis_variables['Variable'] = ['% population 60+ years','% urban population','Population density (inhabitants/km²)','% male population','% indigenous population','Per capita income (BRL)','Gini coefficient','% informal settlement households', 'Population density in informal settlement (inhabitants/ha)', '% sanitation-related hospitalizations', '% self-employed workers', 'Unemployment rate', '% commerce workers', '% service workers', '% industry workers', 'Expected years of schooling at age 18', 'Days since first death']

df_analysis_variables = df_analysis_variables.set_index('Variable')  

df_analysis_variables.to_csv('data/output/df_analysis_variables.csv', index=True)

# %%
df_analysis_variables
# Out:
#                                                     2020 (first half)  \
# Variable
# % population 60+ years                              0.92\n(0.88-0.97)
# % urban population                                  1.07\n(1.01-1.14)
# Population density (inhabitants/km²)                1.03\n(1.01-1.06)
# % male population                                   0.99\n(0.95-1.03)
# % indigenous population                              1.02\n(1.0-1.05)
# Per capita income (BRL)                              0.74\n(0.7-0.78)
# Gini coefficient                                    1.03\n(0.98-1.07)
# % informal settlement households                    1.09\n(1.06-1.12)
# Population density in informal settlement (inha...  0.99\n(0.96-1.01)
# % sanitation-related hospitalizations                1.0\n(0.97-1.03)
# % self-employed workers                             1.13\n(1.08-1.18)
# Unemployment rate                                   1.11\n(1.06-1.15)
# % commerce workers                                  0.93\n(0.89-0.97)
# % service workers                                    1.1\n(1.05-1.17)
# % industry workers                                   1.1\n(1.05-1.15)
# Expected years of schooling at age 18               1.07\n(1.02-1.11)
# Days since first death                               2.4\n(2.32-2.48)
#
#                                                                  2020  \
# Variable
# % population 60+ years                              1.09\n(1.07-1.12)
# % urban population                                  1.11\n(1.07-1.14)
# Population density (inhabitants/km²)                1.01\n(0.99-1.02)
# % male population                                    1.02\n(1.0-1.04)
# % indigenous population                             1.05\n(1.03-1.06)
# Per capita income (BRL)                             0.94\n(0.92-0.97)
# Gini coefficient                                     0.98\n(0.96-1.0)
# % informal settlement households                    1.04\n(1.02-1.05)
# Population density in informal settlement (inha...   1.0\n(0.98-1.01)
# % sanitation-related hospitalizations                0.98\n(0.97-1.0)
# % self-employed workers                             1.05\n(1.02-1.07)
# Unemployment rate                                   1.01\n(0.99-1.03)
# % commerce workers                                   0.98\n(0.96-1.0)
# % service workers                                   1.09\n(1.06-1.12)
# % industry workers                                  1.06\n(1.03-1.08)
# Expected years of schooling at age 18               0.99\n(0.97-1.01)
# Days since first death                              1.63\n(1.59-1.67)
#
#                                                                  2021  \
# Variable
# % population 60+ years                              1.09\n(1.07-1.11)
# % urban population                                   1.13\n(1.1-1.15)
# Population density (inhabitants/km²)                0.99\n(0.98-1.01)
# % male population                                   1.06\n(1.04-1.07)
# % indigenous population                             1.03\n(1.02-1.04)
# Per capita income (BRL)                              1.02\n(1.0-1.04)
# Gini coefficient                                    0.99\n(0.98-1.01)
# % informal settlement households                     1.0\n(0.99-1.01)
# Population density in informal settlement (inha...   1.01\n(1.0-1.02)
# % sanitation-related hospitalizations                1.0\n(0.99-1.01)
# % self-employed workers                             0.99\n(0.98-1.01)
# Unemployment rate                                   0.95\n(0.94-0.96)
# % commerce workers                                   0.98\n(0.96-1.0)
# % service workers                                   1.06\n(1.03-1.08)
# % industry workers                                  1.01\n(0.99-1.03)
# Expected years of schooling at age 18               1.07\n(1.05-1.09)
# Days since first death                               1.28\n(1.26-1.3)
#
#                                                                  2022  \
# Variable
# % population 60+ years                              1.35\n(1.32-1.37)
# % urban population                                  1.09\n(1.06-1.13)
# Population density (inhabitants/km²)                 0.99\n(0.98-1.0)
# % male population                                   1.07\n(1.05-1.09)
# % indigenous population                             1.03\n(1.01-1.05)
# Per capita income (BRL)                             1.03\n(1.01-1.06)
# Gini coefficient                                    0.97\n(0.95-0.99)
# % informal settlement households                     0.99\n(0.98-1.0)
# Population density in informal settlement (inha...   1.0\n(0.98-1.01)
# % sanitation-related hospitalizations                0.98\n(0.96-1.0)
# % self-employed workers                             0.94\n(0.92-0.96)
# Unemployment rate                                    0.98\n(0.95-1.0)
# % commerce workers                                  0.94\n(0.92-0.97)
# % service workers                                   0.99\n(0.96-1.02)
# % industry workers                                  0.96\n(0.94-0.99)
# Expected years of schooling at age 18               1.05\n(1.03-1.07)
# Days since first death                              2.37\n(2.27-2.48)
#
#                                                             2020-2022
# Variable
# % population 60+ years                               1.1\n(1.08-1.11)
# % urban population                                  1.13\n(1.11-1.15)
# Population density (inhabitants/km²)                 1.0\n(0.99-1.01)
# % male population                                   1.04\n(1.02-1.05)
# % indigenous population                             1.04\n(1.03-1.05)
# Per capita income (BRL)                             1.01\n(0.99-1.02)
# Gini coefficient                                    0.99\n(0.98-1.01)
# % informal settlement households                     1.01\n(1.0-1.02)
# Population density in informal settlement (inha...   1.01\n(1.0-1.02)
# % sanitation-related hospitalizations               0.98\n(0.97-0.99)
# % self-employed workers                             1.01\n(0.99-1.02)
# Unemployment rate                                   0.97\n(0.96-0.99)
# % commerce workers                                   1.0\n(0.99-1.01)
# % service workers                                   1.05\n(1.03-1.06)
# % industry workers                                   1.02\n(1.0-1.03)
# Expected years of schooling at age 18               1.04\n(1.03-1.05)
# Days since first death                              1.17\n(1.16-1.19)

# %%
with open('models/model_1_2020_1.pkl', 'rb') as file:
    model = pickle.load(file)
print(model.summary())
# Out:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5539
# Model Family:                            NegativeBinomial   Df Model:                           20
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -10175.
# Date:                                    Mon, 17 Jun 2024   Deviance:                       5337.7
# Time:                                            17:08:33   Pearson chi2:                 6.89e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.3332
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.4148      0.044   -215.447      0.000      -9.500      -9.329
# cluster_label_Urbanized with informal settlements              0.3076      0.094      3.276      0.001       0.124       0.492
# cluster_label_Semi-urbanized                                   0.6248      0.069      9.084      0.000       0.490       0.760
# cluster_label_Rural with high human development                0.0065      0.101      0.065      0.948      -0.191       0.204
# cluster_label_Rural with low human development                 0.9748      0.114      8.524      0.000       0.751       1.199
# percentage_population_age_range_60_more                       -0.2468      0.028     -8.940      0.000      -0.301      -0.193
# percentage_urban_population                                    0.0316      0.034      0.928      0.354      -0.035       0.098
# demographic_density                                            0.0772      0.016      4.841      0.000       0.046       0.108
# percentage_male_population                                    -0.1654      0.025     -6.532      0.000      -0.215      -0.116
# percentage_indigenous_population                               0.0162      0.016      1.023      0.306      -0.015       0.047
# per_capita_income                                             -0.2667      0.032     -8.262      0.000      -0.330      -0.203
# gini                                                           0.0595      0.025      2.362      0.018       0.010       0.109
# percentage_estimated_households_in_informal_settlements        0.1378      0.016      8.743      0.000       0.107       0.169
# demographic_density_in_informal_settlements                    0.0206      0.017      1.206      0.228      -0.013       0.054
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0517      0.018     -2.796      0.005      -0.088      -0.015
# percentage_self_employed_workers                               0.2486      0.026      9.620      0.000       0.198       0.299
# unemployment_rate                                              0.1181      0.022      5.400      0.000       0.075       0.161
# percentage_workers_commerce                                    0.0427      0.026      1.671      0.095      -0.007       0.093
# percentage_workers_services                                    0.2553      0.031      8.353      0.000       0.195       0.315
# percentage_workers_industry                                    0.2280      0.027      8.407      0.000       0.175       0.281
# expected_years_of_schooling_at_age_18                          0.0983      0.023      4.226      0.000       0.053       0.144
# ==============================================================================================================================

# %%
with open('models/model_2_2020_1.pkl', 'rb') as file:
    model = pickle.load(file)
print(model.summary())
# Out:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5538
# Model Family:                            NegativeBinomial   Df Model:                           21
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -9126.6
# Date:                                    Mon, 17 Jun 2024   Deviance:                       4528.0
# Time:                                            17:08:34   Pearson chi2:                 5.78e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.6433
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -9.6246      0.041   -236.366      0.000      -9.704      -9.545
# cluster_label_Urbanized with informal settlements              0.0060      0.075      0.080      0.936      -0.141       0.152
# cluster_label_Semi-urbanized                                   0.3789      0.062      6.120      0.000       0.258       0.500
# cluster_label_Rural with high human development                0.1883      0.099      1.911      0.056      -0.005       0.381
# cluster_label_Rural with low human development                 0.3871      0.101      3.839      0.000       0.189       0.585
# percentage_population_age_range_60_more                       -0.0835      0.025     -3.342      0.001      -0.132      -0.035
# percentage_urban_population                                    0.0713      0.031      2.308      0.021       0.011       0.132
# demographic_density                                            0.0311      0.012      2.556      0.011       0.007       0.055
# percentage_male_population                                    -0.0134      0.021     -0.647      0.517      -0.054       0.027
# percentage_indigenous_population                               0.0244      0.013      1.844      0.065      -0.002       0.050
# per_capita_income                                             -0.3007      0.028    -10.912      0.000      -0.355      -0.247
# gini                                                           0.0281      0.022      1.251      0.211      -0.016       0.072
# percentage_estimated_households_in_informal_settlements        0.0858      0.012      6.988      0.000       0.062       0.110
# demographic_density_in_informal_settlements                   -0.0146      0.014     -1.078      0.281      -0.041       0.012
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0022      0.016     -0.133      0.894      -0.034       0.030
# percentage_self_employed_workers                               0.1230      0.024      5.177      0.000       0.076       0.170
# unemployment_rate                                              0.1011      0.020      5.136      0.000       0.063       0.140
# percentage_workers_commerce                                   -0.0732      0.023     -3.165      0.002      -0.119      -0.028
# percentage_workers_services                                    0.0998      0.028      3.558      0.000       0.045       0.155
# percentage_workers_industry                                    0.0927      0.025      3.749      0.000       0.044       0.141
# expected_years_of_schooling_at_age_18                          0.0633      0.021      3.016      0.003       0.022       0.104
# delta_first_death_period                                       0.8744      0.017     50.923      0.000       0.841       0.908
# ==============================================================================================================================

# %%
with open('models/model_1_2020.pkl', 'rb') as file:
    model = pickle.load(file)
print(model.summary())
# Out:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     deaths_accumulated_2020   No. Observations:                 5560
# Model:                                 GLM   Df Residuals:                     5539
# Model Family:             NegativeBinomial   Df Model:                           20
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -16446.
# Date:                     Mon, 17 Jun 2024   Deviance:                       6233.4
# Time:                             17:08:34   Pearson chi2:                 5.86e+03
# No. Iterations:                          8   Pseudo R-squ. (CS):             0.1972
# Covariance Type:                 nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -7.4659      0.020   -371.139      0.000      -7.505      -7.426
# cluster_label_Urbanized with informal settlements              0.0549      0.048      1.144      0.253      -0.039       0.149
# cluster_label_Semi-urbanized                                   0.2035      0.033      6.236      0.000       0.140       0.268
# cluster_label_Rural with high human development                0.0813      0.041      1.988      0.047       0.001       0.161
# cluster_label_Rural with low human development                 0.2531      0.057      4.426      0.000       0.141       0.365
# percentage_population_age_range_60_more                        0.0015      0.013      0.118      0.906      -0.023       0.026
# percentage_urban_population                                    0.0916      0.016      5.582      0.000       0.059       0.124
# demographic_density                                            0.0162      0.008      1.965      0.049       4e-05       0.032
# percentage_male_population                                    -0.0379      0.011     -3.518      0.000      -0.059      -0.017
# percentage_indigenous_population                               0.0386      0.008      4.658      0.000       0.022       0.055
# per_capita_income                                             -0.0479      0.015     -3.118      0.002      -0.078      -0.018
# gini                                                           0.0098      0.012      0.818      0.413      -0.014       0.033
# percentage_estimated_households_in_informal_settlements        0.0531      0.008      6.449      0.000       0.037       0.069
# demographic_density_in_informal_settlements                    0.0083      0.009      0.949      0.343      -0.009       0.026
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0276      0.009     -2.947      0.003      -0.046      -0.009
# percentage_self_employed_workers                               0.0849      0.012      6.906      0.000       0.061       0.109
# unemployment_rate                                              0.0221      0.011      1.977      0.048       0.000       0.044
# percentage_workers_commerce                                    0.0520      0.012      4.230      0.000       0.028       0.076
# percentage_workers_services                                    0.1330      0.015      9.074      0.000       0.104       0.162
# percentage_workers_industry                                    0.1124      0.013      8.833      0.000       0.087       0.137
# expected_years_of_schooling_at_age_18                         -0.0067      0.011     -0.616      0.538      -0.028       0.015
# ==============================================================================================================================

# %%
with open('models/model_1_2021.pkl', 'rb') as file:
    model = pickle.load(file)
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            deaths_2021   No. Observations:                 5560
# Model:                            GLM   Df Residuals:                     5539
# Model Family:        NegativeBinomial   Df Model:                           20
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20011.
# Date:                Mon, 17 Jun 2024   Deviance:                       5867.7
# Time:                        17:08:34   Pearson chi2:                 5.83e+03
# No. Iterations:                    10   Pseudo R-squ. (CS):             0.5301
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -6.2221      0.014   -447.685      0.000      -6.249      -6.195
# cluster_label_Urbanized with informal settlements             -0.2395      0.036     -6.684      0.000      -0.310      -0.169
# cluster_label_Semi-urbanized                                  -0.3138      0.023    -13.636      0.000      -0.359      -0.269
# cluster_label_Rural with high human development               -0.0549      0.027     -2.043      0.041      -0.108      -0.002
# cluster_label_Rural with low human development                -0.5429      0.042    -12.944      0.000      -0.625      -0.461
# percentage_population_age_range_60_more                        0.0657      0.009      7.478      0.000       0.048       0.083
# percentage_urban_population                                    0.1316      0.012     11.335      0.000       0.109       0.154
# demographic_density                                           -0.0059      0.006     -0.953      0.340      -0.018       0.006
# percentage_male_population                                     0.0378      0.007      5.445      0.000       0.024       0.051
# percentage_indigenous_population                               0.0332      0.006      5.158      0.000       0.021       0.046
# per_capita_income                                              0.0317      0.011      2.929      0.003       0.010       0.053
# gini                                                           0.0042      0.008      0.492      0.622      -0.012       0.021
# percentage_estimated_households_in_informal_settlements        0.0013      0.006      0.205      0.837      -0.011       0.014
# demographic_density_in_informal_settlements                    0.0133      0.007      2.029      0.042       0.000       0.026
# percentage_hospitalizations_diseases_inadequate_sanitation    -0.0079      0.007     -1.157      0.247      -0.021       0.005
# percentage_self_employed_workers                               0.0036      0.009      0.420      0.674      -0.013       0.020
# unemployment_rate                                             -0.0484      0.008     -5.878      0.000      -0.065      -0.032
# percentage_workers_commerce                                    0.0208      0.009      2.398      0.016       0.004       0.038
# percentage_workers_services                                    0.0433      0.010      4.195      0.000       0.023       0.064
# percentage_workers_industry                                    0.0162      0.009      1.816      0.069      -0.001       0.034
# expected_years_of_schooling_at_age_18                          0.0529      0.008      6.942      0.000       0.038       0.068
# ==============================================================================================================================

# %%
df_deaths['deaths'].sum()
# Out:
# 701736.0

# %%
df_deaths[df_deaths['cluster_label']=='Urbanized with informal settlements']['deaths'].sum()
# Out:
# 363523.0

# %%
df_deaths[df_deaths['cluster_label']=='Urbanized']['deaths'].sum()
# Out:
# 236607.0

# %%
df_deaths['population'].sum()
# Out:
# 202760341

# %%
df_deaths[df_deaths['cluster_label']=='Urbanized with informal settlements']['population'].sum()
# Out:
# 92394320

# %%
df_deaths[df_deaths['cluster_label']=='Urbanized']['population'].sum()
# Out:
# 63741508

# %%
df_deaths['deaths_2021'].sum()
# Out:
# 423977.0
