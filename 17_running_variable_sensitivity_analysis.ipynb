# %% [markdown]
# # Variable sensitive analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import pickle

import util

# %% [markdown]
# ## Loading data

# %%
df_variables = pd.read_csv('data/output/df_without_collinearity_standardized.csv', index_col=0)

# %%
df_political = pd.read_csv('data/output/df_political_without_missing_points.csv', index_col=0)[['percentual_votes_for_bolsonaro']]

# %%
df_vaccination_fully_vaccinated_people = pd.read_csv('data/df_vaccination.csv', index_col=0)[['% people fully vaccinated (1/2020)', '% people fully vaccinated (2020)', '% people fully vaccinated (2020-2021)', '% people fully vaccinated (2020-2022)']]

# %%
df_y = pd.read_csv('data/output/df_mortality.csv', index_col=0)

# %%
list_population =  df_y['population']
list_offset = np.log(list_population)

# %% [markdown]
# ## Variable Sensitivity Analysis

# %%
list_columns_y = ['deaths_accumulated_first_semester_2020', 'deaths_accumulated_2020', 'deaths_2021', 'deaths_2022', 'deaths']
list_periods = ['2020_1','2020', '2021', '2022', '2020_2022']
list_delta_first_death_columns = ['delta_first_death_2020-06-30', 'delta_first_death_2020-12-31', 'delta_first_death_2021-12-31', 'delta_first_death_2022-12-31', 'delta_first_death_general_period']
   
vaccination_columns = [0,1,2,3,3]   
   
for i in range(5):
    column_y = list_columns_y[i]
    period = list_periods[i]
    column_delta_first_death = list_delta_first_death_columns[i]    
    list_offset_extra = np.log(df_y[column_delta_first_death]+1)
    print('\n*** Period: ', period)
        
    y = df_y[column_y]
    
    # Model 10
    print('\*** Model 10')
    print('===>Full model:')
    with open('models/model_10_'+period+'.pkl', 'rb') as file:
        model = pickle.load(file)
    util.summarize_results(model)

    x = df_variables.copy()
    scaler = StandardScaler()
    percentage_votes_for_bolsonaro_standardized = scaler.fit_transform(df_political)
    x['percentage_votes_for_bolsonaro'] = percentage_votes_for_bolsonaro_standardized[:,0]
    vaccination_column = vaccination_columns[i]
    vaccination_standardized = scaler.fit_transform(df_vaccination_fully_vaccinated_people)
    x['% people fully vaccinated'] = vaccination_standardized[:, vaccination_column]    

    for variable in x.columns:
        print('\n*** Removed variable: ',variable)
        x_analysis = x.drop(columns=[variable])
        x_analysis = sm.add_constant(x_analysis)
        model = util.tunning_negative_binomial_model(x_analysis,y,list_offset,list_offset_extra)
        filename = 'model_10_'+period+'_'+variable
        util.save_model(model,filename,'models/sensitivity_analysis/variable')
        util.summarize_results(model)
# Out:
# *** Period:  2020_1
# \*** Model 10
# ===>Full model:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5543
# Model Family:                            NegativeBinomial   Df Model:                           16
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8500.3
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3459.1
# Time:                                            22:59:20   Pearson chi2:                 5.27e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1012
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1952      0.020   -621.760      0.000     -12.234     -12.157
# percentage_population_age_range_60_more                       -0.0433      0.022     -1.953      0.051      -0.087       0.000
# percentage_urban_population                                   -0.0630      0.031     -2.049      0.040      -0.123      -0.003
# percentage_male_population                                     0.0575      0.021      2.715      0.007       0.016       0.099
# percentage_indigenous_population                               0.0399      0.013      3.174      0.002       0.015       0.064
# density_median_effectively_domiciled_area                      0.0978      0.016      5.962      0.000       0.066       0.130
# gini                                                          -0.0605      0.021     -2.924      0.003      -0.101      -0.020
# percentage_estimated_households_in_informal_settlements        0.0638      0.011      5.989      0.000       0.043       0.085
# demographic_density_in_informal_settlements                   -0.0099      0.012     -0.833      0.405      -0.033       0.013
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0183      0.016      1.153      0.249      -0.013       0.049
# percentage_self_employed_workers                               0.0839      0.023      3.636      0.000       0.039       0.129
# unemployment_rate                                              0.2162      0.019     11.602      0.000       0.180       0.253
# percentage_workers_commerce                                   -0.1110      0.023     -4.866      0.000      -0.156      -0.066
# percentage_workers_services                                   -0.0717      0.027     -2.699      0.007      -0.124      -0.020
# percentage_workers_industry                                   -0.0968      0.024     -4.097      0.000      -0.143      -0.050
# expected_years_of_schooling_at_age_18                          0.0504      0.021      2.431      0.015       0.010       0.091
# percentage_votes_for_bolsonaro                                -0.0451      0.022     -2.082      0.037      -0.088      -0.003
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8500.32
# deviance:  3459.08
# pearson_chi2:  5269.94
# Estimated dispersion:  0.95
# aic:  17034.65
#
# *** Removed variable:  percentage_population_age_range_60_more
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8502.1
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3462.6
# Time:                                            22:59:37   Pearson chi2:                 5.23e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1007
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1824      0.018   -659.682      0.000     -12.219     -12.146
# percentage_urban_population                                   -0.0628      0.031     -2.043      0.041      -0.123      -0.003
# percentage_male_population                                     0.0723      0.020      3.632      0.000       0.033       0.111
# percentage_indigenous_population                               0.0429      0.012      3.446      0.001       0.018       0.067
# density_median_effectively_domiciled_area                      0.1025      0.016      6.332      0.000       0.071       0.134
# gini                                                          -0.0504      0.020     -2.497      0.013      -0.090      -0.011
# percentage_estimated_households_in_informal_settlements        0.0654      0.011      6.176      0.000       0.045       0.086
# demographic_density_in_informal_settlements                   -0.0099      0.012     -0.839      0.401      -0.033       0.013
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0214      0.016      1.354      0.176      -0.010       0.052
# percentage_self_employed_workers                               0.0830      0.023      3.600      0.000       0.038       0.128
# unemployment_rate                                              0.2232      0.018     12.143      0.000       0.187       0.259
# percentage_workers_commerce                                   -0.1040      0.023     -4.596      0.000      -0.148      -0.060
# percentage_workers_services                                   -0.0758      0.026     -2.862      0.004      -0.128      -0.024
# percentage_workers_industry                                   -0.0902      0.023     -3.852      0.000      -0.136      -0.044
# expected_years_of_schooling_at_age_18                          0.0411      0.020      2.043      0.041       0.002       0.081
# percentage_votes_for_bolsonaro                                -0.0469      0.022     -2.166      0.030      -0.089      -0.004
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8502.1
# deviance:  3462.63
# pearson_chi2:  5234.46
# Estimated dispersion:  0.94
# aic:  17036.2
#
# *** Removed variable:  percentage_urban_population
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8502.4
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3463.2
# Time:                                            22:59:55   Pearson chi2:                 5.24e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1006
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1942      0.020   -621.655      0.000     -12.233     -12.156
# percentage_population_age_range_60_more                       -0.0433      0.022     -1.952      0.051      -0.087       0.000
# percentage_male_population                                     0.0617      0.021      2.925      0.003       0.020       0.103
# percentage_indigenous_population                               0.0405      0.013      3.225      0.001       0.016       0.065
# density_median_effectively_domiciled_area                      0.0924      0.016      5.715      0.000       0.061       0.124
# gini                                                          -0.0551      0.020     -2.688      0.007      -0.095      -0.015
# percentage_estimated_households_in_informal_settlements        0.0636      0.011      5.976      0.000       0.043       0.085
# demographic_density_in_informal_settlements                   -0.0084      0.012     -0.710      0.478      -0.032       0.015
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0167      0.016      1.053      0.292      -0.014       0.048
# percentage_self_employed_workers                               0.0885      0.023      3.854      0.000       0.043       0.134
# unemployment_rate                                              0.2164      0.019     11.605      0.000       0.180       0.253
# percentage_workers_commerce                                   -0.1274      0.021     -5.959      0.000      -0.169      -0.086
# percentage_workers_services                                   -0.0942      0.024     -3.934      0.000      -0.141      -0.047
# percentage_workers_industry                                   -0.1143      0.022     -5.196      0.000      -0.157      -0.071
# expected_years_of_schooling_at_age_18                          0.0478      0.021      2.309      0.021       0.007       0.088
# percentage_votes_for_bolsonaro                                -0.0516      0.021     -2.407      0.016      -0.094      -0.010
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8502.39
# deviance:  3463.21
# pearson_chi2:  5238.54
# Estimated dispersion:  0.94
# aic:  17036.78
#
# *** Removed variable:  percentage_male_population
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8503.5
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3465.3
# Time:                                            23:00:13   Pearson chi2:                 5.33e+03
# No. Iterations:                                        12   Pseudo R-squ. (CS):             0.1002
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.2032      0.019   -627.400      0.000     -12.241     -12.165
# percentage_population_age_range_60_more                       -0.0632      0.021     -2.995      0.003      -0.105      -0.022
# percentage_urban_population                                   -0.0699      0.031     -2.281      0.023      -0.130      -0.010
# percentage_indigenous_population                               0.0413      0.013      3.294      0.001       0.017       0.066
# density_median_effectively_domiciled_area                      0.0897      0.016      5.544      0.000       0.058       0.121
# gini                                                          -0.0635      0.021     -3.076      0.002      -0.104      -0.023
# percentage_estimated_households_in_informal_settlements        0.0637      0.011      5.974      0.000       0.043       0.085
# demographic_density_in_informal_settlements                   -0.0105      0.012     -0.889      0.374      -0.034       0.013
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0193      0.016      1.215      0.225      -0.012       0.050
# percentage_self_employed_workers                               0.0869      0.023      3.766      0.000       0.042       0.132
# unemployment_rate                                              0.2134      0.019     11.447      0.000       0.177       0.250
# percentage_workers_commerce                                   -0.1263      0.022     -5.728      0.000      -0.170      -0.083
# percentage_workers_services                                   -0.0784      0.026     -2.959      0.003      -0.130      -0.026
# percentage_workers_industry                                   -0.1045      0.023     -4.458      0.000      -0.151      -0.059
# expected_years_of_schooling_at_age_18                          0.0505      0.021      2.432      0.015       0.010       0.091
# percentage_votes_for_bolsonaro                                -0.0303      0.021     -1.456      0.145      -0.071       0.010
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8503.45
# deviance:  3465.33
# pearson_chi2:  5328.18
# Estimated dispersion:  0.96
# aic:  17038.91
#
# *** Removed variable:  percentage_indigenous_population
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8505.3
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3468.9
# Time:                                            23:00:31   Pearson chi2:                 5.32e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.09963
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1981      0.020   -621.306      0.000     -12.237     -12.160
# percentage_population_age_range_60_more                       -0.0525      0.022     -2.383      0.017      -0.096      -0.009
# percentage_urban_population                                   -0.0653      0.031     -2.126      0.034      -0.126      -0.005
# percentage_male_population                                     0.0607      0.021      2.875      0.004       0.019       0.102
# density_median_effectively_domiciled_area                      0.0960      0.016      5.858      0.000       0.064       0.128
# gini                                                          -0.0430      0.020     -2.134      0.033      -0.083      -0.004
# percentage_estimated_households_in_informal_settlements        0.0644      0.011      6.043      0.000       0.043       0.085
# demographic_density_in_informal_settlements                   -0.0104      0.012     -0.880      0.379      -0.034       0.013
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0145      0.016      0.914      0.361      -0.017       0.046
# percentage_self_employed_workers                               0.0793      0.023      3.441      0.001       0.034       0.124
# unemployment_rate                                              0.2126      0.019     11.408      0.000       0.176       0.249
# percentage_workers_commerce                                   -0.1178      0.023     -5.183      0.000      -0.162      -0.073
# percentage_workers_services                                   -0.0653      0.027     -2.461      0.014      -0.117      -0.013
# percentage_workers_industry                                   -0.0922      0.024     -3.906      0.000      -0.138      -0.046
# expected_years_of_schooling_at_age_18                          0.0385      0.021      1.879      0.060      -0.002       0.079
# percentage_votes_for_bolsonaro                                -0.0416      0.022     -1.918      0.055      -0.084       0.001
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8505.25
# deviance:  3468.94
# pearson_chi2:  5315.21
# Estimated dispersion:  0.96
# aic:  17042.51
#
# *** Removed variable:  density_median_effectively_domiciled_area
# Selected alpha: 0.4
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8518.8
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3449.1
# Time:                                            23:00:49   Pearson chi2:                 5.21e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.09301
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1850      0.020   -617.447      0.000     -12.224     -12.146
# percentage_population_age_range_60_more                       -0.0633      0.022     -2.869      0.004      -0.107      -0.020
# percentage_urban_population                                   -0.0306      0.030     -1.006      0.315      -0.090       0.029
# percentage_male_population                                     0.0291      0.022      1.351      0.177      -0.013       0.071
# percentage_indigenous_population                               0.0373      0.013      2.951      0.003       0.013       0.062
# gini                                                          -0.0582      0.021     -2.799      0.005      -0.099      -0.017
# percentage_estimated_households_in_informal_settlements        0.0733      0.011      6.881      0.000       0.052       0.094
# demographic_density_in_informal_settlements                    0.0248      0.011      2.350      0.019       0.004       0.045
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0098      0.016      0.611      0.541      -0.022       0.041
# percentage_self_employed_workers                               0.0842      0.023      3.620      0.000       0.039       0.130
# unemployment_rate                                              0.2300      0.019     12.354      0.000       0.194       0.266
# percentage_workers_commerce                                   -0.1065      0.023     -4.643      0.000      -0.151      -0.062
# percentage_workers_services                                   -0.0743      0.027     -2.778      0.005      -0.127      -0.022
# percentage_workers_industry                                   -0.0892      0.024     -3.759      0.000      -0.136      -0.043
# expected_years_of_schooling_at_age_18                          0.0417      0.021      2.006      0.045       0.001       0.083
# percentage_votes_for_bolsonaro                                -0.0653      0.022     -3.025      0.002      -0.108      -0.023
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8518.79
# deviance:  3449.07
# pearson_chi2:  5212.67
# Estimated dispersion:  0.94
# aic:  17069.57
#
# *** Removed variable:  gini
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8504.4
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3467.1
# Time:                                            23:01:05   Pearson chi2:                 5.32e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.09992
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.2014      0.020   -625.698      0.000     -12.240     -12.163
# percentage_population_age_range_60_more                       -0.0272      0.022     -1.254      0.210      -0.070       0.015
# percentage_urban_population                                   -0.0521      0.031     -1.706      0.088      -0.112       0.008
# percentage_male_population                                     0.0612      0.021      2.891      0.004       0.020       0.103
# percentage_indigenous_population                               0.0307      0.012      2.499      0.012       0.007       0.055
# density_median_effectively_domiciled_area                      0.0973      0.016      5.926      0.000       0.065       0.129
# percentage_estimated_households_in_informal_settlements        0.0634      0.011      5.951      0.000       0.043       0.084
# demographic_density_in_informal_settlements                   -0.0104      0.012     -0.881      0.378      -0.034       0.013
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0142      0.016      0.898      0.369      -0.017       0.045
# percentage_self_employed_workers                               0.0796      0.023      3.451      0.001       0.034       0.125
# unemployment_rate                                              0.2180      0.019     11.701      0.000       0.182       0.255
# percentage_workers_commerce                                   -0.1165      0.023     -5.116      0.000      -0.161      -0.072
# percentage_workers_services                                   -0.0814      0.026     -3.092      0.002      -0.133      -0.030
# percentage_workers_industry                                   -0.0787      0.023     -3.443      0.001      -0.124      -0.034
# expected_years_of_schooling_at_age_18                          0.0563      0.021      2.733      0.006       0.016       0.097
# percentage_votes_for_bolsonaro                                -0.0396      0.022     -1.833      0.067      -0.082       0.003
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8504.35
# deviance:  3467.14
# pearson_chi2:  5323.61
# Estimated dispersion:  0.96
# aic:  17040.71
#
# *** Removed variable:  percentage_estimated_households_in_informal_settlements
# Selected alpha: 0.4
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8518.8
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3449.1
# Time:                                            23:01:22   Pearson chi2:                 5.22e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.09300
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1947      0.020   -617.176      0.000     -12.233     -12.156
# percentage_population_age_range_60_more                       -0.0542      0.022     -2.436      0.015      -0.098      -0.011
# percentage_urban_population                                   -0.0604      0.031     -1.952      0.051      -0.121       0.000
# percentage_male_population                                     0.0581      0.021      2.731      0.006       0.016       0.100
# percentage_indigenous_population                               0.0413      0.013      3.256      0.001       0.016       0.066
# density_median_effectively_domiciled_area                      0.1128      0.016      6.883      0.000       0.081       0.145
# gini                                                          -0.0599      0.021     -2.875      0.004      -0.101      -0.019
# demographic_density_in_informal_settlements                    0.0021      0.012      0.178      0.858      -0.021       0.025
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0142      0.016      0.889      0.374      -0.017       0.046
# percentage_self_employed_workers                               0.0927      0.023      3.992      0.000       0.047       0.138
# unemployment_rate                                              0.2219      0.019     11.855      0.000       0.185       0.259
# percentage_workers_commerce                                   -0.1070      0.023     -4.659      0.000      -0.152      -0.062
# percentage_workers_services                                   -0.0519      0.027     -1.956      0.051      -0.104       0.000
# percentage_workers_industry                                   -0.1036      0.024     -4.355      0.000      -0.150      -0.057
# expected_years_of_schooling_at_age_18                          0.0455      0.021      2.182      0.029       0.005       0.086
# percentage_votes_for_bolsonaro                                -0.0379      0.022     -1.738      0.082      -0.081       0.005
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8518.82
# deviance:  3449.14
# pearson_chi2:  5219.72
# Estimated dispersion:  0.94
# aic:  17069.65
#
# *** Removed variable:  demographic_density_in_informal_settlements
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8500.6
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3459.7
# Time:                                            23:01:38   Pearson chi2:                 5.27e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1011
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1946      0.020   -622.097      0.000     -12.233     -12.156
# percentage_population_age_range_60_more                       -0.0434      0.022     -1.956      0.050      -0.087    7.98e-05
# percentage_urban_population                                   -0.0615      0.031     -2.004      0.045      -0.122      -0.001
# percentage_male_population                                     0.0579      0.021      2.733      0.006       0.016       0.099
# percentage_indigenous_population                               0.0400      0.013      3.187      0.001       0.015       0.065
# density_median_effectively_domiciled_area                      0.0920      0.015      6.314      0.000       0.063       0.121
# gini                                                          -0.0608      0.021     -2.939      0.003      -0.101      -0.020
# percentage_estimated_households_in_informal_settlements        0.0623      0.011      5.933      0.000       0.042       0.083
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0179      0.016      1.128      0.259      -0.013       0.049
# percentage_self_employed_workers                               0.0830      0.023      3.600      0.000       0.038       0.128
# unemployment_rate                                              0.2179      0.019     11.741      0.000       0.182       0.254
# percentage_workers_commerce                                   -0.1089      0.023     -4.809      0.000      -0.153      -0.065
# percentage_workers_services                                   -0.0763      0.026     -2.921      0.003      -0.128      -0.025
# percentage_workers_industry                                   -0.0984      0.024     -4.177      0.000      -0.145      -0.052
# expected_years_of_schooling_at_age_18                          0.0500      0.021      2.413      0.016       0.009       0.091
# percentage_votes_for_bolsonaro                                -0.0453      0.022     -2.090      0.037      -0.088      -0.003
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8500.65
# deviance:  3459.73
# pearson_chi2:  5272.31
# Estimated dispersion:  0.95
# aic:  17033.3
#
# *** Removed variable:  percentage_hospitalizations_diseases_inadequate_sanitation
# Selected alpha: 0.39
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8501.0
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3460.4
# Time:                                            23:01:56   Pearson chi2:                 5.28e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):             0.1010
# Covariance Type:                                nonrobust
# ===========================================================================================================================
#                                                               coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                     -12.1945      0.020   -622.162      0.000     -12.233     -12.156
# percentage_population_age_range_60_more                    -0.0459      0.022     -2.082      0.037      -0.089      -0.003
# percentage_urban_population                                -0.0613      0.031     -1.997      0.046      -0.121      -0.001
# percentage_male_population                                  0.0581      0.021      2.749      0.006       0.017       0.099
# percentage_indigenous_population                            0.0388      0.013      3.101      0.002       0.014       0.063
# density_median_effectively_domiciled_area                   0.0963      0.016      5.891      0.000       0.064       0.128
# gini                                                       -0.0583      0.021     -2.836      0.005      -0.099      -0.018
# percentage_estimated_households_in_informal_settlements     0.0633      0.011      5.944      0.000       0.042       0.084
# demographic_density_in_informal_settlements                -0.0094      0.012     -0.799      0.424      -0.033       0.014
# percentage_self_employed_workers                            0.0867      0.023      3.779      0.000       0.042       0.132
# unemployment_rate                                           0.2154      0.019     11.562      0.000       0.179       0.252
# percentage_workers_commerce                                -0.1104      0.023     -4.839      0.000      -0.155      -0.066
# percentage_workers_services                                -0.0748      0.026     -2.829      0.005      -0.127      -0.023
# percentage_workers_industry                                -0.0990      0.024     -4.196      0.000      -0.145      -0.053
# expected_years_of_schooling_at_age_18                       0.0499      0.021      2.408      0.016       0.009       0.091
# percentage_votes_for_bolsonaro                             -0.0484      0.021     -2.259      0.024      -0.090      -0.006
# % people fully vaccinated                                        0          0        nan        nan           0           0
# ===========================================================================================================================
# llf: -8500.96
# deviance:  3460.35
# pearson_chi2:  5277.85
# Estimated dispersion:  0.95
# aic:  17033.92
#
# *** Removed variable:  percentage_self_employed_workers
# Selected alpha: 0.4
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     deaths_accumulated_first_semester_2020   No. Observations:                 5560
# Model:                                                GLM   Df Residuals:                     5544
# Model Family:                            NegativeBinomial   Df Model:                           15
# Link Function:                                        Log   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -8506.5
# Date:                                    Mon, 30 Dec 2024   Deviance:                       3424.5
# Time:                                            23:02:20   Pearson chi2:                 5.16e+03
# No. Iterations:                                        13   Pseudo R-squ. (CS):            0.09701
# Covariance Type:                                nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        -12.1914      0.020   -616.828      0.000     -12.230     -12.153
# percentage_population_age_range_60_more                       -0.0412      0.022     -1.840      0.066      -0.085       0.003
# percentage_urban_population                                   -0.0721      0.031     -2.341      0.019      -0.132      -0.012
# percentage_male_population                                     0.0619      0.021      2.925      0.003       0.020       0.103
# percentage_indigenous_population                               0.0374      0.013      2.963      0.003       0.013       0.062
# density_median_effectively_domiciled_area                      0.0977      0.017      5.894      0.000       0.065       0.130
# gini                                                          -0.0559      0.021     -2.691      0.007      -0.097      -0.015
# percentage_estimated_households_in_informal_settlements        0.0662      0.011      6.160      0.000       0.045       0.087
# demographic_density_in_informal_settlements                   -0.0080      0.012     -0.673      0.501      -0.031       0.015
# percentage_hospitalizations_diseases_inadequate_sanitation     0.0241      0.016      1.514      0.130      -0.007       0.055
# unemployment_rate                                              0.2031      0.019     10.975      0.000       0.167       0.239
# percentage_workers_commerce                                   -0.0880      0.022     -3.975      0.000      -0.131      -0.045
# percentage_workers_services                                   -0.1004      0.026     -3.915      0.000      -0.151      -0.050
# percentage_workers_industry                                   -0.1188      0.023     -5.151      0.000      -0.164      -0.074
# expected_years_of_schooling_at_age_18                          0.0458      0.021      2.197      0.028       0.005       0.087
# percentage_votes_for_bolsonaro                                -0.0374      0.022     -1.722      0.085      -0.080       0.005
# % people fully vaccinated                                           0          0        nan        nan           0           0
# ==============================================================================================================================
# llf: -8506.52
# deviance:  3424.54
# pearson_chi2:  5156.19
# Estimated dispersion:  0.93
# aic:  17045.05
#
# *** Removed variable:  unemployment_rate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e6101cdf98ed> in <module>
#      33         x_analysis = x.drop(columns=[variable])
#      34         x_analysis = sm.add_constant(x_analysis)
# ---> 35         model = tunning_negative_binomial_model(x_analysis,y,list_offset,list_offset_extra)
#      36         filename = 'model_10_'+period+'_'+variable
#      37         save_model(model,filename,'models/sensitivity_analysis/variable')
#
# ~/Codigos/Python/PesquisasCovid19/main/thesis/correlation_sociodemographic_covid/util.py in tunning_negative_binomial_model(x, y, list_offset, list_offset_extra, list_offset_extra_2)
#      19
#      20     for alpha in list_alpha:
# ---> 21         nb_glm_model = sm.GLM(y, x, family=sm.families.NegativeBinomial(alpha=alpha), offset=list_offset).fit()
#      22         llf = nb_glm_model.llf
#      23         list_nb_glm_models = np.append(list_nb_glm_models, nb_glm_model)
#
# ~/anaconda3/envs/base-r/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py in fit(self, start_params, maxiter, method, tol, scale, cov_type, cov_kwds, use_t, full_output, disp, max_start_irls, **kwargs)
#    1105             if cov_type.lower() == 'eim':
#    1106                 cov_type = 'nonrobust'
# -> 1107             return self._fit_irls(start_params=start_params, maxiter=maxiter,
#    1108                                   tol=tol, scale=scale, cov_type=cov_type,
#    1109                                   cov_kwds=cov_kwds, use_t=use_t, **kwargs)
#
# ~/anaconda3/envs/base-r/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py in _fit_irls(self, start_params, maxiter, tol, scale, cov_type, cov_kwds, use_t, **kwargs)
#    1246                                             self.weights, check_endog=True,
#    1247                                             check_weights=True)
# -> 1248             wls_results = wls_mod.fit(method=wls_method)
#    1249             lin_pred = np.dot(self.exog, wls_results.params)
#    1250             lin_pred += self._offset_exposure
#
# ~/anaconda3/envs/base-r/lib/python3.9/site-packages/statsmodels/regression/_tools.py in fit(self, method)
#      99             params = np.linalg.solve(R, np.dot(Q.T, self.wendog))
#     100         else:
# --> 101             params, _, _, _ = np.linalg.lstsq(self.wexog, self.wendog,
#     102                                               rcond=-1)
#     103         return self.results(params)
#
# ~/anaconda3/envs/base-r/lib/python3.9/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2324         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327     if m == 0:
#    2328         x[...] = 0
#
# KeyboardInterrupt:
